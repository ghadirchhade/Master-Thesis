# %% [markdown]
# <a href="https://colab.research.google.com/github/ghadirchhade/Master-Thesis/blob/main/baseline1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %%
# !pip install -q torch torchvision

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.11.0+cu128
# Torchvision version: 0.26.0+cu128
# CUDA is available: True

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# facebook/sam3 is gated on the Hub -> you must accept the license at
# https://huggingface.co/facebook/sam3 with the account whose token you use below.
# !pip install -q -U transformers accelerate huggingface_hub supervision

from huggingface_hub import login
login()  # paste your HF token (needs access to facebook/sam3)

print("Transformers SAM3 dependencies installed.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 64.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 kB 23.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 4.6 MB/s eta 0:00:00
# Transformers SAM3 dependencies installed.

# %%
import os, glob, csv, time
import numpy as np
import pandas as pd
import gc
import torch
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import supervision as sv
import matplotlib.patches as patches
from transformers import Sam3Model, Sam3Processor

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

sam3_model = Sam3Model.from_pretrained("facebook/sam3", device_map="auto")
sam3_model.eval()

sam3_processor = Sam3Processor.from_pretrained("facebook/sam3")

print("HF transformers SAM3 model + processor loaded.")
print("Model device:", next(sam3_model.parameters()).device)
# Out:
# config.json:   0%|          | 0.00/25.8k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.44GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/1468 [00:00<?, ?it/s]
# processor_config.json:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]
# HF transformers SAM3 model + processor loaded.
# Model device: cuda:0

# %%
IMAGES_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/images"
LABELS_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/annotations_yolo"
RUMEX_CLASS_ID = 0

# %%
#Experiment identity (CHANGE THESE 3 LINES PER EXPERIMENT)
EXPERIMENT_NAME = "E02_2"   # e.g. "E02_2" (Exp1), "<exp2_name>", "<exp3_name>"
N_EXEMPLARS     = 3         # 3 for Exp1/Exp2, 1 for Exp3
USE_TILING      = True      # True for Exp1/Exp3, False for Exp2

# SAM3 / tiling params (reuse Exp1's values)
TILE_SIZE = 1000
OVERLAP   = 150
THRESHOLD = 0.3
IOU_THRESHOLD = 0.5

RNG = np.random.default_rng(42)  # fixed seed -> reproducible exemplar sampling

# %%
# Output CSV (append-safe: survives Colab disconnects)
OUTPUT_CSV = f"/content/drive/MyDrive/master_thesis/results/results_{EXPERIMENT_NAME}.csv"
CSV_COLUMNS = ["experiment_name", "image_ID", "anchor_idx", "Prompt_ID", "Prompt_Type", "mAP50",
               "precision", "recall", "IoU1", "IoU2"]

PROMPT_TYPE = "multiple" if N_EXEMPLARS > 1 else "single"

# %%
#reads yolo annotations and convert its normailzed bboxes into pixel-coordinate bboxes (x1,y1,x2,y2)
# from (id,x,y,w,h) to (x1,y1,x2,y2)
def load_yolo_boxes(label_path, img_width, img_height, class_id=0):
    boxes = []
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if not parts: #skip empty lines and move to the next one
                continue
            cls = int(parts[0])
            if cls != class_id: #keep only the requested class
                continue
            xc, yc, bw, bh = map(float, parts[1:5]) #read normalized yolo coordinates and convert them to float
            xc, yc, bw, bh = xc * img_width, yc * img_height, bw * img_width, bh * img_height #convert normalized coordinates into pixels coordinates
            boxes.append([xc - bw / 2, yc - bh / 2, xc + bw / 2, yc + bh / 2]) # convert center format to corner format
    return np.array(boxes, dtype=np.float32)

# %%
def format_prompt_id(exemplar_indices: list) -> str:
    """
    Single box (Exp3)   -> "5"
    Multiple boxes (Exp1/Exp2) -> "5+12+3"  (anchor first, then the sampled others,
    order preserved so you can always tell which one was the anchor: it's the
    first number in the string)
    """
    return "+".join(str(i) for i in exemplar_indices)

# %%
#takes an image name and its folder, searches for the corresponding YOLO .txt
#annotation in either a mirrored-folder structure or a flat structure,
#and returns the label path if found; otherwise it returns None.
def find_label_path(image_filename_no_ext, folder_name):
    mirrored = os.path.join(LABELS_ROOT, folder_name, image_filename_no_ext + ".txt")
    flat = os.path.join(LABELS_ROOT, image_filename_no_ext + ".txt")
    if os.path.exists(mirrored):
        return mirrored
    if os.path.exists(flat):
        return flat
    return None

# %%
#Discover every image across all folders in AGS_MULTI_RUMEX
image_records = []  # (folder, image_path, label_path, image_id)
VALID_EXT = (".jpg", ".jpeg", ".png")

for folder in sorted(os.listdir(IMAGES_ROOT)): #loop over folders
    folder_path = os.path.join(IMAGES_ROOT, folder) #full folder path
    if not os.path.isdir(folder_path): #make sure it is actually a directory
        continue
    for fname in sorted(os.listdir(folder_path)): #loop through every file inside that folder
        if not fname.lower().endswith(VALID_EXT):
            continue
        name_no_ext = os.path.splitext(fname)[0] #select only the image name without extension
        label_path = find_label_path(name_no_ext, folder)
        image_id = f"{folder}/{name_no_ext}"
        image_records.append((folder, os.path.join(folder_path, fname), label_path, image_id))
        missing_labels = [r for r in image_records if r[2] is None]

print(f"Discovered {len(image_records)} images across {len(set(r[0] for r in image_records))} folders.")
if missing_labels:
    print(f"WARNING: {len(missing_labels)} images have no matching label file (will be skipped). "
          f"First few: {[r[3] for r in missing_labels[:5]]}")
# Out:
# Discovered 179 images across 15 folders.

# %%
# Exemplar selection (anchor + N-1 random others)
def select_exemplar_indices(n_gt: int, anchor_idx: int, n_exemplars: int, image_id: str) -> list:
    """
    Builds the exemplar index set for one run:
      - always includes the anchor box (the one this row is "about")
      - fills the rest (n_exemplars - 1 slots) with OTHER GT boxes from the
        same image, sampled without replacement
      - if the image doesn't have enough other GT boxes, just uses whatever
        is available (no duplication, no crash)
    """

    ## each GT bbox gets a chance to act as the "anchor"
    ## prompt, while the remaining exemplars are randomly sampled from the same image.
    seed = abs(hash((image_id, anchor_idx))) % (2**32) #create a deterministic seed
    rng = np.random.default_rng(seed)
    others = [i for i in range(n_gt) if i != anchor_idx]
    n_others_needed = min(n_exemplars - 1, len(others))
    if n_others_needed > 0: # several positive bboxes
        chosen_others = list(rng.choice(others, size=n_others_needed, replace=False))
    else:
        chosen_others = [] #single positive bbox
    return [anchor_idx] + chosen_others

# %%
#to make the strip looks less artificial
#patch_w   → desired strip width
#patch_h   → desired strip height
def get_local_background_patch(tile_img: Image.Image, patch_w: int, patch_h: int) -> Image.Image:
    """
    Instead of a flat white block, sample REAL texture from the tile itself to use as
    the strip's background. Why this matters:
      - Color balance, brightness, and grain automatically match this tile's own
        lighting conditions (which can vary tile-to-tile across a large drone photo).
      - There's no artificial white-vs-photo boundary for the vision transformer's
        self-attention to latch onto as a spurious "edge feature".
      - The exemplar's ROI-pooled feature (computed AFTER the image encoder has already
        mixed in neighboring context via attention) ends up looking like "a plant in
        grass" instead of "a plant in a void" -- much closer to a real target instance.

    We grab the top-left corner of the tile from target img (an area that won't be duplicated, since
    the strip sits ABOVE the tile in the final canvas, not overlapping it).
    """

    #take a crop from the top-left corner of the tile
    sample = tile_img.crop((0, 0, min(patch_w, tile_img.width), min(patch_h, tile_img.height)))
    if sample.size != (patch_w, patch_h): #Check whether the sampled patch has the required size of the exemplar strip
        sample = sample.resize((patch_w, patch_h))
    return sample


#This function creates a soft transparency mask around an exemplar crop
#If we paste it directly into another image, you may get a sharp rectangular boundary
#That rectangle can look artificial
#The feather mask makes the edges partially transparent so that the crop blends gradually into the local-texture background.
def make_feather_mask(size, feather_width):
    #feather_width is the requested thickness of the soft blending border around the exemplar crop
    w, h = size #of the exemplar crop
    mask = np.full((h, w), 255.0, dtype=np.float32) #Create a fully opaque mask
    #initially every pixel contains 255(fully opaque=>entire crop would be fully visible)

    #effective_feather is the actual feather width the code is allowed to use, after checking that the crop is large enough
    effective_feather = min(feather_width, h // 2, w // 2) # Determine how large the feather can safely be
    if effective_feather >= 1:
        for i in range(effective_feather): #loop over the feather border (i=>border layer)
            alpha = 255.0 * (i + 1) / effective_feather #compute transparency for the layer
            mask[i, :] = np.minimum(mask[i, :], alpha) #feather top edge
            mask[h - 1 - i, :] = np.minimum(mask[h - 1 - i, :], alpha) #bottom edge
            mask[:, i] = np.minimum(mask[:, i], alpha) #left edge
            mask[:, w - 1 - i] = np.minimum(mask[:, w - 1 - i], alpha) #right edge

    return Image.fromarray(mask.astype(np.uint8), mode="L")  # <-- return a PIL Image, not ndarray

# %%
#It takes:the current tile; the exemplar crop images (list of exemplar crops selected from the GT boxes);a margin between exemplars;a feather width for blending.
#and also returns the exemplar bounding boxes in the coordinates of this composed image.
def compose_tile_with_exemplars(tile_img: Image.Image, crop_images: list,
                                 margin: int = 6, feather_width: int = 8):
    """
    Builds the small composed image actually sent to SAM3, for ONE tile, with
    MULTIPLE exemplar crops placed side-by-side in a strip above the tile.

    Returns:
        composed  -- the image to feed to SAM3
        crop_boxes -- list of [x1,y1,x2,y2], one per exemplar, in composed-image coords
        offset    -- (dx, dy) to convert composed target-region coords back
                     to this TILE's own coordinate system
    """
    n = len(crop_images) #number of exemplars
    strip_h = max(c.height for c in crop_images) + 2 * margin # This finds the height of the tallest exemplar + 2 * (margin of top+margin of bottom)=strip height
    strip_content_w = sum(c.width for c in crop_images) + margin * (n + 1) #Compute how wide the strip needs to be
    canvas_w = max(tile_img.width, strip_content_w)
    canvas_h = strip_h + tile_img.height

    #create the strip background
    strip_bg = get_local_background_patch(tile_img, canvas_w, strip_h)

    #final container
    composed = Image.new("RGB", (canvas_w, canvas_h))
    composed.paste(strip_bg, (0, 0)) #very top
    offset = (0, strip_h) #tile offeset (bcz we put the strip above the tile, the tile no longer sterts at (0,0) in the composed img, it now starts at y=strip_h => shifted down by strip_h px)
    composed.paste(tile_img, offset) #paste the real tile (shifted down)

    crop_boxes = [] #This will store the position (coordinates) of every exemplar inside the composed image,these boxes are later passed to SAM3 as positive visual prompts
    cursor_x = margin #horizontal cursor starts at x=6 (bcz of the margin before the strip)
    for crop_image in crop_images: #loop over exemplar crops
        feather_mask = make_feather_mask(crop_image.size, feather_width=feather_width)
        paste_xy = (cursor_x, margin) #Decide where to paste the exemplar (x1,y1)
        composed.paste(crop_image, paste_xy, feather_mask)

        crop_boxes.append([
            paste_xy[0], paste_xy[1],
            paste_xy[0] + crop_image.width, paste_xy[1] + crop_image.height,
        ]) #(x1,y1,x2,y2)
        cursor_x += crop_image.width + margin #move horizontal cursor forward

    return composed, crop_boxes, offset

# %%
#generates the bounding boxes of all overlapping tiles that will cover the full UAV image
def tile_bboxes(img_w: int, img_h: int, tile_size: int, overlap: int):
    """
    Generates (x1,y1,x2,y2) windows covering the whole image, with overlap so plants
    sitting right on a tile boundary aren't missed or half-cut in every window.
    """
    step = tile_size - overlap
    tiles = []
    for y in range(0, img_h, step):
        for x in range(0, img_w, step):
            x2 = min(x + tile_size, img_w) #bottom right
            y2 = min(y + tile_size, img_h)
            x1 = max(0, x2 - tile_size) #top left
            y1 = max(0, y2 - tile_size)
            tiles.append((x1, y1, x2, y2))
    return list(dict.fromkeys(tiles))

# %%
def keep_only_target_region_detections(boxes, scores, masks, offset, y_tolerance=5):
    """
    Drop any detection sitting inside the padding strip (that's a pasted exemplar
    being re-detected, not a real find), keep only detections that fall within the
    tile's real-content region, and remap their coordinates back to that tile's own
    coordinate system (undo the paste offset).
    """
    dx, dy = offset
    kept_boxes, kept_scores, kept_masks = [], [], []

    for box, score, mask in zip(boxes, scores, masks):
        x1, y1, x2, y2 = box.tolist() if torch.is_tensor(box) else box
        if y1 >= dy - y_tolerance:
            remapped_box = [x1 - dx, max(y1 - dy, 0), x2 - dx, y2 - dy]
            kept_boxes.append(remapped_box)
            kept_scores.append(score)
            mask_np = mask.cpu().numpy() if torch.is_tensor(mask) else mask
            kept_masks.append(mask_np[dy:, dx:] if dx or dy else mask_np)

    return kept_boxes, kept_scores, kept_masks

# %%
def filter_implausible_boxes(boxes, scores, masks, tile_w, tile_h,
                              min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5):
    """
    Drops detections unlikely to be real single Rumex plants:
      - box area implausibly large relative to the tile (likely background clutter,
        not a single plant)
      - predicted mask fills too little of its own box (weak/noisy detection rather
        than a confident, well-localized instance)
      - degenerate boxes clipped to (near) zero size at the tile edges
    `edge_margin` is used to tolerate boxes that legitimately touch a tile border
    (real plants often do, since tiles overlap and neighboring tiles will pick up
    the rest of the same plant) rather than penalizing them outright.
    """
    kept_boxes, kept_scores, kept_masks = [], [], []
    tile_area = tile_w * tile_h

    for box, score, mask in zip(boxes, scores, masks):
        x1, y1, x2, y2 = box
        box_w, box_h = x2 - x1, y2 - y1
        if box_w <= edge_margin or box_h <= edge_margin:
            continue

        box_area = box_w * box_h
        if box_area / tile_area > max_area_fraction:
            continue

        mask_np = mask.cpu().numpy() if torch.is_tensor(mask) else mask
        x1c, y1c = int(max(0, x1)), int(max(0, y1))
        x2c, y2c = int(min(mask_np.shape[1], x2)), int(min(mask_np.shape[0], y2))
        if x2c <= x1c or y2c <= y1c:
            continue

        region = mask_np[y1c:y2c, x1c:x2c]
        fill_ratio = (region > 0.5).mean() if region.size > 0 else 0.0
        if fill_ratio < min_fill_ratio:
            continue

        kept_boxes.append(box)
        kept_scores.append(score)
        kept_masks.append(mask)

    return kept_boxes, kept_scores, kept_masks

# %%
def run_sam3_on_tile(composed_tile, crop_boxes, offset, text_prompt=None, threshold=0.3):
    """
    crop_boxes: list of [x1,y1,x2,y2] exemplar boxes in composed-image coords
    (one per exemplar). All are passed as positive boxes.

    text_prompt is optional. Combining a text phrase the model's text encoder doesn't
    resolve ("rumex...") with the box exemplars actively suppresses real candidate
    detections instead of reinforcing them. Default to box-exemplar-only unless
    you've validated a text phrase actually helps.
    """
    kwargs = dict(
        images=composed_tile,
        input_boxes=[[[float(c) for c in box] for box in crop_boxes]],
        input_boxes_labels=[[1] * len(crop_boxes)],
        return_tensors="pt",
    )
    if text_prompt:
        kwargs["text"] = text_prompt

    inputs = sam3_processor(**kwargs).to(sam3_model.device)
    with torch.no_grad():
        outputs = sam3_model(**inputs)

    results = sam3_processor.post_process_instance_segmentation(
        outputs, threshold=threshold, mask_threshold=0.4,
        target_sizes=inputs.get("original_sizes").tolist(),
    )[0]

    return keep_only_target_region_detections(
        results["boxes"], results["scores"], results["masks"], offset
    )

    del inputs, outputs, results  # <-- new
    return kept

# %%
def nms_merge(boxes, scores, masks, iou_thresh: float = 0.5):
    """
    Because tiles overlap, the same real plant can get detected in two neighboring
    tiles. Standard IoU-based Non-Max Suppression collapses duplicates down to the
    single highest-confidence box -- carries the matching mask through too.
    """
    if not boxes: #if there's no detections
        return [], [], [] #empty boxes,masks,scores

    boxes_t = torch.tensor(boxes, dtype=torch.float32) #convert boxes to tensots
    scores_t = torch.tensor([s.item() if torch.is_tensor(s) else s for s in scores]) #convert scores to tensor
    order = scores_t.argsort(descending=True) #highest detection confidence is processed first
    keep = [] #indices of boxes we keep

    while order.numel() > 0: #continue until  all boxes are processed
        i = order[0].item() #selected highest score box
        keep.append(i)
        if order.numel() == 1:
            break
        rest = order[1:] #the remaining boxes other than the best one
        #compute intersection coordinates (selected best box and the remaining boxes)
        xx1 = torch.maximum(boxes_t[i, 0], boxes_t[rest, 0]) #left
        yy1 = torch.maximum(boxes_t[i, 1], boxes_t[rest, 1]) #top
        xx2 = torch.minimum(boxes_t[i, 2], boxes_t[rest, 2]) #right
        yy2 = torch.minimum(boxes_t[i, 3], boxes_t[rest, 3]) #bottom
        inter = (xx2 - xx1).clamp(0) * (yy2 - yy1).clamp(0) #intersection area
        area_i = (boxes_t[i, 2] - boxes_t[i, 0]) * (boxes_t[i, 3] - boxes_t[i, 1]) #area of selected box
        #area_r: outputs a tensor with areas of all remaining boxes
        area_r = (boxes_t[rest, 2] - boxes_t[rest, 0]) * (boxes_t[rest, 3] - boxes_t[rest, 1]) #area of remaining boxes
        iou = inter / (area_i + area_r - inter + 1e-6) # n IoU values bcz area_r contains the areas of n remaining boxes
        order = rest[iou <= iou_thresh] #filtering (decision to remove duplicates)
        #filters the remaining boxes, keeping only those whose IoU with the selected box is less than or equal to the threshold.

    kept_boxes = [boxes[i] for i in keep]
    kept_scores = [scores[i] for i in keep]
    kept_masks = [masks[i] for i in keep]
    return kept_boxes, kept_scores, kept_masks

# %%
# Unified SAM3 pipeline -- tiled vs whole-image (no tiling)
# Reuses ALL the helper functions already defined from Exp1's code:
# tile_bboxes, compose_tile_with_exemplars, run_sam3_on_tile,
# filter_implausible_boxes, nms_merge, get_local_background_patch,
# make_feather_mask, keep_only_target_region_detections
# Make sure those cells have been run before this one.
def run_sam3_pipeline(image: Image.Image, exemplar_crops: list, use_tiling: bool,
                       tile_size: int = 1000, overlap: int = 150, threshold: float = 0.3):
    """
    Runs the full SAM3 detection pipeline on `image` using `exemplar_crops` as
    positive visual prompts, and returns final (boxes, scores, masks) in the
    full image's coordinate system.

    use_tiling=True  -> splits the image into overlapping tiles (Exp1/Exp3 style),
                         runs SAM3 per tile, merges duplicates with NMS.
    use_tiling=False -> single pass: exemplar strip pasted above the WHOLE image,
                         one SAM3 call, no tile-splitting, no NMS merge needed
                         (still run through nms_merge for safety/consistency,
                         it's a no-op if there's nothing to merge).
    """
    all_boxes, all_scores, all_masks = [], [], []

    if use_tiling:
        for (x1, y1, x2, y2) in tile_bboxes(image.width, image.height, tile_size, overlap):
            tile = image.crop((x1, y1, x2, y2))
            composed_tile, crop_boxes, offset = compose_tile_with_exemplars(
                tile, exemplar_crops, margin=6, feather_width=8
            )
            boxes, scores, masks = run_sam3_on_tile(
                composed_tile, crop_boxes, offset, text_prompt=None, threshold=threshold
            )
            tile_w, tile_h = x2 - x1, y2 - y1
            boxes, scores, masks = filter_implausible_boxes(
                boxes, scores, masks, tile_w, tile_h,
                min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5,
            )
            for b, s, m in zip(boxes, scores, masks):
                all_boxes.append([b[0] + x1, b[1] + y1, b[2] + x1, b[3] + y1])
                all_scores.append(s.item() if torch.is_tensor(s) else s)
                all_masks.append((m, x1, y1))
    else:
        # Whole image treated as a single "tile" the size of the full image.
        composed, crop_boxes, offset = compose_tile_with_exemplars(
            image, exemplar_crops, margin=6, feather_width=8
        )
        boxes, scores, masks = run_sam3_on_tile(
            composed, crop_boxes, offset, text_prompt=None, threshold=threshold
        )
        boxes, scores, masks = filter_implausible_boxes(
            boxes, scores, masks, image.width, image.height,
            min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5,
        )
        for b, s, m in zip(boxes, scores, masks):
            all_boxes.append([b[0], b[1], b[2], b[3]])   # offset is (0,0) here, x1=y1=0
            all_scores.append(s.item() if torch.is_tensor(s) else s)
            all_masks.append((m, 0, 0))

    final_boxes, final_scores, final_masks = nms_merge(all_boxes, all_scores, all_masks, iou_thresh=0.5)
    return final_boxes, final_scores, final_masks

# %%
# Metrics helper -- refactored from Exp1's evaluation cell
# Returns mAP50, precision, recall, IoU1 (matched-only), IoU2 (over all GT)
import supervision as sv
from supervision.metrics import MeanAveragePrecision

def compute_iou_matrix(boxes1, boxes2):
    if len(boxes1) == 0 or len(boxes2) == 0:
        return np.zeros((len(boxes1), len(boxes2)))
    x1 = np.maximum(boxes1[:, None, 0], boxes2[None, :, 0])
    y1 = np.maximum(boxes1[:, None, 1], boxes2[None, :, 1])
    x2 = np.minimum(boxes1[:, None, 2], boxes2[None, :, 2])
    y2 = np.minimum(boxes1[:, None, 3], boxes2[None, :, 3])
    inter_w = np.clip(x2 - x1, 0, None)
    inter_h = np.clip(y2 - y1, 0, None)
    inter_area = inter_w * inter_h
    area1 = (boxes1[:, 2] - boxes1[:, 0]) * (boxes1[:, 3] - boxes1[:, 1])
    area2 = (boxes2[:, 2] - boxes2[:, 0]) * (boxes2[:, 3] - boxes2[:, 1])
    union_area = area1[:, None] + area2[None, :] - inter_area
    return np.where(union_area > 0, inter_area / union_area, 0.0)


def compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold: float = 0.5) -> dict:
    """
    final_boxes/final_scores: predictions for ONE run (one image, one exemplar set)
    gt_boxes: ALL GT boxes for that image (numpy array, xyxy)
    Mirrors exactly the metric logic from Exp1's evaluation cell.
    """
    pred_boxes_np = np.array(final_boxes, dtype=np.float32) if final_boxes else np.zeros((0, 4), dtype=np.float32)
    pred_scores_np = np.array(final_scores, dtype=np.float32) if final_scores else np.zeros((0,), dtype=np.float32)

    # --- mAP50 via supervision ---
    pred_detections = sv.Detections(
        xyxy=pred_boxes_np,
        confidence=pred_scores_np,
        class_id=np.zeros(len(pred_scores_np), dtype=int),
    )
    gt_detections = sv.Detections(
        xyxy=gt_boxes,
        class_id=np.zeros(len(gt_boxes), dtype=int),
    )
    try:
        map_metric = MeanAveragePrecision()
        result = map_metric.update([pred_detections], [gt_detections]).compute()
        map50 = float(result.map50)
    except Exception:
        # supervision can raise/return NaN on degenerate cases (0 preds & 0 GT etc.)
        map50 = 0.0 if len(gt_boxes) > 0 else float("nan")

    #  precision / recall / IoU via greedy matching
    num_preds, num_gt = len(pred_boxes_np), len(gt_boxes)
    iou_matrix = compute_iou_matrix(pred_boxes_np, gt_boxes)

    matched_gt = set()
    true_positives = 0
    matched_ious = []
    pred_order = np.argsort(-pred_scores_np) if num_preds > 0 else []

    for pred_idx in pred_order:
        if num_gt == 0:
            break
        best_gt_idx = np.argmax(iou_matrix[pred_idx])
        best_iou = iou_matrix[pred_idx, best_gt_idx]
        if best_iou >= iou_threshold and best_gt_idx not in matched_gt:
            matched_gt.add(best_gt_idx)
            true_positives += 1
            matched_ious.append(best_iou)

    precision = true_positives / num_preds if num_preds > 0 else 0.0
    recall = true_positives / num_gt if num_gt > 0 else 0.0
    iou1_matched_only = float(np.mean(matched_ious)) if matched_ious else 0.0
    iou2_over_all_gt = float(np.sum(matched_ious) / num_gt) if num_gt > 0 else 0.0

    return {
        "map50": map50,
        "precision": precision,
        "recall": recall,
        "iou_matched": iou1_matched_only,
        "iou_all_gt": iou2_over_all_gt,
    }

# %%
# # Main automated loop -- Exp × Image × Anchor Bbox -> CSV
# # Writes incrementally (append mode) so a Colab disconnect doesn't lose
# # everything already computed. Skips rows already present in the CSV if
# # you re-run after a crash (resumable).
# def load_yolo_boxes(label_path, img_width, img_height, class_id=0):
#     boxes = []
#     with open(label_path, "r") as f:
#         for line in f:
#             parts = line.strip().split()
#             if not parts:
#                 continue
#             cls = int(parts[0])
#             if cls != class_id:
#                 continue
#             xc, yc, bw, bh = map(float, parts[1:5])
#             xc, yc, bw, bh = xc * img_width, yc * img_height, bw * img_width, bh * img_height
#             boxes.append([xc - bw / 2, yc - bh / 2, xc + bw / 2, yc + bh / 2])
#     return np.array(boxes, dtype=np.float32)


# def format_prompt_id(exemplar_indices: list) -> str:
#     """
#     Single box (Exp3)   -> "5"
#     Multiple boxes (Exp1/Exp2) -> "5+12+3"  (anchor first, then the sampled others,
#     order preserved so you can always tell which one was the anchor: it's the
#     first number in the string)
#     """
#     return "+".join(str(i) for i in exemplar_indices)

# # ---- Resume support: now keyed on (image_ID, Prompt_ID) instead of (image_ID, Bbox_ID) ----
# done_keys = set()
# file_exists = os.path.exists(OUTPUT_CSV)
# if file_exists:
#     existing = pd.read_csv(OUTPUT_CSV)
#     existing = existing[existing["experiment_name"] == EXPERIMENT_NAME]
#     done_keys = set(zip(existing["image_ID"], existing["Prompt_ID"].astype(str)))
#     print(f"Resuming: {len(done_keys)} rows already done for {EXPERIMENT_NAME}.")

# csv_file = open(OUTPUT_CSV, "a", newline="")
# csv_writer = csv.DictWriter(csv_file, fieldnames=CSV_COLUMNS)
# if not file_exists:
#     csv_writer.writeheader()

# start_time = time.time()
# n_runs = 0

# for folder, image_path, label_path, image_id in image_records:
#     if label_path is None:
#         continue

#     image = Image.open(image_path).convert("RGB")
#     img_w, img_h = image.size
#     gt_boxes = load_yolo_boxes(label_path, img_w, img_h, class_id=RUMEX_CLASS_ID)
#     n_gt = len(gt_boxes)
#     if n_gt == 0:
#         continue

#     for anchor_idx in range(n_gt):
#         exemplar_indices = select_exemplar_indices(n_gt, anchor_idx, N_EXEMPLARS, RNG)
#         prompt_id = format_prompt_id(exemplar_indices)

#         if (image_id, prompt_id) in done_keys:
#             continue  # already computed in a previous run, skip

#         exemplar_crops = [image.crop([int(round(v)) for v in gt_boxes[i]]) for i in exemplar_indices]

#         final_boxes, final_scores, final_masks = run_sam3_pipeline(
#             image, exemplar_crops, use_tiling=USE_TILING,
#             tile_size=TILE_SIZE, overlap=OVERLAP, threshold=THRESHOLD,
#         )

#         metrics = compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold=IOU_THRESHOLD)

#         row = {
#             "experiment_name": EXPERIMENT_NAME,
#             "image_ID": image_id,
#             "Prompt_ID": prompt_id,
#             "Prompt_Type": PROMPT_TYPE,
#             "mAP50": metrics["map50"],
#             "precision": metrics["precision"],
#             "recall": metrics["recall"],
#             "IoU1": metrics["iou_matched"],
#             "IoU2": metrics["iou_all_gt"],
#         }
#         csv_writer.writerow(row)
#         csv_file.flush()
#         n_runs += 1

#         if n_runs % 20 == 0:
#             elapsed = time.time() - start_time
#             print(f"[{EXPERIMENT_NAME}] {n_runs} runs done | image={image_id} | "
#                   f"prompt={prompt_id} | mAP50={metrics['map50']:.3f} | "
#                   f"elapsed={elapsed/60:.1f} min")

#         torch.cuda.empty_cache()

# csv_file.close()
# print(f"Finished {EXPERIMENT_NAME}: {n_runs} new rows written to {OUTPUT_CSV}")

# %%
# ============================================================
# CELL: Main automated loop -- Exp × Image × Anchor Bbox -> CSV
# Now with per-image logging (time per image + running ETA)
# ============================================================

# ---- Resume support ----
done_keys = set()
file_exists = os.path.exists(OUTPUT_CSV)
if file_exists:
    existing = pd.read_csv(OUTPUT_CSV)
    existing = existing[existing["experiment_name"] == EXPERIMENT_NAME]
    done_keys = set(zip(existing["image_ID"], existing["anchor_idx"].astype(int)))
    print(f"Resuming: {len(done_keys)} rows already done for {EXPERIMENT_NAME}.")

csv_file = open(OUTPUT_CSV, "a", newline="")
csv_writer = csv.DictWriter(csv_file, fieldnames=CSV_COLUMNS)
if not file_exists:
    csv_writer.writeheader()

start_time = time.time()
n_runs = 0
image_times = []  # store seconds-per-image, for the running ETA

# Only count images that actually have labels, so the ETA denominator is accurate
valid_images = [rec for rec in image_records if rec[2] is not None]
n_total_images = len(valid_images)

for img_idx, (folder, image_path, label_path, image_id) in enumerate(valid_images, start=1):
    image_t0 = time.time()

    image = Image.open(image_path).convert("RGB")
    img_w, img_h = image.size
    gt_boxes = load_yolo_boxes(label_path, img_w, img_h, class_id=RUMEX_CLASS_ID)
    n_gt = len(gt_boxes)

    if n_gt == 0:
        print(f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id}: 0 GT boxes, skipped.")
        continue

    image_map50s = []  # collect this image's mAP50 values for a quick per-image summary

    for anchor_idx in range(n_gt):

        #any anchor whose row already exists in csv gets skipped in a fraction of a second (no SAM3 call, no RNG draw)
        if (image_id, anchor_idx) in done_keys:
              continue  # skip BEFORE touching RNG at all

        run_t0 = time.time()

        exemplar_indices = select_exemplar_indices(n_gt, anchor_idx, N_EXEMPLARS, image_id)
        prompt_id = format_prompt_id(exemplar_indices)

        exemplar_crops = [image.crop([int(round(v)) for v in gt_boxes[i]]) for i in exemplar_indices]

        final_boxes, final_scores, final_masks = run_sam3_pipeline(
            image, exemplar_crops, use_tiling=USE_TILING,
            tile_size=TILE_SIZE, overlap=OVERLAP, threshold=THRESHOLD,
        )

        metrics = compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold=IOU_THRESHOLD)
        image_map50s.append(metrics["map50"])

        row = {
          "experiment_name": EXPERIMENT_NAME,
          "image_ID": image_id,
          "anchor_idx": anchor_idx,
          "Prompt_ID": prompt_id,
          "Prompt_Type": PROMPT_TYPE,
          "mAP50": metrics["map50"],
          "precision": metrics["precision"],
          "recall": metrics["recall"],
          "IoU1": metrics["iou_matched"],
          "IoU2": metrics["iou_all_gt"],
      }
        csv_writer.writerow(row)
        csv_file.flush()
        n_runs += 1

        # explicitly drop large objects before next iteration
        del final_boxes, final_scores, final_masks, exemplar_crops
        gc.collect()
        torch.cuda.empty_cache()

        run_elapsed = time.time() - run_t0
        print(
            f"    [{EXPERIMENT_NAME}] run #{n_runs} | image={image_id} | "
            f"anchor={anchor_idx} ({anchor_idx+1}/{n_gt}) | prompt_id={prompt_id} | "
            f"mAP50={metrics['map50']:.3f} | time={run_elapsed:.1f}s"
        )

        torch.cuda.empty_cache()

    # ---- Per-image log: prints once this image's anchors are all done ----
    image_elapsed = time.time() - image_t0
    image_times.append(image_elapsed)
    avg_time_per_image = np.mean(image_times)
    images_left = n_total_images - img_idx
    eta_seconds = images_left * avg_time_per_image

    map50_str = f"{np.mean(image_map50s):.3f}" if image_map50s else "N/A (all anchors already done, skipped)"

    print(
        f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id} done | "
        f"{n_gt} GT box(es) | image_mAP50_mean={map50_str} | "
        f"time={image_elapsed:.1f}s | avg/image={avg_time_per_image:.1f}s | "
        f"ETA={eta_seconds/60:.1f} min ({eta_seconds/3600:.2f} h)"
    )

csv_file.close()
total_elapsed = time.time() - start_time
print(f"\nFinished {EXPERIMENT_NAME}: {n_runs} new rows written to {OUTPUT_CSV}")
print(f"Total time: {total_elapsed/60:.1f} min ({total_elapsed/3600:.2f} h)")
# Out:
# Resuming: 1770 rows already done for E02_2.
# [E02_2] (1/179) 20220513_Halden/DJI_20220513075116_0213 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.2s | avg/image=4.2s | ETA=12.5 min (0.21 h)
# [E02_2] (2/179) 20220513_Halden/DJI_20220513075207_0234 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.3s | avg/image=3.7s | ETA=11.1 min (0.18 h)
# [E02_2] (3/179) 20220513_Halden/DJI_20220513075336_0270 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.2s | avg/image=3.9s | ETA=11.4 min (0.19 h)
# [E02_2] (4/179) 20220513_Halden/DJI_20220513075432_0295 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.5s | avg/image=3.8s | ETA=11.1 min (0.19 h)
# [E02_2] (5/179) 20220513_Halden/DJI_20220513075444_0300 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.1s | avg/image=3.7s | ETA=10.6 min (0.18 h)
# [E02_2] (6/179) 20220513_Halden/DJI_20220513075506_0309 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=3.5s | ETA=10.1 min (0.17 h)
# [E02_2] (7/179) 20220513_Halden/DJI_20220513075707_0358 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.2s | avg/image=3.6s | ETA=10.3 min (0.17 h)
# [E02_2] (8/179) 20220513_Halden/DJI_20220513075753_0379 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.6s | ETA=10.3 min (0.17 h)
# [E02_2] (9/179) 20220513_Halden/DJI_20220513075822_0391 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.1s | avg/image=3.6s | ETA=10.1 min (0.17 h)
# [E02_2] (10/179) 20220513_Halden/DJI_20220513075916_0413 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.1s | avg/image=3.6s | ETA=10.2 min (0.17 h)
# [E02_2] (11/179) 20220701_Halden/DJI_20220701165417_0004 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=3.5s | ETA=9.9 min (0.17 h)
# [E02_2] (12/179) 20220701_Halden/DJI_20220701170828_0136: 0 GT boxes, skipped.
# [E02_2] (13/179) 20220701_Halden/DJI_20220701170852_0151 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.6s | ETA=9.9 min (0.17 h)
# [E02_2] (14/179) 20220701_Halden/DJI_20220701170908_0161 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.6s | ETA=9.9 min (0.16 h)
# [E02_2] (15/179) 20220701_Halden/DJI_20220701170934_0178: 0 GT boxes, skipped.
# [E02_2] (16/179) 20220701_Halden/DJI_20220701170943_0185: 0 GT boxes, skipped.
# [E02_2] (17/179) 20220701_Halden/DJI_20220701170957_0193: 0 GT boxes, skipped.
# [E02_2] (18/179) 20220701_Halden/DJI_20220701171012_0203: 0 GT boxes, skipped.
# [E02_2] (19/179) 20220701_Halden/DJI_20220701171049_0225: 0 GT boxes, skipped.
# [E02_2] (20/179) 20220701_Halden/DJI_20220701171150_0238 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.3s | avg/image=3.6s | ETA=9.5 min (0.16 h)
# [E02_2] (21/179) 20220701_Waldegg/DJI_20220701173416_0008 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.6s | ETA=9.4 min (0.16 h)
# [E02_2] (22/179) 20220701_Waldegg/DJI_20220701173429_0016: 0 GT boxes, skipped.
# [E02_2] (23/179) 20220701_Waldegg/DJI_20220701173552_0032: 0 GT boxes, skipped.
# [E02_2] (24/179) 20220701_Waldegg/DJI_20220701173614_0046 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.6s | ETA=9.3 min (0.15 h)
# [E02_2] (25/179) 20220701_Waldegg/DJI_20220701173639_0062 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.6s | ETA=9.1 min (0.15 h)
# [E02_2] (26/179) 20220701_Waldegg/DJI_20220701173702_0076: 0 GT boxes, skipped.
# [E02_2] (27/179) 20220701_Waldegg/DJI_20220701173741_0100 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=3.5s | ETA=8.9 min (0.15 h)
# [E02_2] (28/179) 20220701_Waldegg/DJI_20220701173746_0103 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.4s | avg/image=3.5s | ETA=8.8 min (0.15 h)
# [E02_2] (29/179) 20220701_Waldegg/DJI_20220701174049_0215 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=5.2s | avg/image=3.6s | ETA=9.0 min (0.15 h)
# [E02_2] (30/179) 20220701_Waldegg/DJI_20220701174249_0292: 0 GT boxes, skipped.
# [E02_2] (31/179) 20220708_Herrenpuent/DJI_20220708152335_0016: 0 GT boxes, skipped.
# [E02_2] (32/179) 20220708_Herrenpuent/DJI_20220708152405_0036: 0 GT boxes, skipped.
# [E02_2] (33/179) 20220708_Herrenpuent/DJI_20220708152423_0047: 0 GT boxes, skipped.
# [E02_2] (34/179) 20220708_Herrenpuent/DJI_20220708152437_0056: 0 GT boxes, skipped.
# [E02_2] (35/179) 20220708_Herrenpuent/DJI_20220708152505_0073 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.1s | avg/image=3.6s | ETA=8.6 min (0.14 h)
# [E02_2] (36/179) 20220708_Herrenpuent/DJI_20220708152528_0087: 0 GT boxes, skipped.
# [E02_2] (37/179) 20220708_Herrenpuent/DJI_20220708152551_0102 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.2s | avg/image=3.5s | ETA=8.4 min (0.14 h)
# [E02_2] (38/179) 20220708_Herrenpuent/DJI_20220708152616_0112: 0 GT boxes, skipped.
# [E02_2] (39/179) 20220708_Herrenpuent/DJI_20220708152637_0125 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.2s | avg/image=3.5s | ETA=8.2 min (0.14 h)
# [E02_2] (40/179) 20220708_Herrenpuent/DJI_20220708152738_0164 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.6s | ETA=8.2 min (0.14 h)
# [E02_2] (41/179) 20220902_Herrenpuent/DJI_20220902101510_0137 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=3.5s | ETA=8.1 min (0.13 h)
# [E02_2] (42/179) 20220902_Herrenpuent/DJI_20220902102152_0354: 0 GT boxes, skipped.
# [E02_2] (43/179) 20220902_Herrenpuent/DJI_20220902102227_0374 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.5s | ETA=7.9 min (0.13 h)
# [E02_2] (44/179) 20220902_Herrenpuent/DJI_20220902102331_0408 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.5s | ETA=7.9 min (0.13 h)
# [E02_2] (45/179) 20220902_Herrenpuent/DJI_20220902102358_0423 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=3.5s | ETA=7.8 min (0.13 h)
# [E02_2] (46/179) 20220902_Herrenpuent/DJI_20220902102502_0458 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=3.4s | ETA=7.6 min (0.13 h)
# [E02_2] (47/179) 20220902_Herrenpuent/DJI_20220902102606_0492 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.1s | avg/image=3.4s | ETA=7.5 min (0.13 h)
# [E02_2] (48/179) 20220902_Herrenpuent/DJI_20220902102721_0533 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=3.4s | ETA=7.4 min (0.12 h)
# [E02_2] (49/179) 20220902_Herrenpuent/DJI_20220902103027_0633 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.4s | ETA=7.4 min (0.12 h)
# [E02_2] (50/179) 20220902_Herrenpuent/DJI_20220902103325_0729 done | 21 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=3.4s | ETA=7.3 min (0.12 h)
# [E02_2] (51/179) 20221010_HaldenNord/DJI_20221010151043_0001 done | 9 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.1s | avg/image=3.4s | ETA=7.3 min (0.12 h)
# [E02_2] (52/179) 20221010_HaldenNord/DJI_20221010151055_0012 done | 13 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.4s | ETA=7.2 min (0.12 h)
# [E02_2] (53/179) 20221010_HaldenNord/DJI_20221010151239_0115 done | 18 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.4s | ETA=7.2 min (0.12 h)
# [E02_2] (54/179) 20221010_HaldenNord/DJI_20221010151341_0176 done | 14 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.3s | avg/image=3.4s | ETA=7.1 min (0.12 h)
# [E02_2] (55/179) 20221010_HaldenNord/DJI_20221010151406_0200 done | 23 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.4s | ETA=7.1 min (0.12 h)
# [E02_2] (56/179) 20221010_HaldenNord/DJI_20221010151502_0255 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.4s | ETA=7.0 min (0.12 h)
# [E02_2] (57/179) 20221010_HaldenNord/DJI_20221010151556_0309 done | 11 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=3.4s | ETA=6.9 min (0.12 h)
# [E02_2] (58/179) 20221010_HaldenNord/DJI_20221010151812_0443 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.5s | avg/image=3.4s | ETA=6.9 min (0.11 h)
# [E02_2] (59/179) 20221010_HaldenNord/DJI_20221010151951_0542 done | 25 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.9s | avg/image=3.4s | ETA=6.8 min (0.11 h)
# [E02_2] (60/179) 20221010_HaldenNord/DJI_20221010152133_0643 done | 7 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.4s | ETA=6.8 min (0.11 h)
# [E02_2] (61/179) 20221010_HaldenNord/DJI_20221010152627_0933 done | 16 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.3s | avg/image=3.4s | ETA=6.7 min (0.11 h)
# [E02_2] (62/179) 20221010_HaldenNord/DJI_20221010152733_0996 done | 48 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.4s | avg/image=3.4s | ETA=6.7 min (0.11 h)
# [E02_2] (63/179) 20221010_HaldenSued/DJI_20221010142742_0010 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.4s | ETA=6.6 min (0.11 h)
# [E02_2] (64/179) 20221010_HaldenSued/DJI_20221010142813_0041 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.4s | ETA=6.6 min (0.11 h)
# [E02_2] (65/179) 20221010_HaldenSued/DJI_20221010142858_0086 done | 14 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.2s | avg/image=3.4s | ETA=6.5 min (0.11 h)
# [E02_2] (66/179) 20221010_HaldenSued/DJI_20221010142928_0116 done | 63 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.4s | ETA=6.5 min (0.11 h)
# [E02_2] (67/179) 20221010_HaldenSued/DJI_20221010143006_0154 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=3.4s | ETA=6.4 min (0.11 h)
# [E02_2] (68/179) 20221010_HaldenSued/DJI_20221010143033_0181 done | 8 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=3.4s | ETA=6.3 min (0.10 h)
# [E02_2] (69/179) 20221010_HaldenSued/DJI_20221010143151_0259 done | 25 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.4s | ETA=6.2 min (0.10 h)
# [E02_2] (70/179) 20221010_HaldenSued/DJI_20221010143311_0338 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.4s | ETA=6.2 min (0.10 h)
# [E02_2] (71/179) 20221010_HaldenSued/DJI_20221010143419_0406 done | 24 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.4s | avg/image=3.4s | ETA=6.1 min (0.10 h)
# [E02_2] (72/179) 20221010_HaldenSued/DJI_20221010143733_0598 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=3.4s | ETA=6.0 min (0.10 h)
# [E02_2] (73/179) 20230329_Herrenpuent/DJI_20230329152152_0001: 0 GT boxes, skipped.
# [E02_2] (74/179) 20230329_Herrenpuent/DJI_20230329152212_0019 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.1s | avg/image=3.4s | ETA=6.0 min (0.10 h)
# [E02_2] (75/179) 20230329_Herrenpuent/DJI_20230329152251_0054 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.5s | avg/image=3.4s | ETA=5.9 min (0.10 h)
# [E02_2] (76/179) 20230329_Herrenpuent/DJI_20230329152312_0072 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=5.1s | avg/image=3.4s | ETA=5.9 min (0.10 h)
# [E02_2] (77/179) 20230329_Herrenpuent/DJI_20230329152322_0082 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=3.4s | ETA=5.8 min (0.10 h)
# [E02_2] (78/179) 20230329_Herrenpuent/DJI_20230329152400_0108: 0 GT boxes, skipped.
# [E02_2] (79/179) 20230329_Herrenpuent/DJI_20230329152408_0114 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.7s | avg/image=3.4s | ETA=5.7 min (0.10 h)
# [E02_2] (80/179) 20230329_Herrenpuent/DJI_20230329152432_0130 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.4s | ETA=5.7 min (0.09 h)
# [E02_2] (81/179) 20230329_Herrenpuent/DJI_20230329152440_0135 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.5s | avg/image=3.4s | ETA=5.6 min (0.09 h)
# [E02_2] (82/179) 20230329_Herrenpuent/DJI_20230329152449_0141: 0 GT boxes, skipped.
# [E02_2] (83/179) 20230329_Herrenpuent/DJI_20230329152524_0164 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.1s | avg/image=3.5s | ETA=5.5 min (0.09 h)
# [E02_2] (84/179) 20230329_Herrenpuent/DJI_20230329152551_0180 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=3.4s | ETA=5.5 min (0.09 h)
# [E02_2] (85/179) 20230329_Herrenpuent/DJI_20230329152603_0188 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.1s | avg/image=3.4s | ETA=5.4 min (0.09 h)
# [E02_2] (86/179) 20230329_Herrenpuent/DJI_20230329152642_0214 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.4s | ETA=5.3 min (0.09 h)
# [E02_2] (87/179) 20230426_Wallenwil/DJI_20230426110736_0035 done | 57 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.4s | ETA=5.3 min (0.09 h)
# [E02_2] (88/179) 20230426_Wallenwil/DJI_20230426110807_0053 done | 84 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.3s | avg/image=3.5s | ETA=5.2 min (0.09 h)
# [E02_2] (89/179) 20230426_Wallenwil/DJI_20230426110820_0061 done | 105 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.5s | ETA=5.2 min (0.09 h)
# [E02_2] (90/179) 20230426_Wallenwil/DJI_20230426110838_0071 done | 51 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.5s | ETA=5.1 min (0.09 h)
# [E02_2] (91/179) 20230426_Wallenwil/DJI_20230426110844_0075 done | 49 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.5s | ETA=5.1 min (0.08 h)
# [E02_2] (92/179) 20230426_Wallenwil/DJI_20230426110857_0082 done | 65 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.1s | avg/image=3.5s | ETA=5.0 min (0.08 h)
# [E02_2] (93/179) 20230426_Wallenwil/DJI_20230426111205_0193 done | 48 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.9s | avg/image=3.5s | ETA=5.0 min (0.08 h)
# [E02_2] (94/179) 20230426_Wallenwil/DJI_20230426111219_0201 done | 66 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.6s | avg/image=3.5s | ETA=5.0 min (0.08 h)
# [E02_2] (95/179) 20230426_Wallenwil/DJI_20230426111258_0224 done | 55 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.5s | ETA=4.9 min (0.08 h)
# [E02_2] (96/179) 20230426_Wallenwil/DJI_20230426111402_0261: 0 GT boxes, skipped.
# [E02_2] (97/179) 20230727_Mythen/DJI_20230727103845_0001 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.1s | avg/image=3.5s | ETA=4.8 min (0.08 h)
# [E02_2] (98/179) 20230727_Mythen/DJI_20230727103933_0028 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.3s | avg/image=3.5s | ETA=4.7 min (0.08 h)
# [E02_2] (99/179) 20230727_Mythen/DJI_20230727103949_0037 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.5s | ETA=4.7 min (0.08 h)
# [E02_2] (100/179) 20230727_Mythen/DJI_20230727103957_0042 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.9s | avg/image=3.5s | ETA=4.6 min (0.08 h)
# [E02_2] (101/179) 20230727_Mythen/DJI_20230727104013_0051 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.2s | avg/image=3.5s | ETA=4.6 min (0.08 h)
# [E02_2] (102/179) 20230727_Mythen/DJI_20230727104031_0061 done | 9 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.5s | avg/image=3.5s | ETA=4.5 min (0.08 h)
# [E02_2] (103/179) 20230727_Mythen/DJI_20230727104147_0103 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.5s | ETA=4.5 min (0.07 h)
# [E02_2] (104/179) 20230727_Mythen/DJI_20230727104429_0193 done | 10 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.5s | ETA=4.4 min (0.07 h)
# [E02_2] (105/179) 20230727_Mythen/DJI_20230727104721_0289 done | 24 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=3.5s | ETA=4.4 min (0.07 h)
# [E02_2] (106/179) 20230727_Mythen/DJI_20230727105113_0418 done | 10 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=3.5s | ETA=4.3 min (0.07 h)
# [E02_2] (107/179) 20230727_Mythen/DJI_20230727105344_0502 done | 15 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.5s | ETA=4.2 min (0.07 h)
# [E02_2] (108/179) 20230727_Mythen/DJI_20230727105523_0558 done | 49 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.3s | avg/image=3.5s | ETA=4.2 min (0.07 h)
# [E02_2] (109/179) 20230823_Stanserhorn/DJI_20230823100806_0012 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.2s | avg/image=3.5s | ETA=4.1 min (0.07 h)
# [E02_2] (110/179) 20230823_Stanserhorn/DJI_20230823100915_0050: 0 GT boxes, skipped.
# [E02_2] (111/179) 20230823_Stanserhorn/DJI_20230823101006_0078: 0 GT boxes, skipped.
# [E02_2] (112/179) 20230823_Stanserhorn/DJI_20230823101050_0102 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.9s | avg/image=3.5s | ETA=3.9 min (0.07 h)
# [E02_2] (113/179) 20230823_Stanserhorn/DJI_20230823101117_0117 done | 15 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.4s | avg/image=3.5s | ETA=3.9 min (0.06 h)
# [E02_2] (114/179) 20230823_Stanserhorn/DJI_20230823101203_0143 done | 16 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.3s | avg/image=3.5s | ETA=3.8 min (0.06 h)
# [E02_2] (115/179) 20230823_Stanserhorn/DJI_20230823101225_0155 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=3.5s | ETA=3.7 min (0.06 h)
# [E02_2] (116/179) 20230823_Stanserhorn/DJI_20230823101406_0211 done | 10 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.5s | ETA=3.7 min (0.06 h)
# [E02_2] (117/179) 20230823_Stanserhorn/DJI_20230823101525_0255 done | 88 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.5s | ETA=3.6 min (0.06 h)
# [E02_2] (118/179) 20230823_Stanserhorn/DJI_20230823101631_0291 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.3s | avg/image=3.5s | ETA=3.6 min (0.06 h)
# [E02_2] (119/179) 20230823_Stanserhorn/DJI_20230823101756_0338 done | 12 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.5s | ETA=3.5 min (0.06 h)
# [E02_2] (120/179) 20230823_Stanserhorn/DJI_20230823101851_0369 done | 11 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.9s | avg/image=3.5s | ETA=3.5 min (0.06 h)
# [E02_2] (121/179) 20230823_Stanserhorn/DJI_20230823101931_0391 done | 18 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.5s | ETA=3.4 min (0.06 h)
# [E02_2] (122/179) 20230823_Stanserhorn/DJI_20230823102120_0452 done | 27 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.0s | avg/image=3.5s | ETA=3.3 min (0.06 h)
# [E02_2] (123/179) 20230927_Napf/DJI_20230927110610_0005: 0 GT boxes, skipped.
# [E02_2] (124/179) 20230927_Napf/DJI_20230927110649_0025: 0 GT boxes, skipped.
# [E02_2] (125/179) 20230927_Napf/DJI_20230927111334_0251: 0 GT boxes, skipped.
# [E02_2] (126/179) 20230927_Napf/DJI_20230927111542_0322: 0 GT boxes, skipped.
# [E02_2] (127/179) 20230927_Napf/DJI_20230927111831_0413: 0 GT boxes, skipped.
# [E02_2] (128/179) 20230927_Napf/DJI_20230927112042_0485: 0 GT boxes, skipped.
# [E02_2] (129/179) 20230927_Napf/DJI_20230927112355_0593: 0 GT boxes, skipped.
# [E02_2] (130/179) 20230927_Napf/DJI_20230927112830_0746: 0 GT boxes, skipped.
# [E02_2] (131/179) 20230927_Napf/DJI_20230927113037_0818: 0 GT boxes, skipped.
# [E02_2] (132/179) 20230927_Napf/DJI_20230927113732_0026: 0 GT boxes, skipped.
# [E02_2] (133/179) 20230927_Napf/DJI_20230927113848_0070: 0 GT boxes, skipped.
# [E02_2] (134/179) 20230927_Napf/DJI_20230927114118_0153: 0 GT boxes, skipped.
# [E02_2] (135/179) 20230927_Napf/DJI_20230927114221_0188: 0 GT boxes, skipped.
# [E02_2] (136/179) 20231026_Herrenpuent/DJI_20231026142132_0002 done | 8 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=3.5s | ETA=2.5 min (0.04 h)
# [E02_2] (137/179) 20231026_Herrenpuent/DJI_20231026142138_0003 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=3.5s | ETA=2.5 min (0.04 h)
# [E02_2] (138/179) 20231026_Herrenpuent/DJI_20231026142150_0005 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=3.5s | ETA=2.4 min (0.04 h)
# [E02_2] (139/179) 20231026_Herrenpuent/DJI_20231026142155_0006 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.9s | avg/image=3.5s | ETA=2.3 min (0.04 h)
# [E02_2] (140/179) 20231026_Herrenpuent/DJI_20231026142207_0008 done | 7 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.2s | avg/image=3.5s | ETA=2.3 min (0.04 h)
# [E02_2] (141/179) 20231026_Herrenpuent/DJI_20231026142212_0009 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=3.5s | ETA=2.2 min (0.04 h)
# [E02_2] (142/179) 20231026_Herrenpuent/DJI_20231026142229_0012 done | 7 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.7s | avg/image=3.5s | ETA=2.1 min (0.04 h)
# [E02_2] (143/179) 20231026_Herrenpuent/DJI_20231026142241_0014 done | 34 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.5s | ETA=2.1 min (0.03 h)
# [E02_2] (144/179) 20231026_Herrenpuent/DJI_20231026142258_0017 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.9s | avg/image=3.5s | ETA=2.0 min (0.03 h)
# [E02_2] (145/179) 20231026_Herrenpuent/DJI_20231026142335_0024: 0 GT boxes, skipped.
# [E02_2] (146/179) 20231026_Herrenpuent/DJI_20231026142343_0026: 0 GT boxes, skipped.
# [E02_2] (147/179) 20231026_Herrenpuent/DJI_20231026142408_0031: 0 GT boxes, skipped.
# [E02_2] (148/179) 20231026_Herrenpuent/DJI_20231026142551_0049: 0 GT boxes, skipped.
# [E02_2] (149/179) 20231026_Herrenpuent/DJI_20231026142602_0053 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.5s | ETA=1.7 min (0.03 h)
# [E02_2] (150/179) 20231026_Herrenpuent/DJI_20231026142627_0058: 0 GT boxes, skipped.
# [E02_2] (151/179) 20231026_Herrenpuent/DJI_20231026143002_0099: 0 GT boxes, skipped.
# [E02_2] (152/179) 20231026_Herrenpuent/DJI_20231026143030_0104: 0 GT boxes, skipped.
# [E02_2] (153/179) 20231030_Ruedimoos/DJI_20231030101656_0005 done | 21 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.3s | avg/image=3.5s | ETA=1.5 min (0.03 h)
# [E02_2] (154/179) 20231030_Ruedimoos/DJI_20231030101857_0026 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.2s | avg/image=3.5s | ETA=1.4 min (0.02 h)
# [E02_2] (155/179) 20231030_Ruedimoos/DJI_20231030101949_0036 done | 27 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=3.5s | ETA=1.4 min (0.02 h)
# [E02_2] (156/179) 20231030_Ruedimoos/DJI_20231030102051_0048 done | 43 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.2s | avg/image=3.4s | ETA=1.3 min (0.02 h)
# [E02_2] (157/179) 20231030_Ruedimoos/DJI_20231030102153_0059 done | 16 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=3.4s | ETA=1.3 min (0.02 h)
# [E02_2] (158/179) 20231030_Ruedimoos/DJI_20231030102306_0073 done | 7 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.6s | avg/image=3.4s | ETA=1.2 min (0.02 h)
# [E02_2] (159/179) 20231030_Ruedimoos/DJI_20231030102402_0084 done | 23 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.9s | avg/image=3.4s | ETA=1.1 min (0.02 h)
# [E02_2] (160/179) 20231030_Ruedimoos/DJI_20231030102505_0095 done | 23 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.0s | avg/image=3.4s | ETA=1.1 min (0.02 h)
# [E02_2] (161/179) 20231030_Ruedimoos/DJI_20231030102727_0122 done | 29 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.2s | avg/image=3.4s | ETA=1.0 min (0.02 h)
# [E02_2] (162/179) 20231030_Ruedimoos/DJI_20231030102910_0140 done | 55 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.0s | avg/image=3.4s | ETA=1.0 min (0.02 h)
# [E02_2] (163/179) 20241203_Loehre/DJI_20241203150604_0010 done | 14 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=3.4s | ETA=0.9 min (0.02 h)
# [E02_2] (164/179) 20241203_Loehre/DJI_20241203150637_0028 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.4s | ETA=0.8 min (0.01 h)
# [E02_2] (165/179) 20241203_Loehre/DJI_20241203150725_0055 done | 7 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.4s | ETA=0.8 min (0.01 h)
# [E02_2] (166/179) 20241203_Loehre/DJI_20241203150750_0069 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=4.8s | avg/image=3.4s | ETA=0.7 min (0.01 h)
# [E02_2] (167/179) 20241203_Loehre/DJI_20241203150821_0086 done | 10 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=3.4s | ETA=0.7 min (0.01 h)
# [E02_2] (168/179) 20241203_Loehre/DJI_20241203150837_0095 done | 10 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.4s | avg/image=3.4s | ETA=0.6 min (0.01 h)
# DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#     [E02_2] run #1 | image=20241203_Loehre/DJI_20241203150935_0127 | anchor=3 (4/4) | prompt_id=3+1+2 | mAP50=0.000 | time=181.0s
# [E02_2] (169/179) 20241203_Loehre/DJI_20241203150935_0127 done | 4 GT box(es) | image_mAP50_mean=0.000 | time=184.6s | avg/image=4.8s | ETA=0.8 min (0.01 h)
#     [E02_2] run #2 | image=20241203_Loehre/DJI_20241203151004_0143 | anchor=0 (1/5) | prompt_id=0+3+1 | mAP50=0.249 | time=177.3s
#     [E02_2] run #3 | image=20241203_Loehre/DJI_20241203151004_0143 | anchor=1 (2/5) | prompt_id=1+4+0 | mAP50=0.244 | time=177.7s
#     [E02_2] run #4 | image=20241203_Loehre/DJI_20241203151004_0143 | anchor=2 (3/5) | prompt_id=2+4+0 | mAP50=0.019 | time=178.0s
#     [E02_2] run #5 | image=20241203_Loehre/DJI_20241203151004_0143 | anchor=3 (4/5) | prompt_id=3+1+2 | mAP50=0.406 | time=176.7s
#     [E02_2] run #6 | image=20241203_Loehre/DJI_20241203151004_0143 | anchor=4 (5/5) | prompt_id=4+3+2 | mAP50=0.030 | time=179.2s
# [E02_2] (170/179) 20241203_Loehre/DJI_20241203151004_0143 done | 5 GT box(es) | image_mAP50_mean=0.189 | time=892.9s | avg/image=11.8s | ETA=1.8 min (0.03 h)
#     [E02_2] run #7 | image=20241203_Loehre/DJI_20241203151029_0158 | anchor=0 (1/7) | prompt_id=0+6+2 | mAP50=0.213 | time=177.1s
#     [E02_2] run #8 | image=20241203_Loehre/DJI_20241203151029_0158 | anchor=1 (2/7) | prompt_id=1+4+3 | mAP50=0.389 | time=176.6s
#     [E02_2] run #9 | image=20241203_Loehre/DJI_20241203151029_0158 | anchor=2 (3/7) | prompt_id=2+1+3 | mAP50=0.355 | time=176.3s
#     [E02_2] run #10 | image=20241203_Loehre/DJI_20241203151029_0158 | anchor=3 (4/7) | prompt_id=3+1+0 | mAP50=0.196 | time=176.7s
#     [E02_2] run #11 | image=20241203_Loehre/DJI_20241203151029_0158 | anchor=4 (5/7) | prompt_id=4+2+0 | mAP50=0.293 | time=176.7s
#     [E02_2] run #12 | image=20241203_Loehre/DJI_20241203151029_0158 | anchor=5 (6/7) | prompt_id=5+2+1 | mAP50=0.193 | time=176.7s
#     [E02_2] run #13 | image=20241203_Loehre/DJI_20241203151029_0158 | anchor=6 (7/7) | prompt_id=6+0+4 | mAP50=0.128 | time=176.8s
# [E02_2] (171/179) 20241203_Loehre/DJI_20241203151029_0158 done | 7 GT box(es) | image_mAP50_mean=0.252 | time=1240.7s | avg/image=21.4s | ETA=2.9 min (0.05 h)
#     [E02_2] run #14 | image=20241203_Loehre/DJI_20241203151101_0176 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.027 | time=178.6s
# [E02_2] (172/179) 20241203_Loehre/DJI_20241203151101_0176 done | 1 GT box(es) | image_mAP50_mean=0.027 | time=182.6s | avg/image=22.7s | ETA=2.6 min (0.04 h)
#     [E02_2] run #15 | image=20241203_Loehre/DJI_20241203151115_0184 | anchor=0 (1/2) | prompt_id=0+1 | mAP50=1.000 | time=177.4s
#     [E02_2] run #16 | image=20241203_Loehre/DJI_20241203151115_0184 | anchor=1 (2/2) | prompt_id=1+0 | mAP50=0.703 | time=177.9s
# [E02_2] (173/179) 20241203_Loehre/DJI_20241203151115_0184 done | 2 GT box(es) | image_mAP50_mean=0.851 | time=358.7s | avg/image=25.3s | ETA=2.5 min (0.04 h)
#     [E02_2] run #17 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=0 (1/8) | prompt_id=0+7+6 | mAP50=0.118 | time=178.1s
#     [E02_2] run #18 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=1 (2/8) | prompt_id=1+4+5 | mAP50=0.390 | time=177.9s
#     [E02_2] run #19 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=2 (3/8) | prompt_id=2+5+1 | mAP50=0.274 | time=176.9s
#     [E02_2] run #20 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=3 (4/8) | prompt_id=3+6+7 | mAP50=0.228 | time=177.5s
#     [E02_2] run #21 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=4 (5/8) | prompt_id=4+7+5 | mAP50=0.438 | time=177.4s
#     [E02_2] run #22 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=5 (6/8) | prompt_id=5+0+2 | mAP50=0.329 | time=176.9s
#     [E02_2] run #23 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=6 (7/8) | prompt_id=6+0+7 | mAP50=0.230 | time=177.5s
#     [E02_2] run #24 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=7 (8/8) | prompt_id=7+4+0 | mAP50=0.433 | time=177.3s
# [E02_2] (174/179) 20241203_Loehre/DJI_20241203151132_0193 done | 8 GT box(es) | image_mAP50_mean=0.305 | time=1425.8s | avg/image=36.0s | ETA=3.0 min (0.05 h)
#     [E02_2] run #25 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=0 (1/9) | prompt_id=0+7+6 | mAP50=0.203 | time=177.0s
#     [E02_2] run #26 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=1 (2/9) | prompt_id=1+6+8 | mAP50=0.059 | time=178.3s
#     [E02_2] run #27 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=2 (3/9) | prompt_id=2+5+7 | mAP50=0.023 | time=177.8s
#     [E02_2] run #28 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=3 (4/9) | prompt_id=3+7+6 | mAP50=0.153 | time=177.8s
#     [E02_2] run #29 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=4 (5/9) | prompt_id=4+0+2 | mAP50=0.006 | time=178.1s
#     [E02_2] run #30 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=5 (6/9) | prompt_id=5+3+8 | mAP50=0.039 | time=177.4s
#     [E02_2] run #31 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=6 (7/9) | prompt_id=6+2+3 | mAP50=0.169 | time=176.6s
#     [E02_2] run #32 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=7 (8/9) | prompt_id=7+3+4 | mAP50=0.016 | time=177.4s
#     [E02_2] run #33 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=8 (9/9) | prompt_id=8+1+4 | mAP50=0.000 | time=179.8s
# [E02_2] (175/179) 20241203_Loehre/DJI_20241203151209_0214 done | 9 GT box(es) | image_mAP50_mean=0.074 | time=1604.5s | avg/image=47.8s | ETA=3.2 min (0.05 h)
#     [E02_2] run #34 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=0 (1/18) | prompt_id=0+14+13 | mAP50=0.220 | time=177.3s
#     [E02_2] run #35 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=1 (2/18) | prompt_id=1+3+12 | mAP50=0.065 | time=177.6s
#     [E02_2] run #36 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=2 (3/18) | prompt_id=2+11+10 | mAP50=0.204 | time=176.9s
#     [E02_2] run #37 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=3 (4/18) | prompt_id=3+6+8 | mAP50=0.215 | time=177.9s
#     [E02_2] run #38 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=4 (5/18) | prompt_id=4+7+6 | mAP50=0.346 | time=176.6s
#     [E02_2] run #39 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=5 (6/18) | prompt_id=5+0+4 | mAP50=0.272 | time=177.1s
#     [E02_2] run #40 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=6 (7/18) | prompt_id=6+4+11 | mAP50=0.236 | time=176.7s
#     [E02_2] run #41 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=7 (8/18) | prompt_id=7+5+4 | mAP50=0.140 | time=177.5s
#     [E02_2] run #42 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=8 (9/18) | prompt_id=8+3+0 | mAP50=0.223 | time=177.3s
#     [E02_2] run #43 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=9 (10/18) | prompt_id=9+1+14 | mAP50=0.376 | time=176.4s
#     [E02_2] run #44 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=10 (11/18) | prompt_id=10+11+1 | mAP50=0.311 | time=176.7s
#     [E02_2] run #45 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=11 (12/18) | prompt_id=11+7+8 | mAP50=0.267 | time=176.4s
#     [E02_2] run #46 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=12 (13/18) | prompt_id=12+8+13 | mAP50=0.247 | time=176.7s
#     [E02_2] run #47 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=13 (14/18) | prompt_id=13+7+12 | mAP50=0.167 | time=177.1s
#     [E02_2] run #48 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=14 (15/18) | prompt_id=14+2+11 | mAP50=0.279 | time=177.1s
#     [E02_2] run #49 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=15 (16/18) | prompt_id=15+5+17 | mAP50=0.158 | time=177.2s
#     [E02_2] run #50 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=16 (17/18) | prompt_id=16+3+5 | mAP50=0.169 | time=177.4s
#     [E02_2] run #51 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=17 (18/18) | prompt_id=17+15+4 | mAP50=0.282 | time=177.1s
# [E02_2] (176/179) 20241203_Loehre/DJI_20241203151245_0234 done | 18 GT box(es) | image_mAP50_mean=0.232 | time=3191.0s | avg/image=71.5s | ETA=3.6 min (0.06 h)
#     [E02_2] run #52 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=0 (1/10) | prompt_id=0+6+3 | mAP50=0.348 | time=177.5s
#     [E02_2] run #53 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=1 (2/10) | prompt_id=1+3+5 | mAP50=0.362 | time=177.5s
#     [E02_2] run #54 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=2 (3/10) | prompt_id=2+5+7 | mAP50=0.210 | time=178.0s
#     [E02_2] run #55 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=3 (4/10) | prompt_id=3+6+4 | mAP50=0.171 | time=177.0s
#     [E02_2] run #56 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=4 (5/10) | prompt_id=4+9+2 | mAP50=0.439 | time=177.1s
#     [E02_2] run #57 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=5 (6/10) | prompt_id=5+1+9 | mAP50=0.227 | time=177.4s
#     [E02_2] run #58 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=6 (7/10) | prompt_id=6+7+4 | mAP50=0.151 | time=177.3s
#     [E02_2] run #59 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=7 (8/10) | prompt_id=7+2+9 | mAP50=0.306 | time=177.4s
#     [E02_2] run #60 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=8 (9/10) | prompt_id=8+9+3 | mAP50=0.512 | time=176.6s
#     [E02_2] run #61 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=9 (10/10) | prompt_id=9+6+8 | mAP50=0.201 | time=176.9s
# [E02_2] (177/179) 20241203_Loehre/DJI_20241203151314_0250 done | 10 GT box(es) | image_mAP50_mean=0.293 | time=1776.7s | avg/image=84.2s | ETA=2.8 min (0.05 h)
#     [E02_2] run #62 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=0 (1/9) | prompt_id=0+3+8 | mAP50=0.337 | time=177.1s
#     [E02_2] run #63 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=1 (2/9) | prompt_id=1+3+5 | mAP50=0.337 | time=178.0s
#     [E02_2] run #64 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=2 (3/9) | prompt_id=2+6+7 | mAP50=0.024 | time=178.0s
#     [E02_2] run #65 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=3 (4/9) | prompt_id=3+5+2 | mAP50=0.346 | time=177.5s
#     [E02_2] run #66 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=4 (5/9) | prompt_id=4+6+3 | mAP50=0.357 | time=176.7s
#     [E02_2] run #67 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=5 (6/9) | prompt_id=5+6+8 | mAP50=0.274 | time=177.4s
#     [E02_2] run #68 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=6 (7/9) | prompt_id=6+0+1 | mAP50=0.368 | time=176.0s
#     [E02_2] run #69 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=7 (8/9) | prompt_id=7+4+0 | mAP50=0.241 | time=177.4s
#     [E02_2] run #70 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=8 (9/9) | prompt_id=8+3+2 | mAP50=0.217 | time=176.5s
# [E02_2] (178/179) 20241203_Loehre/DJI_20241203151419_0286 done | 9 GT box(es) | image_mAP50_mean=0.278 | time=1598.2s | avg/image=95.4s | ETA=1.6 min (0.03 h)
#     [E02_2] run #71 | image=20241203_Loehre/DJI_20241203151524_0321 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.000 | time=177.5s
# [E02_2] (179/179) 20241203_Loehre/DJI_20241203151524_0321 done | 1 GT box(es) | image_mAP50_mean=0.000 | time=181.3s | avg/image=96.0s | ETA=0.0 min (0.00 h)
#
# Finished E02_2: 71 new rows written to /content/drive/MyDrive/master_thesis/results/results_E02_2.csv
# Total time: 219.9 min (3.66 h)

# %%
# # Aggregate statistics -- mean + std of mAP50 per experiment
# # Run this AFTER all 3 experiments' CSVs have been produced, pointing
# # ALL_RESULTS_CSVS at each experiment's output file.
# ALL_RESULTS_CSVS = [
#     "/content/drive/MyDrive/results/results_E02_2.csv",
#     # "/content/drive/MyDrive/datasets/AGS_Multi_Rumex/results_<exp2_name>.csv",
#     # "/content/drive/MyDrive/datasets/AGS_Multi_Rumex/results_<exp3_name>.csv",
# ]

# dfs = [pd.read_csv(p) for p in ALL_RESULTS_CSVS if os.path.exists(p)]
# full_df = pd.concat(dfs, ignore_index=True)
# print(f"Loaded {len(full_df)} total rows across {full_df['experiment_name'].nunique()} experiment(s).")

# summary = full_df.groupby("experiment_name").agg(
#     n_runs=("mAP50", "count"),
#     mAP50_mean=("mAP50", "mean"),
#     mAP50_std=("mAP50", "std"),
#     precision_mean=("precision", "mean"),
#     precision_std=("precision", "std"),
#     recall_mean=("recall", "mean"),
#     recall_std=("recall", "std"),
#     IoU1_mean=("IoU1", "mean"),
#     IoU2_mean=("IoU2", "mean"),
# ).reset_index()

# print(summary.to_string(index=False))
# summary.to_csv("/content/drive/MyDrive/results/summary_all_experiments.csv", index=False)

# %%
# import pandas as pd

# EXPERIMENT_NAME = "E02_2"
# OUTPUT_CSV = f"/content/drive/MyDrive/master_thesis/results/results_{EXPERIMENT_NAME}.csv"

# df = pd.read_csv(OUTPUT_CSV)
# print(f"Rows before: {len(df)}")

# target_image_id = "20230426_Wallenwil/DJI_20230426111258_0224"
# target_anchors = [33, 34]

# # Show what matches, before deleting anything
# mask = (
#     (df["experiment_name"] == EXPERIMENT_NAME) &
#     (df["image_ID"] == target_image_id) &
#     (df["anchor_idx"].astype(int).isin(target_anchors))
# )
# print(f"Matching rows found: {mask.sum()}")
# print(df[mask])

# %%
# # Keep only the FIRST occurrence of each (image_ID, anchor_idx) pair among the matches,
# # drop any later duplicates (the accidental rerun rows)
# df_clean = pd.concat([
#     df[~mask],
#     df[mask].drop_duplicates(subset=["experiment_name", "image_ID", "anchor_idx"], keep="first")
# ]).sort_index()
# df_clean.to_csv(OUTPUT_CSV, index=False)
# print(f"Rows after: {len(df_clean)}")

# %%
def has_rumex_annotation(label_path, class_id=0):
    if label_path is None:
        return False
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if parts and int(parts[0]) == class_id:
                return True
    return False

annotated_count = sum(1 for _, _, label_path, _ in image_records if has_rumex_annotation(label_path, RUMEX_CLASS_ID))
unannotated_count = len(image_records) - annotated_count

print(f"Total images:      {len(image_records)}")
print(f"Annotated:         {annotated_count}")
print(f"Unannotated:       {unannotated_count}")
# Out:
# Total images:      179
# Annotated:         136
# Unannotated:       43

# %%
#  Aggregate statistics for ONE experiment (run separately per experiment)
import pandas as pd
import numpy as np
import os

#  Change this single line for each experiment
EXPERIMENT_CSV = "/content/drive/MyDrive/master_thesis/results/results_E02_2.csv"
OUTPUT_DIR = "/content/drive/MyDrive/results/"
os.makedirs(OUTPUT_DIR, exist_ok=True)  # just in case it doesn't exist yet

assert os.path.exists(EXPERIMENT_CSV), f"File not found: {EXPERIMENT_CSV}"
df = pd.read_csv(EXPERIMENT_CSV)

exp_name = df["experiment_name"].iloc[0]
print(f"Experiment: {exp_name}")
print(f"Total rows (image x prompt runs): {len(df)}")
print(f"Number of distinct images: {df['image_ID'].nunique()}")
# Out:
# Experiment: E02_2
# Total rows (image x prompt runs): 1841
# Number of distinct images: 136

# %%
#  Raw per-run stats (every row = one image + one prompt set, independent observation)
# Here, every row in our CSV is treated as one independent experiment.
#output 1 value per metric (produces one overall mean and one overall std for each metric)
raw_summary = df.agg(
    n_runs=("mAP50", "count"),
    mAP50_mean=("mAP50", "mean"),
    mAP50_std=("mAP50", "std"),
    precision_mean=("precision", "mean"),
    precision_std=("precision", "std"),
    recall_mean=("recall", "mean"),
    recall_std=("recall", "std"),
    IoU1_mean=("IoU1", "mean"),
    IoU1_std=("IoU1", "std"),
    IoU2_mean=("IoU2", "mean"),
    IoU2_std=("IoU2", "std"),
)

raw_summary.to_csv(os.path.join(OUTPUT_DIR, f"image_level_{exp_name}.csv"), index=False)
print(f"Saved raw_summary_{exp_name}.csv to {OUTPUT_DIR}")

print(f"=== {exp_name} -- raw per-run summary (all rows independent) ===")
print(raw_summary)
# Out:
# Saved raw_summary_E02_2.csv to /content/drive/MyDrive/results/
# === E02_2 -- raw per-run summary (all rows independent) ===
#                       mAP50  precision    recall      IoU1      IoU2
# n_runs          1841.000000        NaN       NaN       NaN       NaN
# mAP50_mean         0.235910        NaN       NaN       NaN       NaN
# mAP50_std          0.154667        NaN       NaN       NaN       NaN
# precision_mean          NaN   0.157294       NaN       NaN       NaN
# precision_std           NaN   0.088179       NaN       NaN       NaN
# recall_mean             NaN        NaN  0.566406       NaN       NaN
# recall_std              NaN        NaN  0.191659       NaN       NaN
# IoU1_mean               NaN        NaN       NaN  0.768590       NaN
# IoU1_std                NaN        NaN       NaN  0.107279       NaN
# IoU2_mean               NaN        NaN       NaN       NaN  0.443888
# IoU2_std                NaN        NaN       NaN       NaN  0.158330

# %%
# Image-level stats (collapse multiple prompt runs per image to one value first,
# so images with more GT boxes / more prompt sets don't dominate the average)
image_level = ( # produces one mean value per image for each metric
    df.groupby("image_ID")
    .agg(
        mAP50_image_mean=("mAP50", "mean"),
        precision_image_mean=("precision", "mean"),
        recall_image_mean=("recall", "mean"),
        IoU1_image_mean=("IoU1", "mean"),
        IoU2_image_mean=("IoU2", "mean"),
        n_prompts=("mAP50", "count"),
    )
    .reset_index()
)
image_level.to_csv(os.path.join(OUTPUT_DIR, f"image_level_{exp_name}.csv"), index=False)
print(f"Saved image_level{exp_name}.csv to {OUTPUT_DIR}")

print(f"=== {exp_name} -- image-level results ({len(image_level)} images) ===")
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    print(image_level.to_string(index=False))
# Out:
# Saved image_levelE02_2.csv to /content/drive/MyDrive/results/
# === E02_2 -- image-level results (136 images) ===
#                                     image_ID  mAP50_image_mean  precision_image_mean  recall_image_mean  IoU1_image_mean  IoU2_image_mean  n_prompts
#      20220513_Halden/DJI_20220513075116_0213          0.500000              0.200000           1.000000         0.809795         0.809795          1
#      20220513_Halden/DJI_20220513075207_0234          0.834983              0.022634           1.000000         0.845720         0.845720          2
#      20220513_Halden/DJI_20220513075336_0270          0.651861              0.061650           0.777778         0.866044         0.673344          6
#      20220513_Halden/DJI_20220513075432_0295          0.350935              0.086940           0.555556         0.791104         0.444967          3
#      20220513_Halden/DJI_20220513075444_0300          0.673809              0.036972           1.000000         0.692496         0.692496          3
#      20220513_Halden/DJI_20220513075506_0309          0.500000              0.500000           1.000000         0.718549         0.718549          1
#      20220513_Halden/DJI_20220513075707_0358          0.000000              0.000000           0.000000         0.000000         0.000000          1
#      20220513_Halden/DJI_20220513075753_0379          0.621322              0.120445           0.875000         0.877706         0.768328          4
#      20220513_Halden/DJI_20220513075822_0391          0.488044              0.093759           0.760000         0.843785         0.644363          5
#      20220513_Halden/DJI_20220513075916_0413          0.000000              0.000000           0.000000         0.000000         0.000000          1
#      20220701_Halden/DJI_20220701165417_0004          0.047821              0.009303           1.000000         0.754677         0.754677          2
#      20220701_Halden/DJI_20220701170852_0151          0.000000              0.000000           0.000000         0.000000         0.000000          2
#      20220701_Halden/DJI_20220701170908_0161          0.000000              0.000000           0.000000         0.000000         0.000000          1
#      20220701_Halden/DJI_20220701171150_0238          0.547394              0.043522           1.000000         0.860464         0.860464          3
#     20220701_Waldegg/DJI_20220701173416_0008          0.210396              0.005803           0.500000         0.791174         0.395587          2
#     20220701_Waldegg/DJI_20220701173614_0046          0.000000              0.000000           0.000000         0.000000         0.000000          1
#     20220701_Waldegg/DJI_20220701173639_0062          0.250000              0.008929           1.000000         0.892807         0.892807          1
#     20220701_Waldegg/DJI_20220701173741_0100          0.281377              0.018274           1.000000         0.760127         0.760127          3
#     20220701_Waldegg/DJI_20220701173746_0103          0.834983              0.011240           1.000000         0.889770         0.889770          2
#     20220701_Waldegg/DJI_20220701174049_0215          0.000000              0.000000           0.000000         0.000000         0.000000          1
# 20220708_Herrenpuent/DJI_20220708152505_0073          0.313820              0.111264           0.800000         0.827883         0.662306          5
# 20220708_Herrenpuent/DJI_20220708152551_0102          0.100000              0.017241           1.000000         0.616207         0.616207          1
# 20220708_Herrenpuent/DJI_20220708152637_0125          0.500000              0.021739           1.000000         0.548415         0.548415          1
# 20220708_Herrenpuent/DJI_20220708152738_0164          0.000000              0.003106           0.250000         0.256448         0.128224          2
# 20220902_Herrenpuent/DJI_20220902101510_0137          1.000000              0.062500           1.000000         0.793155         0.793155          1
# 20220902_Herrenpuent/DJI_20220902102227_0374          0.518152              0.147009           0.666667         0.822897         0.548598          3
# 20220902_Herrenpuent/DJI_20220902102331_0408          0.000000              0.000000           0.000000         0.000000         0.000000          1
# 20220902_Herrenpuent/DJI_20220902102358_0423          0.461221              0.026515           0.750000         0.877206         0.635819          2
# 20220902_Herrenpuent/DJI_20220902102502_0458          0.000000              0.000000           0.000000         0.000000         0.000000          2
# 20220902_Herrenpuent/DJI_20220902102606_0492          0.462046              0.146520           0.666667         0.825903         0.550602          3
# 20220902_Herrenpuent/DJI_20220902102721_0533          0.303190              0.084541           0.666667         0.840013         0.560009          3
# 20220902_Herrenpuent/DJI_20220902103027_0633          1.000000              0.100000           1.000000         0.795173         0.795173          1
# 20220902_Herrenpuent/DJI_20220902103325_0729          0.279487              0.186682           0.560091         0.840864         0.474357         21
#  20221010_HaldenNord/DJI_20221010151043_0001          0.270557              0.069893           0.580247         0.808967         0.465361          9
#  20221010_HaldenNord/DJI_20221010151055_0012          0.199097              0.040157           0.532544         0.855449         0.455289         13
#  20221010_HaldenNord/DJI_20221010151239_0115          0.202354              0.098451           0.484568         0.825597         0.400485         18
#  20221010_HaldenNord/DJI_20221010151341_0176          0.412783              0.212546           0.581633         0.881504         0.511836         14
#  20221010_HaldenNord/DJI_20221010151406_0200          0.424747              0.255118           0.731569         0.820922         0.599780         23
#  20221010_HaldenNord/DJI_20221010151502_0255          0.337461              0.157829           0.640000         0.797050         0.510429          5
#  20221010_HaldenNord/DJI_20221010151556_0309          0.055277              0.052255           0.181818         0.652017         0.165535         11
#  20221010_HaldenNord/DJI_20221010151812_0443          0.027866              0.014896           0.750000         0.805352         0.590120          2
#  20221010_HaldenNord/DJI_20221010151951_0542          0.214643              0.123492           0.465600         0.857311         0.397693         25
#  20221010_HaldenNord/DJI_20221010152133_0643          0.159842              0.041236           0.551020         0.769598         0.421602          7
#  20221010_HaldenNord/DJI_20221010152627_0933          0.139030              0.095864           0.480469         0.829149         0.398315         16
#  20221010_HaldenNord/DJI_20221010152733_0996          0.125234              0.156019           0.424913         0.837271         0.357608         48
#  20221010_HaldenSued/DJI_20221010142742_0010          0.291814              0.170009           0.562500         0.871346         0.486718          4
#  20221010_HaldenSued/DJI_20221010142813_0041          0.141165              0.040070           0.562500         0.707654         0.398835          4
#  20221010_HaldenSued/DJI_20221010142858_0086          0.385573              0.125851           0.637755         0.832609         0.531363         14
#  20221010_HaldenSued/DJI_20221010142928_0116          0.262152              0.198766           0.605694         0.770210         0.466414         63
#  20221010_HaldenSued/DJI_20221010143006_0154          0.147935              0.090200           0.527778         0.776361         0.408914          6
#  20221010_HaldenSued/DJI_20221010143033_0181          0.044421              0.037053           0.218750         0.594557         0.149021          8
#  20221010_HaldenSued/DJI_20221010143151_0259          0.196454              0.207813           0.398400         0.769089         0.307417         25
#  20221010_HaldenSued/DJI_20221010143311_0338          1.000000              0.392857           1.000000         0.773243         0.773243          2
#  20221010_HaldenSued/DJI_20221010143419_0406          0.211081              0.156356           0.407986         0.742556         0.302487         24
#  20221010_HaldenSued/DJI_20221010143733_0598          0.371700              0.064820           0.388889         0.802122         0.309977          6
# 20230329_Herrenpuent/DJI_20230329152212_0019          1.000000              0.200000           1.000000         0.883993         0.883993          2
# 20230329_Herrenpuent/DJI_20230329152251_0054          1.000000              0.125490           1.000000         0.887368         0.887368          2
# 20230329_Herrenpuent/DJI_20230329152312_0072          0.950495              0.357236           1.000000         0.889281         0.889281          4
# 20230329_Herrenpuent/DJI_20230329152322_0082          0.149615              0.016996           0.333333         0.743112         0.247704          3
# 20230329_Herrenpuent/DJI_20230329152408_0114          0.474540              0.088932           1.000000         0.891812         0.891812          3
# 20230329_Herrenpuent/DJI_20230329152432_0130          1.000000              0.090909           1.000000         0.920962         0.920962          1
# 20230329_Herrenpuent/DJI_20230329152440_0135          1.000000              0.100000           1.000000         0.950406         0.950406          1
# 20230329_Herrenpuent/DJI_20230329152524_0164          0.608911              0.087398           0.666667         0.856445         0.570963          3
# 20230329_Herrenpuent/DJI_20230329152551_0180          0.702970              0.190909           1.000000         0.795399         0.795399          2
# 20230329_Herrenpuent/DJI_20230329152603_0188          1.000000              0.194444           1.000000         0.959900         0.959900          2
# 20230329_Herrenpuent/DJI_20230329152642_0214          0.750825              0.194444           1.000000         0.779149         0.779149          2
#   20230426_Wallenwil/DJI_20230426110736_0035          0.294713              0.224048           0.679594         0.800452         0.544374         57
#   20230426_Wallenwil/DJI_20230426110807_0053          0.178516              0.206685           0.561933         0.812934         0.456290         84
#   20230426_Wallenwil/DJI_20230426110820_0061          0.113139              0.172059           0.584127         0.780149         0.456029        105
#   20230426_Wallenwil/DJI_20230426110838_0071          0.249551              0.173892           0.640907         0.802378         0.513506         51
#   20230426_Wallenwil/DJI_20230426110844_0075          0.332813              0.205184           0.703457         0.799818         0.562906         49
#   20230426_Wallenwil/DJI_20230426110857_0082          0.200283              0.186587           0.660118         0.805874         0.531161         65
#   20230426_Wallenwil/DJI_20230426111205_0193          0.240826              0.207968           0.686198         0.782971         0.537632         48
#   20230426_Wallenwil/DJI_20230426111219_0201          0.295612              0.211400           0.750918         0.760911         0.571060         66
#   20230426_Wallenwil/DJI_20230426111258_0224          0.214412              0.185638           0.716364         0.763930         0.547265         55
#      20230727_Mythen/DJI_20230727103845_0001          0.000000              0.000000           0.000000         0.000000         0.000000          2
#      20230727_Mythen/DJI_20230727103933_0028          0.092692              0.036630           0.750000         0.686299         0.549994          2
#      20230727_Mythen/DJI_20230727103949_0037          0.000000              0.000000           0.000000         0.000000         0.000000          3
#      20230727_Mythen/DJI_20230727103957_0042          0.405941              0.068434           0.400000         0.768705         0.307482          5
#      20230727_Mythen/DJI_20230727104013_0051          0.043643              0.008099           0.187500         0.296175         0.108909          4
#      20230727_Mythen/DJI_20230727104031_0061          0.076642              0.025176           0.506173         0.797457         0.403420          9
#      20230727_Mythen/DJI_20230727104147_0103          0.688315              0.107322           0.833333         0.793359         0.661133          6
#      20230727_Mythen/DJI_20230727104429_0193          0.184485              0.039774           0.390000         0.794772         0.301634         10
#      20230727_Mythen/DJI_20230727104721_0289          0.119742              0.142783           0.291667         0.755647         0.220701         24
#      20230727_Mythen/DJI_20230727105113_0418          0.132918              0.045865           0.310000         0.725145         0.218292         10
#      20230727_Mythen/DJI_20230727105344_0502          0.182155              0.080900           0.475556         0.746865         0.356136         15
#      20230727_Mythen/DJI_20230727105523_0558          0.211809              0.176714           0.519367         0.741262         0.384553         49
# 20230823_Stanserhorn/DJI_20230823100806_0012          0.579549              0.017145           0.750000         0.885516         0.664137          4
# 20230823_Stanserhorn/DJI_20230823101050_0102          0.238592              0.076649           0.777778         0.876441         0.682518          6
# 20230823_Stanserhorn/DJI_20230823101117_0117          0.285281              0.079211           0.591111         0.784161         0.464490         15
# 20230823_Stanserhorn/DJI_20230823101203_0143          0.427913              0.173727           0.742188         0.779969         0.581023         16
# 20230823_Stanserhorn/DJI_20230823101225_0155          0.887789              0.179762           0.888889         0.784532         0.690092          3
# 20230823_Stanserhorn/DJI_20230823101406_0211          0.418303              0.089989           0.840000         0.778675         0.653470         10
# 20230823_Stanserhorn/DJI_20230823101525_0255          0.232619              0.224896           0.656508         0.759840         0.498876         88
# 20230823_Stanserhorn/DJI_20230823101631_0291          0.585809              0.036018           0.750000         0.799411         0.576453          2
# 20230823_Stanserhorn/DJI_20230823101756_0338          0.249162              0.053153           0.625000         0.721534         0.451977         12
# 20230823_Stanserhorn/DJI_20230823101851_0369          0.235820              0.077196           0.743802         0.835859         0.621721         11
# 20230823_Stanserhorn/DJI_20230823101931_0391          0.241218              0.117388           0.555556         0.789830         0.438447         18
# 20230823_Stanserhorn/DJI_20230823102120_0452          0.081171              0.129669           0.353909         0.705626         0.253545         27
# 20231026_Herrenpuent/DJI_20231026142132_0002          0.301652              0.094899           0.875000         0.787208         0.685207          8
# 20231026_Herrenpuent/DJI_20231026142138_0003          0.534798              0.017091           1.000000         0.891034         0.891034          2
# 20231026_Herrenpuent/DJI_20231026142150_0005          0.098479              0.041667           0.500000         0.365676         0.365676          2
# 20231026_Herrenpuent/DJI_20231026142155_0006          1.000000              0.016129           1.000000         0.925496         0.925496          1
# 20231026_Herrenpuent/DJI_20231026142207_0008          0.579300              0.121809           0.734694         0.748363         0.549431          7
# 20231026_Herrenpuent/DJI_20231026142212_0009          0.322772              0.044657           0.400000         0.773105         0.309242          5
# 20231026_Herrenpuent/DJI_20231026142229_0012          0.216982              0.052169           0.489796         0.699845         0.355945          7
# 20231026_Herrenpuent/DJI_20231026142241_0014          0.182678              0.099158           0.512976         0.711388         0.364984         34
# 20231026_Herrenpuent/DJI_20231026142258_0017          0.362183              0.053686           0.625000         0.907295         0.561035          4
# 20231026_Herrenpuent/DJI_20231026142602_0053          0.000000              0.000000           0.000000         0.000000         0.000000          1
#   20231030_Ruedimoos/DJI_20231030101656_0005          0.225366              0.224858           0.396825         0.673145         0.270018         21
#   20231030_Ruedimoos/DJI_20231030101857_0026          0.404822              0.176507           0.638889         0.724093         0.462893          6
#   20231030_Ruedimoos/DJI_20231030101949_0036          0.116298              0.154238           0.432099         0.744500         0.319754         27
#   20231030_Ruedimoos/DJI_20231030102051_0048          0.139767              0.238165           0.376420         0.725853         0.277585         43
#   20231030_Ruedimoos/DJI_20231030102153_0059          0.140879              0.067416           0.339844         0.780457         0.263650         16
#   20231030_Ruedimoos/DJI_20231030102306_0073          0.225507              0.081551           0.632653         0.738684         0.466022          7
#   20231030_Ruedimoos/DJI_20231030102402_0084          0.329236              0.183759           0.584121         0.726287         0.424232         23
#   20231030_Ruedimoos/DJI_20231030102505_0095          0.119684              0.154803           0.357278         0.675631         0.240850         23
#   20231030_Ruedimoos/DJI_20231030102727_0122          0.210530              0.206366           0.472057         0.782422         0.368513         29
#   20231030_Ruedimoos/DJI_20231030102910_0140          0.128062              0.171361           0.450909         0.762160         0.342502         55
#      20241203_Loehre/DJI_20241203150604_0010          0.177897              0.114833           0.500000         0.766887         0.382525         14
#      20241203_Loehre/DJI_20241203150637_0028          0.464416              0.168595           0.760000         0.764162         0.578625          5
#      20241203_Loehre/DJI_20241203150725_0055          0.178339              0.078024           0.265306         0.602613         0.162322          7
#      20241203_Loehre/DJI_20241203150750_0069          0.062644              0.030429           0.277778         0.760162         0.204193          6
#      20241203_Loehre/DJI_20241203150821_0086          0.073021              0.052636           0.400000         0.718044         0.299099         10
#      20241203_Loehre/DJI_20241203150837_0095          0.292991              0.092194           0.640000         0.806079         0.516440         10
#      20241203_Loehre/DJI_20241203150935_0127          0.091584              0.044321           0.250000         0.569755         0.190050          4
#      20241203_Loehre/DJI_20241203151004_0143          0.189472              0.090554           0.360000         0.816461         0.294667          5
#      20241203_Loehre/DJI_20241203151029_0158          0.252372              0.191787           0.489796         0.790278         0.390506          7
#      20241203_Loehre/DJI_20241203151101_0176          0.027027              0.005682           1.000000         0.833498         0.833498          1
#      20241203_Loehre/DJI_20241203151115_0184          0.851485              0.105556           1.000000         0.743593         0.743593          2
#      20241203_Loehre/DJI_20241203151132_0193          0.305041              0.084804           0.671875         0.718667         0.482652          8
#      20241203_Loehre/DJI_20241203151209_0214          0.074230              0.039454           0.283951         0.750411         0.208292          9
#      20241203_Loehre/DJI_20241203151245_0234          0.232143              0.145884           0.444444         0.776428         0.344613         18
#      20241203_Loehre/DJI_20241203151314_0250          0.292643              0.110293           0.540000         0.820581         0.441058         10
#      20241203_Loehre/DJI_20241203151419_0286          0.277845              0.118707           0.358025         0.851274         0.303242          9
#      20241203_Loehre/DJI_20241203151524_0321          0.000000              0.000000           0.000000         0.000000         0.000000          1

# %%
image_level_summary = pd.DataFrame({
    "experiment_name": [exp_name],
    "n_images": [image_level["image_ID"].nunique()],
    "mAP50_mean": [image_level["mAP50_image_mean"].mean()],
    "mAP50_std": [image_level["mAP50_image_mean"].std()],
    "precision_mean": [image_level["precision_image_mean"].mean()],
    "precision_std": [image_level["precision_image_mean"].std()],
    "recall_mean": [image_level["recall_image_mean"].mean()],
    "recall_std": [image_level["recall_image_mean"].std()],
    "IoU1_mean": [image_level["IoU1_image_mean"].mean()],
    "IoU2_mean": [image_level["IoU2_image_mean"].mean()],
})

image_level_summary.to_csv(os.path.join(OUTPUT_DIR, f"summary_{exp_name}.csv"), index=False)
print(f"\nSaved image_level_{exp_name}.csv and summary_{exp_name}.csv to {OUTPUT_DIR}")

print(f"\n=== {exp_name} -- image-level summary ===")
print(image_level_summary.to_string(index=False))
# Out:
# Saved image_level_E02_2.csv and summary_E02_2.csv to /content/drive/MyDrive/results/
#
# === E02_2 -- image-level summary ===
# experiment_name  n_images  mAP50_mean  mAP50_std  precision_mean  precision_std  recall_mean  recall_std  IoU1_mean  IoU2_mean
#           E02_2       136    0.324948   0.276836        0.103007       0.085297     0.592094    0.294281   0.708266   0.472632
