# %% [markdown]
# <a href="https://colab.research.google.com/github/ghadirchhade/Master-Thesis/blob/main/baseline1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %%
# !pip install -q torch torchvision

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.11.0+cu128
# Torchvision version: 0.26.0+cu128
# CUDA is available: True

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# facebook/sam3 is gated on the Hub -> you must accept the license at
# https://huggingface.co/facebook/sam3 with the account whose token you use below.
# !pip install -q -U transformers accelerate huggingface_hub supervision

from huggingface_hub import login
login()  # paste your HF token (needs access to facebook/sam3)

print("Transformers SAM3 dependencies installed.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 112.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 780.4/780.4 kB 56.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.2/280.2 kB 27.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 11.0 MB/s eta 0:00:00
# Transformers SAM3 dependencies installed.

# %%
import os, glob, csv, time
import numpy as np
import pandas as pd
import gc
import torch
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import supervision as sv
import matplotlib.patches as patches
from transformers import Sam3Model, Sam3Processor

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

sam3_model = Sam3Model.from_pretrained("facebook/sam3", device_map="auto")
sam3_model.eval()

sam3_processor = Sam3Processor.from_pretrained("facebook/sam3")

print("HF transformers SAM3 model + processor loaded.")
print("Model device:", next(sam3_model.parameters()).device)
# Out:
# config.json:   0%|          | 0.00/25.8k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.44GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/1468 [00:00<?, ?it/s]
# processor_config.json:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]
# HF transformers SAM3 model + processor loaded.
# Model device: cuda:0

# %%
IMAGES_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/images"
LABELS_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/annotations_yolo"
RUMEX_CLASS_ID = 0

# %%
#Experiment identity (CHANGE THESE 3 LINES PER EXPERIMENT)
EXPERIMENT_NAME = "E02_2"   # e.g. "E02_2" (Exp1), "<exp2_name>", "<exp3_name>"
N_EXEMPLARS     = 3         # 3 for Exp1/Exp2, 1 for Exp3
USE_TILING      = True      # True for Exp1/Exp3, False for Exp2

# SAM3 / tiling params (reuse Exp1's values)
TILE_SIZE = 1000
OVERLAP   = 150
THRESHOLD = 0.3
IOU_THRESHOLD = 0.5

RNG = np.random.default_rng(42)  # fixed seed -> reproducible exemplar sampling

# %%
# Output CSV (append-safe: survives Colab disconnects)
OUTPUT_CSV = f"/content/drive/MyDrive/master_thesis/results/results_{EXPERIMENT_NAME}.csv"
CSV_COLUMNS = ["experiment_name", "image_ID", "anchor_idx", "Prompt_ID", "Prompt_Type", "mAP50",
               "precision", "recall", "IoU1", "IoU2"]

PROMPT_TYPE = "multiple" if N_EXEMPLARS > 1 else "single"

# %%
def load_yolo_boxes(label_path, img_width, img_height, class_id=0):
    boxes = []
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            cls = int(parts[0])
            if cls != class_id:
                continue
            xc, yc, bw, bh = map(float, parts[1:5])
            xc, yc, bw, bh = xc * img_width, yc * img_height, bw * img_width, bh * img_height
            boxes.append([xc - bw / 2, yc - bh / 2, xc + bw / 2, yc + bh / 2])
    return np.array(boxes, dtype=np.float32)

# %%
def format_prompt_id(exemplar_indices: list) -> str:
    """
    Single box (Exp3)   -> "5"
    Multiple boxes (Exp1/Exp2) -> "5+12+3"  (anchor first, then the sampled others,
    order preserved so you can always tell which one was the anchor: it's the
    first number in the string)
    """
    return "+".join(str(i) for i in exemplar_indices)

# %%
def find_label_path(image_filename_no_ext, folder_name):
    mirrored = os.path.join(LABELS_ROOT, folder_name, image_filename_no_ext + ".txt")  # <- change here if needed
    flat = os.path.join(LABELS_ROOT, image_filename_no_ext + ".txt")                    # <- and here
    if os.path.exists(mirrored):
        return mirrored
    if os.path.exists(flat):
        return flat
    return None

# %%
#Discover every image across all folders in AGS_MULTI_RUMEX
image_records = []  # (folder, image_path, label_path, image_id)
VALID_EXT = (".jpg", ".jpeg", ".png")

for folder in sorted(os.listdir(IMAGES_ROOT)):
    folder_path = os.path.join(IMAGES_ROOT, folder)
    if not os.path.isdir(folder_path):
        continue
    for fname in sorted(os.listdir(folder_path)):
        if not fname.lower().endswith(VALID_EXT):
            continue
        name_no_ext = os.path.splitext(fname)[0]
        label_path = find_label_path(name_no_ext, folder)
        image_id = f"{folder}/{name_no_ext}"
        image_records.append((folder, os.path.join(folder_path, fname), label_path, image_id))
        missing_labels = [r for r in image_records if r[2] is None]

print(f"Discovered {len(image_records)} images across {len(set(r[0] for r in image_records))} folders.")
if missing_labels:
    print(f"WARNING: {len(missing_labels)} images have no matching label file (will be skipped). "
          f"First few: {[r[3] for r in missing_labels[:5]]}")
# Out:
# Discovered 179 images across 15 folders.

# %%
# Exemplar selection (anchor + N-1 random others)
def select_exemplar_indices(n_gt: int, anchor_idx: int, n_exemplars: int, image_id: str) -> list:
    """
    Builds the exemplar index set for one run:
      - always includes the anchor box (the one this row is "about")
      - fills the rest (n_exemplars - 1 slots) with OTHER GT boxes from the
        same image, sampled without replacement
      - if the image doesn't have enough other GT boxes, just uses whatever
        is available (no duplication, no crash)
    """

    ## each GT bbox gets a chance to act as the "anchor"
    ## prompt, while the remaining exemplars are randomly sampled from the same image.
    seed = abs(hash((image_id, anchor_idx))) % (2**32)
    rng = np.random.default_rng(seed)
    others = [i for i in range(n_gt) if i != anchor_idx]
    n_others_needed = min(n_exemplars - 1, len(others))
    if n_others_needed > 0:
        chosen_others = list(rng.choice(others, size=n_others_needed, replace=False))
    else:
        chosen_others = []
    return [anchor_idx] + chosen_others

# %%
def get_local_background_patch(tile_img: Image.Image, patch_w: int, patch_h: int) -> Image.Image:
    """
    Instead of a flat white block, sample REAL texture from the tile itself to use as
    the strip's background. Why this matters:
      - Color balance, brightness, and grain automatically match this tile's own
        lighting conditions (which can vary tile-to-tile across a large drone photo).
      - There's no artificial white-vs-photo boundary for the vision transformer's
        self-attention to latch onto as a spurious "edge feature".
      - The exemplar's ROI-pooled feature (computed AFTER the image encoder has already
        mixed in neighboring context via attention) ends up looking like "a plant in
        grass" instead of "a plant in a void" -- much closer to a real target instance.

    We grab the top-left corner of the tile from target img (an area that won't be duplicated, since
    the strip sits ABOVE the tile in the final canvas, not overlapping it).
    """
    sample = tile_img.crop((0, 0, min(patch_w, tile_img.width), min(patch_h, tile_img.height)))
    if sample.size != (patch_w, patch_h):
        sample = sample.resize((patch_w, patch_h))
    return sample


def make_feather_mask(size, feather_width):
    w, h = size
    mask = np.full((h, w), 255.0, dtype=np.float32)

    effective_feather = min(feather_width, h // 2, w // 2)
    if effective_feather >= 1:
        for i in range(effective_feather):
            alpha = 255.0 * (i + 1) / effective_feather
            mask[i, :] = np.minimum(mask[i, :], alpha)
            mask[h - 1 - i, :] = np.minimum(mask[h - 1 - i, :], alpha)
            mask[:, i] = np.minimum(mask[:, i], alpha)
            mask[:, w - 1 - i] = np.minimum(mask[:, w - 1 - i], alpha)

    return Image.fromarray(mask.astype(np.uint8), mode="L")  # <-- return a PIL Image, not ndarray

# %%
def compose_tile_with_exemplars(tile_img: Image.Image, crop_images: list,
                                 margin: int = 6, feather_width: int = 8):
    """
    Builds the small composed image actually sent to SAM3, for ONE tile, with
    MULTIPLE exemplar crops placed side-by-side in a strip above the tile.

    Returns:
        composed  -- the image to feed to SAM3
        crop_boxes -- list of [x1,y1,x2,y2], one per exemplar, in composed-image coords
        offset    -- (dx, dy) to convert composed target-region coords back
                     to this TILE's own coordinate system
    """
    n = len(crop_images)
    strip_h = max(c.height for c in crop_images) + 2 * margin
    strip_content_w = sum(c.width for c in crop_images) + margin * (n + 1)
    canvas_w = max(tile_img.width, strip_content_w)
    canvas_h = strip_h + tile_img.height

    strip_bg = get_local_background_patch(tile_img, canvas_w, strip_h)

    composed = Image.new("RGB", (canvas_w, canvas_h))
    composed.paste(strip_bg, (0, 0))
    offset = (0, strip_h)
    composed.paste(tile_img, offset)

    crop_boxes = []
    cursor_x = margin
    for crop_image in crop_images:
        feather_mask = make_feather_mask(crop_image.size, feather_width=feather_width)
        paste_xy = (cursor_x, margin)
        composed.paste(crop_image, paste_xy, feather_mask)

        crop_boxes.append([
            paste_xy[0], paste_xy[1],
            paste_xy[0] + crop_image.width, paste_xy[1] + crop_image.height,
        ])
        cursor_x += crop_image.width + margin

    return composed, crop_boxes, offset

# %%
def tile_bboxes(img_w: int, img_h: int, tile_size: int, overlap: int):
    """
    Generates (x1,y1,x2,y2) windows covering the whole image, with overlap so plants
    sitting right on a tile boundary aren't missed or half-cut in every window.
    """
    step = tile_size - overlap
    tiles = []
    for y in range(0, img_h, step):
        for x in range(0, img_w, step):
            x2 = min(x + tile_size, img_w)
            y2 = min(y + tile_size, img_h)
            x1 = max(0, x2 - tile_size)
            y1 = max(0, y2 - tile_size)
            tiles.append((x1, y1, x2, y2))
    return list(dict.fromkeys(tiles))

# %%
def keep_only_target_region_detections(boxes, scores, masks, offset, y_tolerance=5):
    """
    Drop any detection sitting inside the padding strip (that's a pasted exemplar
    being re-detected, not a real find), keep only detections that fall within the
    tile's real-content region, and remap their coordinates back to that tile's own
    coordinate system (undo the paste offset).
    """
    dx, dy = offset
    kept_boxes, kept_scores, kept_masks = [], [], []

    for box, score, mask in zip(boxes, scores, masks):
        x1, y1, x2, y2 = box.tolist() if torch.is_tensor(box) else box
        if y1 >= dy - y_tolerance:
            remapped_box = [x1 - dx, max(y1 - dy, 0), x2 - dx, y2 - dy]
            kept_boxes.append(remapped_box)
            kept_scores.append(score)
            mask_np = mask.cpu().numpy() if torch.is_tensor(mask) else mask
            kept_masks.append(mask_np[dy:, dx:] if dx or dy else mask_np)

    return kept_boxes, kept_scores, kept_masks

# %%
def filter_implausible_boxes(boxes, scores, masks, tile_w, tile_h,
                              min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5):
    """
    Drops detections unlikely to be real single Rumex plants:
      - box area implausibly large relative to the tile (likely background clutter,
        not a single plant)
      - predicted mask fills too little of its own box (weak/noisy detection rather
        than a confident, well-localized instance)
      - degenerate boxes clipped to (near) zero size at the tile edges
    `edge_margin` is used to tolerate boxes that legitimately touch a tile border
    (real plants often do, since tiles overlap and neighboring tiles will pick up
    the rest of the same plant) rather than penalizing them outright.
    """
    kept_boxes, kept_scores, kept_masks = [], [], []
    tile_area = tile_w * tile_h

    for box, score, mask in zip(boxes, scores, masks):
        x1, y1, x2, y2 = box
        box_w, box_h = x2 - x1, y2 - y1
        if box_w <= edge_margin or box_h <= edge_margin:
            continue

        box_area = box_w * box_h
        if box_area / tile_area > max_area_fraction:
            continue

        mask_np = mask.cpu().numpy() if torch.is_tensor(mask) else mask
        x1c, y1c = int(max(0, x1)), int(max(0, y1))
        x2c, y2c = int(min(mask_np.shape[1], x2)), int(min(mask_np.shape[0], y2))
        if x2c <= x1c or y2c <= y1c:
            continue

        region = mask_np[y1c:y2c, x1c:x2c]
        fill_ratio = (region > 0.5).mean() if region.size > 0 else 0.0
        if fill_ratio < min_fill_ratio:
            continue

        kept_boxes.append(box)
        kept_scores.append(score)
        kept_masks.append(mask)

    return kept_boxes, kept_scores, kept_masks

# %%
def run_sam3_on_tile(composed_tile, crop_boxes, offset, text_prompt=None, threshold=0.3):
    """
    crop_boxes: list of [x1,y1,x2,y2] exemplar boxes in composed-image coords
    (one per exemplar). All are passed as positive boxes.

    text_prompt is optional. Combining a text phrase the model's text encoder doesn't
    resolve ("rumex...") with the box exemplars actively suppresses real candidate
    detections instead of reinforcing them. Default to box-exemplar-only unless
    you've validated a text phrase actually helps.
    """
    kwargs = dict(
        images=composed_tile,
        input_boxes=[[[float(c) for c in box] for box in crop_boxes]],
        input_boxes_labels=[[1] * len(crop_boxes)],
        return_tensors="pt",
    )
    if text_prompt:
        kwargs["text"] = text_prompt

    inputs = sam3_processor(**kwargs).to(sam3_model.device)
    with torch.no_grad():
        outputs = sam3_model(**inputs)

    results = sam3_processor.post_process_instance_segmentation(
        outputs, threshold=threshold, mask_threshold=0.4,
        target_sizes=inputs.get("original_sizes").tolist(),
    )[0]

    return keep_only_target_region_detections(
        results["boxes"], results["scores"], results["masks"], offset
    )

    del inputs, outputs, results  # <-- new
    return kept

# %%
def nms_merge(boxes, scores, masks, iou_thresh: float = 0.5):
    """
    Because tiles overlap, the same real plant can get detected in two neighboring
    tiles. Standard IoU-based Non-Max Suppression collapses duplicates down to the
    single highest-confidence box -- carries the matching mask through too.
    """
    if not boxes: #if there's no detections
        return [], [], [] #empty boxes,masks,scores

    boxes_t = torch.tensor(boxes, dtype=torch.float32) #convert boxes to tensots
    scores_t = torch.tensor([s.item() if torch.is_tensor(s) else s for s in scores]) #convert scores to tensor
    order = scores_t.argsort(descending=True) #highest detection confidence is processed first
    keep = [] #indices of boxes we keep

    while order.numel() > 0: #continue until  all boxes are processed
        i = order[0].item() #selected highest score box
        keep.append(i)
        if order.numel() == 1:
            break
        rest = order[1:] #the remaining boxes other than the best one
        #compute intersection coordinates (selected best box and the remaining boxes)
        xx1 = torch.maximum(boxes_t[i, 0], boxes_t[rest, 0]) #left
        yy1 = torch.maximum(boxes_t[i, 1], boxes_t[rest, 1]) #top
        xx2 = torch.minimum(boxes_t[i, 2], boxes_t[rest, 2]) #right
        yy2 = torch.minimum(boxes_t[i, 3], boxes_t[rest, 3]) #bottom
        inter = (xx2 - xx1).clamp(0) * (yy2 - yy1).clamp(0) #intersection area
        area_i = (boxes_t[i, 2] - boxes_t[i, 0]) * (boxes_t[i, 3] - boxes_t[i, 1]) #area of selected box
        #area_r: outputs a tensor with areas of all remaining boxes
        area_r = (boxes_t[rest, 2] - boxes_t[rest, 0]) * (boxes_t[rest, 3] - boxes_t[rest, 1]) #area of remaining boxes
        iou = inter / (area_i + area_r - inter + 1e-6) # n IoU values bcz area_r contains the areas of n remaining boxes
        order = rest[iou <= iou_thresh] #filtering (decision to remove duplicates)
        #filters the remaining boxes, keeping only those whose IoU with the selected box is less than or equal to the threshold.

    kept_boxes = [boxes[i] for i in keep]
    kept_scores = [scores[i] for i in keep]
    kept_masks = [masks[i] for i in keep]
    return kept_boxes, kept_scores, kept_masks

# %%
# Unified SAM3 pipeline -- tiled vs whole-image (no tiling)
# Reuses ALL the helper functions already defined from Exp1's code:
# tile_bboxes, compose_tile_with_exemplars, run_sam3_on_tile,
# filter_implausible_boxes, nms_merge, get_local_background_patch,
# make_feather_mask, keep_only_target_region_detections
# Make sure those cells have been run before this one.
def run_sam3_pipeline(image: Image.Image, exemplar_crops: list, use_tiling: bool,
                       tile_size: int = 1000, overlap: int = 150, threshold: float = 0.3):
    """
    Runs the full SAM3 detection pipeline on `image` using `exemplar_crops` as
    positive visual prompts, and returns final (boxes, scores, masks) in the
    full image's coordinate system.

    use_tiling=True  -> splits the image into overlapping tiles (Exp1/Exp3 style),
                         runs SAM3 per tile, merges duplicates with NMS.
    use_tiling=False -> single pass: exemplar strip pasted above the WHOLE image,
                         one SAM3 call, no tile-splitting, no NMS merge needed
                         (still run through nms_merge for safety/consistency,
                         it's a no-op if there's nothing to merge).
    """
    all_boxes, all_scores, all_masks = [], [], []

    if use_tiling:
        for (x1, y1, x2, y2) in tile_bboxes(image.width, image.height, tile_size, overlap):
            tile = image.crop((x1, y1, x2, y2))
            composed_tile, crop_boxes, offset = compose_tile_with_exemplars(
                tile, exemplar_crops, margin=6, feather_width=8
            )
            boxes, scores, masks = run_sam3_on_tile(
                composed_tile, crop_boxes, offset, text_prompt=None, threshold=threshold
            )
            tile_w, tile_h = x2 - x1, y2 - y1
            boxes, scores, masks = filter_implausible_boxes(
                boxes, scores, masks, tile_w, tile_h,
                min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5,
            )
            for b, s, m in zip(boxes, scores, masks):
                all_boxes.append([b[0] + x1, b[1] + y1, b[2] + x1, b[3] + y1])
                all_scores.append(s.item() if torch.is_tensor(s) else s)
                all_masks.append((m, x1, y1))
    else:
        # Whole image treated as a single "tile" the size of the full image.
        composed, crop_boxes, offset = compose_tile_with_exemplars(
            image, exemplar_crops, margin=6, feather_width=8
        )
        boxes, scores, masks = run_sam3_on_tile(
            composed, crop_boxes, offset, text_prompt=None, threshold=threshold
        )
        boxes, scores, masks = filter_implausible_boxes(
            boxes, scores, masks, image.width, image.height,
            min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5,
        )
        for b, s, m in zip(boxes, scores, masks):
            all_boxes.append([b[0], b[1], b[2], b[3]])   # offset is (0,0) here, x1=y1=0
            all_scores.append(s.item() if torch.is_tensor(s) else s)
            all_masks.append((m, 0, 0))

    final_boxes, final_scores, final_masks = nms_merge(all_boxes, all_scores, all_masks, iou_thresh=0.5)
    return final_boxes, final_scores, final_masks

# %%
# Metrics helper -- refactored from Exp1's evaluation cell
# Returns mAP50, precision, recall, IoU1 (matched-only), IoU2 (over all GT)
import supervision as sv
from supervision.metrics import MeanAveragePrecision

def compute_iou_matrix(boxes1, boxes2):
    if len(boxes1) == 0 or len(boxes2) == 0:
        return np.zeros((len(boxes1), len(boxes2)))
    x1 = np.maximum(boxes1[:, None, 0], boxes2[None, :, 0])
    y1 = np.maximum(boxes1[:, None, 1], boxes2[None, :, 1])
    x2 = np.minimum(boxes1[:, None, 2], boxes2[None, :, 2])
    y2 = np.minimum(boxes1[:, None, 3], boxes2[None, :, 3])
    inter_w = np.clip(x2 - x1, 0, None)
    inter_h = np.clip(y2 - y1, 0, None)
    inter_area = inter_w * inter_h
    area1 = (boxes1[:, 2] - boxes1[:, 0]) * (boxes1[:, 3] - boxes1[:, 1])
    area2 = (boxes2[:, 2] - boxes2[:, 0]) * (boxes2[:, 3] - boxes2[:, 1])
    union_area = area1[:, None] + area2[None, :] - inter_area
    return np.where(union_area > 0, inter_area / union_area, 0.0)


def compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold: float = 0.5) -> dict:
    """
    final_boxes/final_scores: predictions for ONE run (one image, one exemplar set)
    gt_boxes: ALL GT boxes for that image (numpy array, xyxy)
    Mirrors exactly the metric logic from Exp1's evaluation cell.
    """
    pred_boxes_np = np.array(final_boxes, dtype=np.float32) if final_boxes else np.zeros((0, 4), dtype=np.float32)
    pred_scores_np = np.array(final_scores, dtype=np.float32) if final_scores else np.zeros((0,), dtype=np.float32)

    # --- mAP50 via supervision ---
    pred_detections = sv.Detections(
        xyxy=pred_boxes_np,
        confidence=pred_scores_np,
        class_id=np.zeros(len(pred_scores_np), dtype=int),
    )
    gt_detections = sv.Detections(
        xyxy=gt_boxes,
        class_id=np.zeros(len(gt_boxes), dtype=int),
    )
    try:
        map_metric = MeanAveragePrecision()
        result = map_metric.update([pred_detections], [gt_detections]).compute()
        map50 = float(result.map50)
    except Exception:
        # supervision can raise/return NaN on degenerate cases (0 preds & 0 GT etc.)
        map50 = 0.0 if len(gt_boxes) > 0 else float("nan")

    #  precision / recall / IoU via greedy matching
    num_preds, num_gt = len(pred_boxes_np), len(gt_boxes)
    iou_matrix = compute_iou_matrix(pred_boxes_np, gt_boxes)

    matched_gt = set()
    true_positives = 0
    matched_ious = []
    pred_order = np.argsort(-pred_scores_np) if num_preds > 0 else []

    for pred_idx in pred_order:
        if num_gt == 0:
            break
        best_gt_idx = np.argmax(iou_matrix[pred_idx])
        best_iou = iou_matrix[pred_idx, best_gt_idx]
        if best_iou >= iou_threshold and best_gt_idx not in matched_gt:
            matched_gt.add(best_gt_idx)
            true_positives += 1
            matched_ious.append(best_iou)

    precision = true_positives / num_preds if num_preds > 0 else 0.0
    recall = true_positives / num_gt if num_gt > 0 else 0.0
    iou1_matched_only = float(np.mean(matched_ious)) if matched_ious else 0.0
    iou2_over_all_gt = float(np.sum(matched_ious) / num_gt) if num_gt > 0 else 0.0

    return {
        "map50": map50,
        "precision": precision,
        "recall": recall,
        "iou_matched": iou1_matched_only,
        "iou_all_gt": iou2_over_all_gt,
    }

# %%
# # Main automated loop -- Exp × Image × Anchor Bbox -> CSV
# # Writes incrementally (append mode) so a Colab disconnect doesn't lose
# # everything already computed. Skips rows already present in the CSV if
# # you re-run after a crash (resumable).
# def load_yolo_boxes(label_path, img_width, img_height, class_id=0):
#     boxes = []
#     with open(label_path, "r") as f:
#         for line in f:
#             parts = line.strip().split()
#             if not parts:
#                 continue
#             cls = int(parts[0])
#             if cls != class_id:
#                 continue
#             xc, yc, bw, bh = map(float, parts[1:5])
#             xc, yc, bw, bh = xc * img_width, yc * img_height, bw * img_width, bh * img_height
#             boxes.append([xc - bw / 2, yc - bh / 2, xc + bw / 2, yc + bh / 2])
#     return np.array(boxes, dtype=np.float32)


# def format_prompt_id(exemplar_indices: list) -> str:
#     """
#     Single box (Exp3)   -> "5"
#     Multiple boxes (Exp1/Exp2) -> "5+12+3"  (anchor first, then the sampled others,
#     order preserved so you can always tell which one was the anchor: it's the
#     first number in the string)
#     """
#     return "+".join(str(i) for i in exemplar_indices)

# # ---- Resume support: now keyed on (image_ID, Prompt_ID) instead of (image_ID, Bbox_ID) ----
# done_keys = set()
# file_exists = os.path.exists(OUTPUT_CSV)
# if file_exists:
#     existing = pd.read_csv(OUTPUT_CSV)
#     existing = existing[existing["experiment_name"] == EXPERIMENT_NAME]
#     done_keys = set(zip(existing["image_ID"], existing["Prompt_ID"].astype(str)))
#     print(f"Resuming: {len(done_keys)} rows already done for {EXPERIMENT_NAME}.")

# csv_file = open(OUTPUT_CSV, "a", newline="")
# csv_writer = csv.DictWriter(csv_file, fieldnames=CSV_COLUMNS)
# if not file_exists:
#     csv_writer.writeheader()

# start_time = time.time()
# n_runs = 0

# for folder, image_path, label_path, image_id in image_records:
#     if label_path is None:
#         continue

#     image = Image.open(image_path).convert("RGB")
#     img_w, img_h = image.size
#     gt_boxes = load_yolo_boxes(label_path, img_w, img_h, class_id=RUMEX_CLASS_ID)
#     n_gt = len(gt_boxes)
#     if n_gt == 0:
#         continue

#     for anchor_idx in range(n_gt):
#         exemplar_indices = select_exemplar_indices(n_gt, anchor_idx, N_EXEMPLARS, RNG)
#         prompt_id = format_prompt_id(exemplar_indices)

#         if (image_id, prompt_id) in done_keys:
#             continue  # already computed in a previous run, skip

#         exemplar_crops = [image.crop([int(round(v)) for v in gt_boxes[i]]) for i in exemplar_indices]

#         final_boxes, final_scores, final_masks = run_sam3_pipeline(
#             image, exemplar_crops, use_tiling=USE_TILING,
#             tile_size=TILE_SIZE, overlap=OVERLAP, threshold=THRESHOLD,
#         )

#         metrics = compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold=IOU_THRESHOLD)

#         row = {
#             "experiment_name": EXPERIMENT_NAME,
#             "image_ID": image_id,
#             "Prompt_ID": prompt_id,
#             "Prompt_Type": PROMPT_TYPE,
#             "mAP50": metrics["map50"],
#             "precision": metrics["precision"],
#             "recall": metrics["recall"],
#             "IoU1": metrics["iou_matched"],
#             "IoU2": metrics["iou_all_gt"],
#         }
#         csv_writer.writerow(row)
#         csv_file.flush()
#         n_runs += 1

#         if n_runs % 20 == 0:
#             elapsed = time.time() - start_time
#             print(f"[{EXPERIMENT_NAME}] {n_runs} runs done | image={image_id} | "
#                   f"prompt={prompt_id} | mAP50={metrics['map50']:.3f} | "
#                   f"elapsed={elapsed/60:.1f} min")

#         torch.cuda.empty_cache()

# csv_file.close()
# print(f"Finished {EXPERIMENT_NAME}: {n_runs} new rows written to {OUTPUT_CSV}")

# %%
# ============================================================
# CELL: Main automated loop -- Exp × Image × Anchor Bbox -> CSV
# Now with per-image logging (time per image + running ETA)
# ============================================================

# ---- Resume support ----
done_keys = set()
file_exists = os.path.exists(OUTPUT_CSV)
if file_exists:
    existing = pd.read_csv(OUTPUT_CSV)
    existing = existing[existing["experiment_name"] == EXPERIMENT_NAME]
    done_keys = set(zip(existing["image_ID"], existing["anchor_idx"].astype(int)))
    print(f"Resuming: {len(done_keys)} rows already done for {EXPERIMENT_NAME}.")

csv_file = open(OUTPUT_CSV, "a", newline="")
csv_writer = csv.DictWriter(csv_file, fieldnames=CSV_COLUMNS)
if not file_exists:
    csv_writer.writeheader()

start_time = time.time()
n_runs = 0
image_times = []  # store seconds-per-image, for the running ETA

# Only count images that actually have labels, so the ETA denominator is accurate
valid_images = [rec for rec in image_records if rec[2] is not None]
n_total_images = len(valid_images)

for img_idx, (folder, image_path, label_path, image_id) in enumerate(valid_images, start=1):
    image_t0 = time.time()

    image = Image.open(image_path).convert("RGB")
    img_w, img_h = image.size
    gt_boxes = load_yolo_boxes(label_path, img_w, img_h, class_id=RUMEX_CLASS_ID)
    n_gt = len(gt_boxes)

    if n_gt == 0:
        print(f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id}: 0 GT boxes, skipped.")
        continue

    image_map50s = []  # collect this image's mAP50 values for a quick per-image summary

    for anchor_idx in range(n_gt):

        #any anchor whose row already exists in csv gets skipped in a fraction of a second (no SAM3 call, no RNG draw)
        if (image_id, anchor_idx) in done_keys:
              continue  # skip BEFORE touching RNG at all

        run_t0 = time.time()

        exemplar_indices = select_exemplar_indices(n_gt, anchor_idx, N_EXEMPLARS, image_id)
        prompt_id = format_prompt_id(exemplar_indices)

        exemplar_crops = [image.crop([int(round(v)) for v in gt_boxes[i]]) for i in exemplar_indices]

        final_boxes, final_scores, final_masks = run_sam3_pipeline(
            image, exemplar_crops, use_tiling=USE_TILING,
            tile_size=TILE_SIZE, overlap=OVERLAP, threshold=THRESHOLD,
        )

        metrics = compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold=IOU_THRESHOLD)
        image_map50s.append(metrics["map50"])

        row = {
          "experiment_name": EXPERIMENT_NAME,
          "image_ID": image_id,
          "anchor_idx": anchor_idx,
          "Prompt_ID": prompt_id,
          "Prompt_Type": PROMPT_TYPE,
          "mAP50": metrics["map50"],
          "precision": metrics["precision"],
          "recall": metrics["recall"],
          "IoU1": metrics["iou_matched"],
          "IoU2": metrics["iou_all_gt"],
      }
        csv_writer.writerow(row)
        csv_file.flush()
        n_runs += 1

        # explicitly drop large objects before next iteration
        del final_boxes, final_scores, final_masks, exemplar_crops
        gc.collect()
        torch.cuda.empty_cache()

        run_elapsed = time.time() - run_t0
        print(
            f"    [{EXPERIMENT_NAME}] run #{n_runs} | image={image_id} | "
            f"anchor={anchor_idx} ({anchor_idx+1}/{n_gt}) | prompt_id={prompt_id} | "
            f"mAP50={metrics['map50']:.3f} | time={run_elapsed:.1f}s"
        )

        torch.cuda.empty_cache()

    # ---- Per-image log: prints once this image's anchors are all done ----
    image_elapsed = time.time() - image_t0
    image_times.append(image_elapsed)
    avg_time_per_image = np.mean(image_times)
    images_left = n_total_images - img_idx
    eta_seconds = images_left * avg_time_per_image

    map50_str = f"{np.mean(image_map50s):.3f}" if image_map50s else "N/A (all anchors already done, skipped)"

    print(
        f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id} done | "
        f"{n_gt} GT box(es) | image_mAP50_mean={map50_str} | "
        f"time={image_elapsed:.1f}s | avg/image={avg_time_per_image:.1f}s | "
        f"ETA={eta_seconds/60:.1f} min ({eta_seconds/3600:.2f} h)"
    )

csv_file.close()
total_elapsed = time.time() - start_time
print(f"\nFinished {EXPERIMENT_NAME}: {n_runs} new rows written to {OUTPUT_CSV}")
print(f"Total time: {total_elapsed/60:.1f} min ({total_elapsed/3600:.2f} h)")
# Out:
# Resuming: 1685 rows already done for E02_2.
# [E02_2] (1/179) 20220513_Halden/DJI_20220513075116_0213 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=2.5s | ETA=7.4 min (0.12 h)
# [E02_2] (2/179) 20220513_Halden/DJI_20220513075207_0234 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=2.4s | ETA=7.1 min (0.12 h)
# [E02_2] (3/179) 20220513_Halden/DJI_20220513075336_0270 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.4s | avg/image=2.4s | ETA=7.0 min (0.12 h)
# [E02_2] (4/179) 20220513_Halden/DJI_20220513075432_0295 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.0s | avg/image=2.3s | ETA=6.7 min (0.11 h)
# [E02_2] (5/179) 20220513_Halden/DJI_20220513075444_0300 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=2.3s | ETA=6.8 min (0.11 h)
# [E02_2] (6/179) 20220513_Halden/DJI_20220513075506_0309 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=2.4s | ETA=6.9 min (0.11 h)
# [E02_2] (7/179) 20220513_Halden/DJI_20220513075707_0358 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.2s | avg/image=2.4s | ETA=6.8 min (0.11 h)
# [E02_2] (8/179) 20220513_Halden/DJI_20220513075753_0379 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=2.4s | ETA=6.8 min (0.11 h)
# [E02_2] (9/179) 20220513_Halden/DJI_20220513075822_0391 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.0s | avg/image=2.4s | ETA=6.7 min (0.11 h)
# [E02_2] (10/179) 20220513_Halden/DJI_20220513075916_0413 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.5s | avg/image=2.3s | ETA=6.4 min (0.11 h)
# [E02_2] (11/179) 20220701_Halden/DJI_20220701165417_0004 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.7s | avg/image=2.3s | ETA=6.5 min (0.11 h)
# [E02_2] (12/179) 20220701_Halden/DJI_20220701170828_0136: 0 GT boxes, skipped.
# [E02_2] (13/179) 20220701_Halden/DJI_20220701170852_0151 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=2.3s | ETA=6.4 min (0.11 h)
# [E02_2] (14/179) 20220701_Halden/DJI_20220701170908_0161 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=2.3s | ETA=6.4 min (0.11 h)
# [E02_2] (15/179) 20220701_Halden/DJI_20220701170934_0178: 0 GT boxes, skipped.
# [E02_2] (16/179) 20220701_Halden/DJI_20220701170943_0185: 0 GT boxes, skipped.
# [E02_2] (17/179) 20220701_Halden/DJI_20220701170957_0193: 0 GT boxes, skipped.
# [E02_2] (18/179) 20220701_Halden/DJI_20220701171012_0203: 0 GT boxes, skipped.
# [E02_2] (19/179) 20220701_Halden/DJI_20220701171049_0225: 0 GT boxes, skipped.
# [E02_2] (20/179) 20220701_Halden/DJI_20220701171150_0238 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.1s | avg/image=2.3s | ETA=6.1 min (0.10 h)
# [E02_2] (21/179) 20220701_Waldegg/DJI_20220701173416_0008 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.2s | avg/image=2.3s | ETA=6.1 min (0.10 h)
# [E02_2] (22/179) 20220701_Waldegg/DJI_20220701173429_0016: 0 GT boxes, skipped.
# [E02_2] (23/179) 20220701_Waldegg/DJI_20220701173552_0032: 0 GT boxes, skipped.
# [E02_2] (24/179) 20220701_Waldegg/DJI_20220701173614_0046 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.1s | avg/image=2.3s | ETA=5.9 min (0.10 h)
# [E02_2] (25/179) 20220701_Waldegg/DJI_20220701173639_0062 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=2.3s | ETA=5.9 min (0.10 h)
# [E02_2] (26/179) 20220701_Waldegg/DJI_20220701173702_0076: 0 GT boxes, skipped.
# [E02_2] (27/179) 20220701_Waldegg/DJI_20220701173741_0100 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.0s | avg/image=2.3s | ETA=5.8 min (0.10 h)
# [E02_2] (28/179) 20220701_Waldegg/DJI_20220701173746_0103 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.1s | avg/image=2.3s | ETA=5.7 min (0.10 h)
# [E02_2] (29/179) 20220701_Waldegg/DJI_20220701174049_0215 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.4s | avg/image=2.3s | ETA=5.7 min (0.10 h)
# [E02_2] (30/179) 20220701_Waldegg/DJI_20220701174249_0292: 0 GT boxes, skipped.
# [E02_2] (31/179) 20220708_Herrenpuent/DJI_20220708152335_0016: 0 GT boxes, skipped.
# [E02_2] (32/179) 20220708_Herrenpuent/DJI_20220708152405_0036: 0 GT boxes, skipped.
# [E02_2] (33/179) 20220708_Herrenpuent/DJI_20220708152423_0047: 0 GT boxes, skipped.
# [E02_2] (34/179) 20220708_Herrenpuent/DJI_20220708152437_0056: 0 GT boxes, skipped.
# [E02_2] (35/179) 20220708_Herrenpuent/DJI_20220708152505_0073 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=2.3s | ETA=5.5 min (0.09 h)
# [E02_2] (36/179) 20220708_Herrenpuent/DJI_20220708152528_0087: 0 GT boxes, skipped.
# [E02_2] (37/179) 20220708_Herrenpuent/DJI_20220708152551_0102 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=2.3s | ETA=5.5 min (0.09 h)
# [E02_2] (38/179) 20220708_Herrenpuent/DJI_20220708152616_0112: 0 GT boxes, skipped.
# [E02_2] (39/179) 20220708_Herrenpuent/DJI_20220708152637_0125 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.8s | avg/image=2.4s | ETA=5.6 min (0.09 h)
# [E02_2] (40/179) 20220708_Herrenpuent/DJI_20220708152738_0164 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=5.3s | avg/image=2.5s | ETA=5.8 min (0.10 h)
# [E02_2] (41/179) 20220902_Herrenpuent/DJI_20220902101510_0137 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=2.5s | ETA=5.8 min (0.10 h)
# [E02_2] (42/179) 20220902_Herrenpuent/DJI_20220902102152_0354: 0 GT boxes, skipped.
# [E02_2] (43/179) 20220902_Herrenpuent/DJI_20220902102227_0374 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.6s | avg/image=2.5s | ETA=5.6 min (0.09 h)
# [E02_2] (44/179) 20220902_Herrenpuent/DJI_20220902102331_0408 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.2s | avg/image=2.5s | ETA=5.6 min (0.09 h)
# [E02_2] (45/179) 20220902_Herrenpuent/DJI_20220902102358_0423 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.6s | avg/image=2.4s | ETA=5.4 min (0.09 h)
# [E02_2] (46/179) 20220902_Herrenpuent/DJI_20220902102502_0458 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.9s | avg/image=2.4s | ETA=5.4 min (0.09 h)
# [E02_2] (47/179) 20220902_Herrenpuent/DJI_20220902102606_0492 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.6s | avg/image=2.4s | ETA=5.3 min (0.09 h)
# [E02_2] (48/179) 20220902_Herrenpuent/DJI_20220902102721_0533 done | 3 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.6s | avg/image=2.4s | ETA=5.2 min (0.09 h)
# [E02_2] (49/179) 20220902_Herrenpuent/DJI_20220902103027_0633 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.2s | avg/image=2.4s | ETA=5.1 min (0.09 h)
# [E02_2] (50/179) 20220902_Herrenpuent/DJI_20220902103325_0729 done | 21 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.4s | avg/image=2.3s | ETA=5.0 min (0.08 h)
# [E02_2] (51/179) 20221010_HaldenNord/DJI_20221010151043_0001 done | 9 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=2.3s | ETA=5.0 min (0.08 h)
# [E02_2] (52/179) 20221010_HaldenNord/DJI_20221010151055_0012 done | 13 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=3.0s | avg/image=2.3s | ETA=5.0 min (0.08 h)
# [E02_2] (53/179) 20221010_HaldenNord/DJI_20221010151239_0115 done | 18 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=2.3s | ETA=4.9 min (0.08 h)
# [E02_2] (54/179) 20221010_HaldenNord/DJI_20221010151341_0176 done | 14 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=2.3s | ETA=4.9 min (0.08 h)
# [E02_2] (55/179) 20221010_HaldenNord/DJI_20221010151406_0200 done | 23 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.3s | avg/image=2.3s | ETA=4.9 min (0.08 h)
# [E02_2] (56/179) 20221010_HaldenNord/DJI_20221010151502_0255 done | 5 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.4s | avg/image=2.3s | ETA=4.8 min (0.08 h)
# [E02_2] (57/179) 20221010_HaldenNord/DJI_20221010151556_0309 done | 11 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.7s | avg/image=2.3s | ETA=4.7 min (0.08 h)
# [E02_2] (58/179) 20221010_HaldenNord/DJI_20221010151812_0443 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=2.3s | ETA=4.7 min (0.08 h)
# [E02_2] (59/179) 20221010_HaldenNord/DJI_20221010151951_0542 done | 25 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.1s | avg/image=2.3s | ETA=4.7 min (0.08 h)
# [E02_2] (60/179) 20221010_HaldenNord/DJI_20221010152133_0643 done | 7 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.8s | avg/image=2.3s | ETA=4.6 min (0.08 h)
# [E02_2] (61/179) 20221010_HaldenNord/DJI_20221010152627_0933 done | 16 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.9s | avg/image=2.3s | ETA=4.5 min (0.08 h)
# [E02_2] (62/179) 20221010_HaldenNord/DJI_20221010152733_0996 done | 48 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.9s | avg/image=2.3s | ETA=4.5 min (0.07 h)
# [E02_2] (63/179) 20221010_HaldenSued/DJI_20221010142742_0010 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.6s | avg/image=2.3s | ETA=4.5 min (0.07 h)
# [E02_2] (64/179) 20221010_HaldenSued/DJI_20221010142813_0041 done | 4 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.8s | avg/image=2.3s | ETA=4.4 min (0.07 h)
# [E02_2] (65/179) 20221010_HaldenSued/DJI_20221010142858_0086 done | 14 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.2s | avg/image=2.3s | ETA
| image=20241203_Loehre/DJI_20241203150725_0055 | anchor=5 (6/7) | prompt_id=5+1+0 | mAP50=0.287 | time=174.4s
#     [E02_2] run #56 | image=20241203_Loehre/DJI_20241203150725_0055 | anchor=6 (7/7) | prompt_id=6+1+5 | mAP50=0.021 | time=173.3s
# [E02_2] (165/179) 20241203_Loehre/DJI_20241203150725_0055 done | 7 GT box(es) | image_mAP50_mean=0.178 | time=1218.7s | avg/image=82.0s | ETA=19.1 min (0.32 h)
#     [E02_2] run #57 | image=20241203_Loehre/DJI_20241203150750_0069 | anchor=0 (1/6) | prompt_id=0+4+1 | mAP50=0.051 | time=173.8s
#     [E02_2] run #58 | image=20241203_Loehre/DJI_20241203150750_0069 | anchor=1 (2/6) | prompt_id=1+4+0 | mAP50=0.006 | time=173.2s
#     [E02_2] run #59 | image=20241203_Loehre/DJI_20241203150750_0069 | anchor=2 (3/6) | prompt_id=2+4+0 | mAP50=0.043 | time=173.8s
#     [E02_2] run #60 | image=20241203_Loehre/DJI_20241203150750_0069 | anchor=3 (4/6) | prompt_id=3+4+2 | mAP50=0.096 | time=173.3s
#     [E02_2] run #61 | image=20241203_Loehre/DJI_20241203150750_0069 | anchor=4 (5/6) | prompt_id=4+2+5 | mAP50=0.175 | time=173.0s
#     [E02_2] run #62 | image=20241203_Loehre/DJI_20241203150750_0069 | anchor=5 (6/6) | prompt_id=5+1+3 | mAP50=0.004 | time=173.5s
# [E02_2] (166/179) 20241203_Loehre/DJI_20241203150750_0069 done | 6 GT box(es) | image_mAP50_mean=0.063 | time=1043.3s | avg/image=89.8s | ETA=19.5 min (0.32 h)
#     [E02_2] run #63 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=0 (1/10) | prompt_id=0+8+6 | mAP50=0.055 | time=173.5s
#     [E02_2] run #64 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=1 (2/10) | prompt_id=1+5+7 | mAP50=0.008 | time=174.9s
#     [E02_2] run #65 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=2 (3/10) | prompt_id=2+8+1 | mAP50=0.195 | time=173.5s
#     [E02_2] run #66 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=3 (4/10) | prompt_id=3+6+4 | mAP50=0.063 | time=173.9s
#     [E02_2] run #67 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=4 (5/10) | prompt_id=4+0+5 | mAP50=0.031 | time=173.3s
#     [E02_2] run #68 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=5 (6/10) | prompt_id=5+8+6 | mAP50=0.029 | time=172.9s
#     [E02_2] run #69 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=6 (7/10) | prompt_id=6+7+1 | mAP50=0.001 | time=173.7s
#     [E02_2] run #70 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=7 (8/10) | prompt_id=7+5+4 | mAP50=0.000 | time=174.6s
#     [E02_2] run #71 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=8 (9/10) | prompt_id=8+6+9 | mAP50=0.206 | time=173.8s
#     [E02_2] run #72 | image=20241203_Loehre/DJI_20241203150821_0086 | anchor=9 (10/10) | prompt_id=9+7+6 | mAP50=0.142 | time=173.8s
# [E02_2] (167/179) 20241203_Loehre/DJI_20241203150821_0086 done | 10 GT box(es) | image_mAP50_mean=0.073 | time=1739.8s | avg/image=103.1s | ETA=20.6 min (0.34 h)
#     [E02_2] run #73 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=0 (1/10) | prompt_id=0+6+5 | mAP50=0.365 | time=173.3s
#     [E02_2] run #74 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=1 (2/10) | prompt_id=1+4+3 | mAP50=0.302 | time=173.7s
#     [E02_2] run #75 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=2 (3/10) | prompt_id=2+4+0 | mAP50=0.127 | time=173.0s
#     [E02_2] run #76 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=3 (4/10) | prompt_id=3+9+5 | mAP50=0.410 | time=173.3s
#     [E02_2] run #77 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=4 (5/10) | prompt_id=4+2+0 | mAP50=0.110 | time=173.4s
#     [E02_2] run #78 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=5 (6/10) | prompt_id=5+2+1 | mAP50=0.419 | time=173.1s
#     [E02_2] run #79 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=6 (7/10) | prompt_id=6+8+0 | mAP50=0.445 | time=173.1s
#     [E02_2] run #80 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=7 (8/10) | prompt_id=7+0+1 | mAP50=0.175 | time=173.7s
#     [E02_2] run #81 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=8 (9/10) | prompt_id=8+2+0 | mAP50=0.193 | time=173.8s
#     [E02_2] run #82 | image=20241203_Loehre/DJI_20241203150837_0095 | anchor=9 (10/10) | prompt_id=9+8+1 | mAP50=0.384 | time=173.6s
# [E02_2] (168/179) 20241203_Loehre/DJI_20241203150837_0095 done | 10 GT box(es) | image_mAP50_mean=0.293 | time=1736.2s | avg/image=116.2s | ETA=21.3 min (0.36 h)
#     [E02_2] run #83 | image=20241203_Loehre/DJI_20241203150935_0127 | anchor=0 (1/4) | prompt_id=0+3+2 | mAP50=0.072 | time=174.7s
#     [E02_2] run #84 | image=20241203_Loehre/DJI_20241203150935_0127 | anchor=1 (2/4) | prompt_id=1+3+0 | mAP50=0.257 | time=172.9s
#     [E02_2] run #85 | image=20241203_Loehre/DJI_20241203150935_0127 | anchor=2 (3/4) | prompt_id=2+3+1 | mAP50=0.037 | time=174.9s

# %%
# # Aggregate statistics -- mean + std of mAP50 per experiment
# # Run this AFTER all 3 experiments' CSVs have been produced, pointing
# # ALL_RESULTS_CSVS at each experiment's output file.
# ALL_RESULTS_CSVS = [
#     "/content/drive/MyDrive/results/results_E02_2.csv",
#     # "/content/drive/MyDrive/datasets/AGS_Multi_Rumex/results_<exp2_name>.csv",
#     # "/content/drive/MyDrive/datasets/AGS_Multi_Rumex/results_<exp3_name>.csv",
# ]

# dfs = [pd.read_csv(p) for p in ALL_RESULTS_CSVS if os.path.exists(p)]
# full_df = pd.concat(dfs, ignore_index=True)
# print(f"Loaded {len(full_df)} total rows across {full_df['experiment_name'].nunique()} experiment(s).")

# summary = full_df.groupby("experiment_name").agg(
#     n_runs=("mAP50", "count"),
#     mAP50_mean=("mAP50", "mean"),
#     mAP50_std=("mAP50", "std"),
#     precision_mean=("precision", "mean"),
#     precision_std=("precision", "std"),
#     recall_mean=("recall", "mean"),
#     recall_std=("recall", "std"),
#     IoU1_mean=("IoU1", "mean"),
#     IoU2_mean=("IoU2", "mean"),
# ).reset_index()

# print(summary.to_string(index=False))
# summary.to_csv("/content/drive/MyDrive/results/summary_all_experiments.csv", index=False)

# %%
# import pandas as pd

# EXPERIMENT_NAME = "E02_2"
# OUTPUT_CSV = f"/content/drive/MyDrive/master_thesis/results/results_{EXPERIMENT_NAME}.csv"

# df = pd.read_csv(OUTPUT_CSV)
# print(f"Rows before: {len(df)}")

# target_image_id = "20230426_Wallenwil/DJI_20230426111258_0224"
# target_anchors = [33, 34]

# # Show what matches, before deleting anything
# mask = (
#     (df["experiment_name"] == EXPERIMENT_NAME) &
#     (df["image_ID"] == target_image_id) &
#     (df["anchor_idx"].astype(int).isin(target_anchors))
# )
# print(f"Matching rows found: {mask.sum()}")
# print(df[mask])

# %%
# # Keep only the FIRST occurrence of each (image_ID, anchor_idx) pair among the matches,
# # drop any later duplicates (the accidental rerun rows)
# df_clean = pd.concat([
#     df[~mask],
#     df[mask].drop_duplicates(subset=["experiment_name", "image_ID", "anchor_idx"], keep="first")
# ]).sort_index()
# df_clean.to_csv(OUTPUT_CSV, index=False)
# print(f"Rows after: {len(df_clean)}")

# %%
def has_rumex_annotation(label_path, class_id=0):
    if label_path is None:
        return False
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if parts and int(parts[0]) == class_id:
                return True
    return False

annotated_count = sum(1 for _, _, label_path, _ in image_records if has_rumex_annotation(label_path, RUMEX_CLASS_ID))
unannotated_count = len(image_records) - annotated_count

print(f"Total images:      {len(image_records)}")
print(f"Annotated:         {annotated_count}")
print(f"Unannotated:       {unannotated_count}")

# %%
#  Aggregate statistics for ONE experiment (run separately per experiment)
import pandas as pd
import numpy as np
import os

#  Change this single line for each experiment
EXPERIMENT_CSV = "/content/drive/MyDrive/results/results_E02_2.csv"
OUTPUT_DIR = "/content/drive/MyDrive/results/"
os.makedirs(OUTPUT_DIR, exist_ok=True)  # just in case it doesn't exist yet

assert os.path.exists(EXPERIMENT_CSV), f"File not found: {EXPERIMENT_CSV}"
df = pd.read_csv(EXPERIMENT_CSV)

exp_name = df["experiment_name"].iloc[0]
print(f"Experiment: {exp_name}")
print(f"Total rows (image x prompt runs): {len(df)}")
print(f"Number of distinct images: {df['image_ID'].nunique()}")

# %%
#  Raw per-run stats (every row = one image + one prompt set, independent observation)
# Here, every row in our CSV is treated as one independent experiment.
#output 1 value per metric (produces one overall mean and one overall std for each metric)
raw_summary = df.agg(
    n_runs=("mAP50", "count"),
    mAP50_mean=("mAP50", "mean"),
    mAP50_std=("mAP50", "std"),
    precision_mean=("precision", "mean"),
    precision_std=("precision", "std"),
    recall_mean=("recall", "mean"),
    recall_std=("recall", "std"),
    IoU1_mean=("IoU1", "mean"),
    IoU1_std=("IoU1", "std"),
    IoU2_mean=("IoU2", "mean"),
    IoU2_std=("IoU2", "std"),
)

raw_summary.to_csv(os.path.join(OUTPUT_DIR, f"image_level_{exp_name}.csv"), index=False)
print(f"Saved raw_summary_{exp_name}.csv to {OUTPUT_DIR}")

print(f"=== {exp_name} -- raw per-run summary (all rows independent) ===")
print(raw_summary)

# %%
# Image-level stats (collapse multiple prompt runs per image to one value first,
# so images with more GT boxes / more prompt sets don't dominate the average)
image_level = ( # produces one mean value per image for each metric
    df.groupby("image_ID")
    .agg(
        mAP50_image_mean=("mAP50", "mean"),
        precision_image_mean=("precision", "mean"),
        recall_image_mean=("recall", "mean"),
        IoU1_image_mean=("IoU1", "mean"),
        IoU2_image_mean=("IoU2", "mean"),
        n_prompts=("mAP50", "count"),
    )
    .reset_index()
)
image_level.to_csv(os.path.join(OUTPUT_DIR, f"image_level_{exp_name}.csv"), index=False)
print(f"Saved image_level{exp_name}.csv to {OUTPUT_DIR}")

print(f"=== {exp_name} -- image-level results ({len(image_level)} images) ===")
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    print(image_level.to_string(index=False))

# %%
image_level_summary = pd.DataFrame({
    "experiment_name": [exp_name],
    "n_images": [image_level["image_ID"].nunique()],
    "mAP50_mean": [image_level["mAP50_image_mean"].mean()],
    "mAP50_std": [image_level["mAP50_image_mean"].std()],
    "precision_mean": [image_level["precision_image_mean"].mean()],
    "precision_std": [image_level["precision_image_mean"].std()],
    "recall_mean": [image_level["recall_image_mean"].mean()],
    "recall_std": [image_level["recall_image_mean"].std()],
    "IoU1_mean": [image_level["IoU1_image_mean"].mean()],
    "IoU2_mean": [image_level["IoU2_image_mean"].mean()],
})

image_level_summary.to_csv(os.path.join(OUTPUT_DIR, f"summary_{exp_name}.csv"), index=False)
print(f"\nSaved image_level_{exp_name}.csv and summary_{exp_name}.csv to {OUTPUT_DIR}")

print(f"\n=== {exp_name} -- image-level summary ===")
print(image_level_summary.to_string(index=False))
