# %% [markdown]
# <a href="https://colab.research.google.com/github/ghadirchhade/Master-Thesis/blob/main/baseline2_new1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %%
# !pip install -q torch torchvision

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.11.0+cu128
# Torchvision version: 0.26.0+cu128
# CUDA is available: True

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# facebook/sam3 is gated on the Hub -> you must accept the license at
# https://huggingface.co/facebook/sam3 with the account whose token you use below.
# !pip install -q -U transformers accelerate huggingface_hub supervision

from huggingface_hub import login
login()  # paste your HF token (needs access to facebook/sam3)

print("Transformers SAM3 dependencies installed.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 95.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 784.9/784.9 kB 43.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.3/373.3 kB 16.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.8/35.8 MB 29.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 82.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 14.4 MB/s eta 0:00:00
# Transformers SAM3 dependencies installed.

# %%
import os, glob, csv, time
import numpy as np
import pandas as pd
import torch
import cv2
from PIL import Image
import supervision as sv
import matplotlib.patches as patches
from transformers import Sam3Model, Sam3Processor
from supervision.metrics import MeanAveragePrecision

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

sam3_model = Sam3Model.from_pretrained("facebook/sam3", device_map="auto")
sam3_model.eval()

sam3_processor = Sam3Processor.from_pretrained("facebook/sam3")

print("HF transformers SAM3 model + processor loaded.")
print("Model device:", next(sam3_model.parameters()).device)
# Out:
# config.json:   0%|          | 0.00/25.8k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.44GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/1468 [00:00<?, ?it/s]
# processor_config.json:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]
# HF transformers SAM3 model + processor loaded.
# Model device: cuda:0

# %%
#configuration
IMAGES_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/images"
LABELS_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/annotations_yolo"
RUMEX_CLASS_ID = 0

EXPERIMENT_NAME = "E02_1"
N_EXEMPLARS     = 3               # several positive bboxes
MAX_DIM         = 1024            # resize cap for SAM3 input (from your Exp2 code)
THRESHOLD       = 0.4            # confidence threshold
MASK_THRESHOLD  = 0.5             # from your Exp2 code (Exp1 used 0.4 -- kept as-is per experiment)
IOU_THRESHOLD   = 0.5

PROMPT_TYPE = "multiple" if N_EXEMPLARS > 1 else "single"

OUTPUT_DIR = "/content/drive/MyDrive/master_thesis/results/"
os.makedirs(OUTPUT_DIR, exist_ok=True)
OUTPUT_CSV = os.path.join(OUTPUT_DIR, f"results2_{EXPERIMENT_NAME}.csv")
CSV_COLUMNS = ["experiment_name", "image_ID", "Prompt_ID", "Prompt_Type", "mAP50",
               "precision", "recall", "IoU1", "IoU2"]

RNG = np.random.default_rng(42)  # same seed as Exp1 -> same anchor/exemplar sampling logic

# %%
#  Dataset discovery
def find_label_path(image_filename_no_ext, folder_name):
    mirrored = os.path.join(LABELS_ROOT, folder_name, image_filename_no_ext + ".txt")
    flat = os.path.join(LABELS_ROOT, image_filename_no_ext + ".txt")
    if os.path.exists(mirrored):
        return mirrored
    if os.path.exists(flat):
        return flat
    return None

image_records = []
VALID_EXT = (".jpg", ".jpeg", ".png")

for folder in sorted(os.listdir(IMAGES_ROOT)):
    folder_path = os.path.join(IMAGES_ROOT, folder)
    if not os.path.isdir(folder_path):
        continue
    for fname in sorted(os.listdir(folder_path)):
        if not fname.lower().endswith(VALID_EXT):
            continue
        name_no_ext = os.path.splitext(fname)[0]
        label_path = find_label_path(name_no_ext, folder)
        image_id = f"{folder}/{name_no_ext}"
        image_records.append((folder, os.path.join(folder_path, fname), label_path, image_id))

missing_labels = [r for r in image_records if r[2] is None]
print(f"Discovered {len(image_records)} images across {len(set(r[0] for r in image_records))} folders.")
if missing_labels:
    print(f"WARNING: {len(missing_labels)} images have no matching label file. "
          f"First few: {[r[3] for r in missing_labels[:5]]}")
# Out:
# Discovered 179 images across 15 folders.

# %%
#  YOLO box loader + exemplar/prompt-id helpers
def load_yolo_boxes(label_path, img_width, img_height, class_id=0):
    boxes = []
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            cls = int(parts[0])
            if cls != class_id:
                continue
            xc, yc, bw, bh = map(float, parts[1:5])
            xc, yc, bw, bh = xc * img_width, yc * img_height, bw * img_width, bh * img_height
            boxes.append([xc - bw / 2, yc - bh / 2, xc + bw / 2, yc + bh / 2])
    return np.array(boxes, dtype=np.float32)


def select_exemplar_indices(n_gt: int, anchor_idx: int, n_exemplars: int, rng) -> list:
    """
    Always includes the anchor box; fills the remaining slots with other GT
    boxes from the same image, sampled without replacement. Falls back to
    whatever's available if the image doesn't have enough other boxes.
    """
    others = [i for i in range(n_gt) if i != anchor_idx]
    n_others_needed = min(n_exemplars - 1, len(others))
    chosen_others = list(rng.choice(others, size=n_others_needed, replace=False)) if n_others_needed > 0 else []
    return [anchor_idx] + chosen_others


def format_prompt_id(exemplar_indices: list) -> str:
    """Anchor first, then sampled others, e.g. '5+12+3' -- anchor is always the first number."""
    return "+".join(str(i) for i in exemplar_indices)

# %%
#  Resize helper
def resize_for_sam3(img, max_dim=MAX_DIM):
    w, h = img.size
    scale = max_dim / max(w, h)
    if scale >= 1:
        return img, 1.0
    new_w, new_h = int(w * scale), int(h * scale)
    return img.resize((new_w, new_h), Image.BILINEAR), scale

# %%
# # ============================================================
# # CELL: Direct scale-mismatch check
# # ============================================================
# folder, image_path, label_path, image_id = valid_images[0]
# image = Image.open(image_path).convert("RGB")
# img_w, img_h = image.size
# gt_boxes = load_yolo_boxes(label_path, img_w, img_h, class_id=RUMEX_CLASS_ID)

# image_sam, sam_scale = resize_for_sam3(image, MAX_DIM)
# print(f"Full-res image size: {image.size}")
# print(f"image_sam size (resized): {image_sam.size}")
# print(f"sam_scale: {sam_scale}")

# anchor_idx = 0
# exemplar_indices = select_exemplar_indices(len(gt_boxes), anchor_idx, N_EXEMPLARS, RNG)
# exemplar_boxes_fullres = [gt_boxes[i].tolist() for i in exemplar_indices]
# print(f"\nExemplar boxes (full-res, these ARE gt_boxes): {exemplar_boxes_fullres}")

# # Reproduce run_sam3_whole_image's internals step by step, with prints at each stage
# input_boxes_xyxy = [[c * sam_scale for c in box] for box in exemplar_boxes_fullres]
# print(f"Exemplar boxes scaled to image_sam space (sent to SAM3): {input_boxes_xyxy}")

# inputs = sam3_processor(
#     images=image_sam,
#     input_boxes=[input_boxes_xyxy],
#     input_boxes_labels=[[1] * len(exemplar_boxes_fullres)],
#     return_tensors="pt",
# ).to(sam3_model.device)

# print(f"\ninputs['original_sizes']: {inputs.get('original_sizes')}")
# print(f"(compare this to image_sam size {image_sam.size} -- should match [H,W] or [W,H])")

# with torch.no_grad():
#     outputs = sam3_model(**inputs)

# results = sam3_processor.post_process_instance_segmentation(
#     outputs, threshold=THRESHOLD, mask_threshold=MASK_THRESHOLD,
#     target_sizes=inputs.get("original_sizes").tolist(),
# )[0]

# pred_boxes_raw = to_numpy(results["boxes"])
# print(f"\nPredicted boxes BEFORE /sam_scale (raw from post_process): \n{pred_boxes_raw}")
# print(f"Range: min={pred_boxes_raw.min() if len(pred_boxes_raw) else 'N/A'}, "
#       f"max={pred_boxes_raw.max() if len(pred_boxes_raw) else 'N/A'}")

# pred_boxes_scaled = pred_boxes_raw / sam_scale
# print(f"\nPredicted boxes AFTER /sam_scale: \n{pred_boxes_scaled}")
# print(f"Range: min={pred_boxes_scaled.min() if len(pred_boxes_scaled) else 'N/A'}, "
#       f"max={pred_boxes_scaled.max() if len(pred_boxes_scaled) else 'N/A'}")

# print(f"\nFor comparison, exemplar/GT boxes (full-res): {exemplar_boxes_fullres}")
# print(f"GT box range: min={gt_boxes.min()}, max={gt_boxes.max()}")

# %%
# pred_scores_np = to_numpy(results["scores"])

# print("=== Inputs to compute_detection_metrics ===")
# print("pred_boxes_scaled:", pred_boxes_scaled)
# print("pred_scores_np:", pred_scores_np)
# print("gt_boxes:", gt_boxes)

# # Temporarily expose the real exception instead of swallowing it
# import traceback

# pred_detections = sv.Detections(
#     xyxy=pred_boxes_scaled,
#     confidence=pred_scores_np,
#     class_id=np.zeros(len(pred_scores_np), dtype=int),
# )
# gt_detections = sv.Detections(
#     xyxy=gt_boxes,
#     class_id=np.zeros(len(gt_boxes), dtype=int),
# )

# try:
#     map_metric = MeanAveragePrecision()
#     result = map_metric.update([pred_detections], [gt_detections]).compute()
#     print("map50 SUCCESS:", result.map50)
# except Exception:
#     print("map50 THREW AN EXCEPTION:")
#     traceback.print_exc()

# # Now run your own IoU-matching logic directly, bypassing sv entirely
# metrics = compute_detection_metrics(pred_boxes_scaled, pred_scores_np, gt_boxes, iou_threshold=IOU_THRESHOLD)
# print("compute_detection_metrics output:", metrics)

# %%
#  SAM3 whole-image (no tiling) inference, exemplar boxes as prompts
def to_numpy(x):
    """Handles tensors (incl. bf16/fp16), lists of tensors, or plain arrays."""
    if torch.is_tensor(x):
        if x.dtype in (torch.bfloat16, torch.float16):
            x = x.float()
        return x.detach().cpu().numpy()
    if isinstance(x, (list, tuple)):
        if len(x) > 0 and torch.is_tensor(x[0]):
            x = [t.float() if t.dtype in (torch.bfloat16, torch.float16) else t for t in x]
            return torch.stack([t.detach().cpu() for t in x]).numpy()
        return np.array(x)
    return np.array(x)


def run_sam3_whole_image(image: Image.Image, exemplar_boxes_fullres: list,
                          threshold: float = THRESHOLD, mask_threshold: float = MASK_THRESHOLD):
    """
    exemplar_boxes_fullres: list of [x1,y1,x2,y2] in the ORIGINAL image's pixel coords.

    Mirrors your Exp2 logic exactly:
      - resize whole image to MAX_DIM
      - scale exemplar boxes into that resized space
      - single SAM3 forward pass, no tiling
      - scale predicted boxes back up to full-res, upsample masks to full-res

    Returns: pred_boxes_fullres (np.ndarray Nx4), pred_scores (np.ndarray N),
             pred_masks_fullres (np.ndarray N,H,W bool) or None if no detections
    """
    img_w, img_h = image.size
    image_sam, sam_scale = resize_for_sam3(image, MAX_DIM)

    input_boxes_xyxy = [[c * sam_scale for c in box] for box in exemplar_boxes_fullres]
    input_boxes = [input_boxes_xyxy]
    input_boxes_labels = [[1] * len(exemplar_boxes_fullres)]

    inputs = sam3_processor(
        images=image_sam,
        input_boxes=input_boxes,
        input_boxes_labels=input_boxes_labels,
        return_tensors="pt",
    ).to(sam3_model.device)

    with torch.no_grad():
        outputs = sam3_model(**inputs)

    results = sam3_processor.post_process_instance_segmentation(
        outputs, threshold=threshold, mask_threshold=mask_threshold,
        target_sizes=inputs.get("original_sizes").tolist(),
    )[0]

    print("Returned keys:", results.keys())
    print("Boxes:", len(results["boxes"]))
    print("Scores:", results["scores"])

    pred_boxes_np = to_numpy(results["boxes"])
    pred_scores_np = to_numpy(results["scores"])
    pred_masks_np = to_numpy(results["masks"])

    # Boxes/masks came back in image_sam's (resized) coordinate space -> rescale to full-res
    if len(pred_boxes_np) > 0:
        pred_boxes_np = pred_boxes_np / sam_scale

    full_res_masks = None
    if len(pred_masks_np) > 0:
        full_res_masks = np.zeros((len(pred_masks_np), img_h, img_w), dtype=bool)
        for i, m in enumerate(pred_masks_np):
            m_resized = cv2.resize(m.astype(np.uint8), (img_w, img_h), interpolation=cv2.INTER_NEAREST)
            full_res_masks[i] = m_resized.astype(bool)

    return pred_boxes_np, pred_scores_np, full_res_masks

# %%
# Metrics (identical logic/formulas to Exp1 -- mAP50, precision,
# recall, IoU1 = matched-only mean IoU, IoU2 = mean IoU over all GT)

def compute_iou_matrix(boxes1, boxes2):
    if len(boxes1) == 0 or len(boxes2) == 0:
        return np.zeros((len(boxes1), len(boxes2)))
    x1 = np.maximum(boxes1[:, None, 0], boxes2[None, :, 0])
    y1 = np.maximum(boxes1[:, None, 1], boxes2[None, :, 1])
    x2 = np.minimum(boxes1[:, None, 2], boxes2[None, :, 2])
    y2 = np.minimum(boxes1[:, None, 3], boxes2[None, :, 3])
    inter_w = np.clip(x2 - x1, 0, None)
    inter_h = np.clip(y2 - y1, 0, None)
    inter_area = inter_w * inter_h
    area1 = (boxes1[:, 2] - boxes1[:, 0]) * (boxes1[:, 3] - boxes1[:, 1])
    area2 = (boxes2[:, 2] - boxes2[:, 0]) * (boxes2[:, 3] - boxes2[:, 1])
    union_area = area1[:, None] + area2[None, :] - inter_area
    return np.where(union_area > 0, inter_area / union_area, 0.0)


def compute_detection_metrics(pred_boxes_np, pred_scores_np, gt_boxes, iou_threshold: float = 0.5) -> dict:
    pred_detections = sv.Detections(
        xyxy=pred_boxes_np if len(pred_boxes_np) else np.zeros((0, 4), dtype=np.float32),
        confidence=pred_scores_np if len(pred_scores_np) else np.zeros((0,), dtype=np.float32),
        class_id=np.zeros(len(pred_scores_np), dtype=int),
    )
    gt_detections = sv.Detections(
        xyxy=gt_boxes,
        class_id=np.zeros(len(gt_boxes), dtype=int),
    )
    try:
        map_metric = MeanAveragePrecision()
        result = map_metric.update([pred_detections], [gt_detections]).compute()
        map50 = float(result.map50)
    except Exception:
        map50 = 0.0 if len(gt_boxes) > 0 else float("nan")

    num_preds, num_gt = len(pred_boxes_np), len(gt_boxes)
    iou_matrix = compute_iou_matrix(pred_boxes_np, gt_boxes)

    matched_gt = set()
    true_positives = 0
    matched_ious = []
    pred_order = np.argsort(-pred_scores_np) if num_preds > 0 else []

    for pred_idx in pred_order:
        if num_gt == 0:
            break
        best_gt_idx = np.argmax(iou_matrix[pred_idx])
        best_iou = iou_matrix[pred_idx, best_gt_idx]
        if best_iou >= iou_threshold and best_gt_idx not in matched_gt:
            matched_gt.add(best_gt_idx)
            true_positives += 1
            matched_ious.append(best_iou)

    precision = true_positives / num_preds if num_preds > 0 else 0.0
    recall = true_positives / num_gt if num_gt > 0 else 0.0
    iou1_matched_only = float(np.mean(matched_ious)) if matched_ious else 0.0
    iou2_over_all_gt = float(np.sum(matched_ious) / num_gt) if num_gt > 0 else 0.0

    return {
        "map50": map50, "precision": precision, "recall": recall,
        "iou_matched": iou1_matched_only, "iou_all_gt": iou2_over_all_gt,
    }

# %%
#  Main automated loop -- Exp2 (no tiling), per-run + per-image logging
done_keys = set()
file_exists = os.path.exists(OUTPUT_CSV)
if file_exists:
    existing = pd.read_csv(OUTPUT_CSV)
    existing = existing[existing["experiment_name"] == EXPERIMENT_NAME]
    done_keys = set(zip(existing["image_ID"], existing["Prompt_ID"].astype(str)))
    print(f"Resuming: {len(done_keys)} rows already done for {EXPERIMENT_NAME}.")

csv_file = open(OUTPUT_CSV, "a", newline="")
csv_writer = csv.DictWriter(csv_file, fieldnames=CSV_COLUMNS)
if not file_exists:
    csv_writer.writeheader()

start_time = time.time()
n_runs = 0
image_times = []

#Only use images that have YOLO annotation files (third dimension is the label path)
valid_images = [rec for rec in image_records if rec[2] is not None]
n_total_images = len(valid_images)

#loop through every img
for img_idx, (folder, image_path, label_path, image_id) in enumerate(valid_images, start=1):
    image_t0 = time.time()

    image = Image.open(image_path).convert("RGB") #load img
    img_w, img_h = image.size #load dimensions
    gt_boxes = load_yolo_boxes(label_path, img_w, img_h, class_id=RUMEX_CLASS_ID)
    n_gt = len(gt_boxes)

    if n_gt == 0: #skip images without annotations
        print(f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id}: 0 GT boxes, skipped.")
        continue

    image_map50s = [] #to store mAP50 values for this img (all prompt results for 1 img)

    for anchor_idx in range(n_gt): #each GT bbox become a positive input bbox for SAM3
        exemplar_indices = select_exemplar_indices(n_gt, anchor_idx, N_EXEMPLARS, RNG)
        prompt_id = format_prompt_id(exemplar_indices)

        if (image_id, prompt_id) in done_keys: #skip completed runs (already evaluated and stored in csv)
            continue

        run_t0 = time.time()

        #create prompt boxes for SAM3
        exemplar_boxes_fullres = [gt_boxes[i].tolist() for i in exemplar_indices]

        #run SAM3
        pred_boxes_np, pred_scores_np, _ = run_sam3_whole_image(
            image, exemplar_boxes_fullres, threshold=THRESHOLD, mask_threshold=MASK_THRESHOLD
        )

        #calculate metrics
        metrics = compute_detection_metrics(pred_boxes_np, pred_scores_np, gt_boxes, iou_threshold=IOU_THRESHOLD)
        image_map50s.append(metrics["map50"])

        #save results to csv
        row = {
            "experiment_name": EXPERIMENT_NAME,
            "image_ID": image_id,
            "Prompt_ID": prompt_id,
            "Prompt_Type": PROMPT_TYPE,
            "mAP50": metrics["map50"],
            "precision": metrics["precision"],
            "recall": metrics["recall"],
            "IoU1": metrics["iou_matched"],
            "IoU2": metrics["iou_all_gt"],
        }
        csv_writer.writerow(row)
        csv_file.flush()
        n_runs += 1

        run_elapsed = time.time() - run_t0
        #this print is executed for every run in an image (let's say we have 5 GTs so this print
        #is executed 5 times at each time the anchor is 1 of the GTs and the other 2 are sampled randomly)
        print(
            f"    [{EXPERIMENT_NAME}] run #{n_runs} | image={image_id} | "
            f"anchor={anchor_idx} ({anchor_idx+1}/{n_gt}) | prompt_id={prompt_id} | "
            f"mAP50={metrics['map50']:.3f} | time={run_elapsed:.1f}s"
        )

        torch.cuda.empty_cache()

    image_elapsed = time.time() - image_t0
    image_times.append(image_elapsed)
    avg_time_per_image = np.mean(image_times)
    images_left = n_total_images - img_idx
    eta_seconds = images_left * avg_time_per_image

    map50_str = f"{np.mean(image_map50s):.3f}" if image_map50s else "N/A (all anchors already done, skipped)"

    #this print will run finally after finishing all runs per image
    print(
        f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id} done | "
        f"{n_gt} GT box(es) | image_mAP50_mean={map50_str} | "
        f"time={image_elapsed:.1f}s | avg/image={avg_time_per_image:.1f}s | "
        f"ETA={eta_seconds/60:.1f} min ({eta_seconds/3600:.2f} h)"
    )

csv_file.close()
total_elapsed = time.time() - start_time
print(f"\nFinished {EXPERIMENT_NAME}: {n_runs} new rows written to {OUTPUT_CSV}")
print(f"Total time: {total_elapsed/60:.1f} min ({total_elapsed/3600:.2f} h)")
# Out:
# Streaming output truncated to the last 5000 lines.
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 9
# Scores: tensor([0.8531, 0.5009, 0.4132, 0.6236, 0.6318, 0.5124, 0.8691, 0.4539, 0.4090],
#        device='cuda:0')
#     [E02_1] run #901 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=26 (27/48) | prompt_id=26+15+46 | mAP50=0.106 | time=3.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 3
# Scores: tensor([0.4486, 0.4275, 0.4730], device='cuda:0')
#     [E02_1] run #902 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=27 (28/48) | prompt_id=27+23+24 | mAP50=0.050 | time=2.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.4527, 0.5522, 0.7652, 0.4149, 0.4672, 0.5164], device='cuda:0')
#     [E02_1] run #903 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=28 (29/48) | prompt_id=28+47+45 | mAP50=0.069 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 4
# Scores: tensor([0.6026, 0.4773, 0.4971, 0.7417], device='cuda:0')
#     [E02_1] run #904 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=29 (30/48) | prompt_id=29+38+18 | mAP50=0.043 | time=2.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.5367, 0.5253, 0.4157, 0.6487, 0.7274, 0.4226], device='cuda:0')
#     [E02_1] run #905 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=30 (31/48) | prompt_id=30+22+26 | mAP50=0.050 | time=3.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 11
# Scores: tensor([0.5185, 0.4859, 0.7522, 0.5099, 0.8885, 0.7681, 0.5102, 0.8880, 0.5683,
#         0.4308, 0.4139], device='cuda:0')
#     [E02_1] run #906 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=31 (32/48) | prompt_id=31+15+30 | mAP50=0.098 | time=3.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 18
# Scores: tensor([0.9225, 0.5832, 0.7787, 0.5060, 0.4061, 0.4330, 0.4347, 0.4477, 0.5750,
#         0.4038, 0.5180, 0.5114, 0.4236, 0.5263, 0.4257, 0.5540, 0.4524, 0.5276],
#        device='cuda:0')
#     [E02_1] run #907 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=32 (33/48) | prompt_id=32+47+8 | mAP50=0.153 | time=3.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 29
# Scores: tensor([0.5961, 0.4151, 0.4803, 0.5923, 0.4971, 0.4059, 0.4767, 0.7421, 0.4417,
#         0.5514, 0.4011, 0.4453, 0.4590, 0.5694, 0.5234, 0.4069, 0.6646, 0.6040,
#         0.4944, 0.4481, 0.4735, 0.4494, 0.4672, 0.5254, 0.8415, 0.5577, 0.4580,
#         0.4447, 0.6710], device='cuda:0')
#     [E02_1] run #908 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=33 (34/48) | prompt_id=33+41+37 | mAP50=0.138 | time=4.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 24
# Scores: tensor([0.5005, 0.4472, 0.4879, 0.4835, 0.4640, 0.4625, 0.5665, 0.4116, 0.5057,
#         0.5880, 0.4195, 0.4348, 0.7045, 0.5034, 0.4427, 0.7379, 0.4375, 0.5173,
#         0.5464, 0.8055, 0.5709, 0.5103, 0.4292, 0.4308], device='cuda:0')
#     [E02_1] run #909 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=34 (35/48) | prompt_id=34+47+27 | mAP50=0.134 | time=4.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 25
# Scores: tensor([0.5509, 0.4434, 0.4283, 0.5504, 0.4200, 0.7741, 0.4993, 0.4326, 0.4085,
#         0.7590, 0.4375, 0.5603, 0.5640, 0.4606, 0.5942, 0.4993, 0.5223, 0.6516,
#         0.7025, 0.5009, 0.5869, 0.9079, 0.7749, 0.4950, 0.5308],
#        device='cuda:0')
#     [E02_1] run #910 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=35 (36/48) | prompt_id=35+19+30 | mAP50=0.188 | time=4.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 18
# Scores: tensor([0.6154, 0.5421, 0.4580, 0.5238, 0.4078, 0.7482, 0.8722, 0.4516, 0.4910,
#         0.5789, 0.5447, 0.7009, 0.6698, 0.6095, 0.5453, 0.8979, 0.4083, 0.4547],
#        device='cuda:0')
#     [E02_1] run #911 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=36 (37/48) | prompt_id=36+19+38 | mAP50=0.167 | time=3.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 13
# Scores: tensor([0.4189, 0.6124, 0.4222, 0.7275, 0.4663, 0.4402, 0.4275, 0.4798, 0.4840,
#         0.4753, 0.4764, 0.4039, 0.4357], device='cuda:0')
#     [E02_1] run #912 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=37 (38/48) | prompt_id=37+17+44 | mAP50=0.109 | time=3.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 33
# Scores: tensor([0.5729, 0.4238, 0.4947, 0.5728, 0.6629, 0.5904, 0.5239, 0.5732, 0.5657,
#         0.6424, 0.5661, 0.5223, 0.5274, 0.6777, 0.7643, 0.6426, 0.5613, 0.5401,
#         0.5560, 0.7970, 0.6437, 0.5371, 0.4234, 0.5024, 0.4217, 0.4247, 0.6444,
#         0.4546, 0.8140, 0.6799, 0.6097, 0.5227, 0.5956], device='cuda:0')
#     [E02_1] run #913 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=38 (39/48) | prompt_id=38+34+43 | mAP50=0.104 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 29
# Scores: tensor([0.4487, 0.4222, 0.5209, 0.4810, 0.8385, 0.5535, 0.7152, 0.4892, 0.5062,
#         0.4930, 0.6354, 0.5908, 0.4153, 0.4484, 0.4073, 0.7038, 0.5159, 0.4763,
#         0.4416, 0.4350, 0.4540, 0.4678, 0.4499, 0.5714, 0.6130, 0.4320, 0.4865,
#         0.7776, 0.5968], device='cuda:0')
#     [E02_1] run #914 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=39 (40/48) | prompt_id=39+15+35 | mAP50=0.103 | time=4.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 12
# Scores: tensor([0.9201, 0.4340, 0.4189, 0.8613, 0.4111, 0.6215, 0.5694, 0.6228, 0.5208,
#         0.5812, 0.4496, 0.6622], device='cuda:0')
#     [E02_1] run #915 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=40 (41/48) | prompt_id=40+20+46 | mAP50=0.155 | time=3.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 28
# Scores: tensor([0.4188, 0.4351, 0.4492, 0.5643, 0.7833, 0.4260, 0.4702, 0.5134, 0.5017,
#         0.4085, 0.5861, 0.5304, 0.4523, 0.5095, 0.4126, 0.6180, 0.5806, 0.4975,
#         0.4905, 0.6119, 0.5745, 0.7977, 0.4907, 0.4152, 0.4298, 0.4005, 0.8831,
#         0.4555], device='cuda:0')
#     [E02_1] run #916 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=41 (42/48) | prompt_id=41+21+17 | mAP50=0.141 | time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 27
# Scores: tensor([0.4353, 0.4030, 0.4483, 0.5474, 0.7889, 0.4596, 0.4934, 0.7966, 0.5996,
#         0.5219, 0.8475, 0.5384, 0.4079, 0.6342, 0.4712, 0.4718, 0.4202, 0.4423,
#         0.5281, 0.4320, 0.6669, 0.4061, 0.6841, 0.5081, 0.5490, 0.4577, 0.5394],
#        device='cuda:0')
#     [E02_1] run #917 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=42 (43/48) | prompt_id=42+30+16 | mAP50=0.116 | time=4.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 28
# Scores: tensor([0.4583, 0.4743, 0.4107, 0.7314, 0.4972, 0.6609, 0.4982, 0.5075, 0.5081,
#         0.5941, 0.5239, 0.5190, 0.5042, 0.4427, 0.6254, 0.4594, 0.5410, 0.4974,
#         0.8301, 0.5804, 0.5729, 0.7090, 0.4424, 0.5059, 0.4450, 0.5008, 0.4757,
#         0.4946], device='cuda:0')
#     [E02_1] run #918 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=43 (44/48) | prompt_id=43+17+15 | mAP50=0.123 | time=4.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 26
# Scores: tensor([0.5176, 0.4707, 0.5109, 0.5172, 0.4435, 0.6296, 0.7268, 0.5633, 0.5150,
#         0.5194, 0.6538, 0.5068, 0.5764, 0.5230, 0.4944, 0.5111, 0.5037, 0.4117,
#         0.8652, 0.5473, 0.8631, 0.6761, 0.4307, 0.4109, 0.5270, 0.4942],
#        device='cuda:0')
#     [E02_1] run #919 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=44 (45/48) | prompt_id=44+3+15 | mAP50=0.131 | time=4.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 27
# Scores: tensor([0.4624, 0.5452, 0.4340, 0.4256, 0.4726, 0.4870, 0.4604, 0.4473, 0.4740,
#         0.5383, 0.7790, 0.4316, 0.4652, 0.5420, 0.4341, 0.4783, 0.4134, 0.6484,
#         0.4623, 0.5956, 0.4745, 0.6073, 0.5821, 0.5586, 0.5084, 0.4096, 0.4887],
#        device='cuda:0')
#     [E02_1] run #920 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=45 (46/48) | prompt_id=45+4+24 | mAP50=0.090 | time=4.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 13
# Scores: tensor([0.8159, 0.5440, 0.4122, 0.5933, 0.4104, 0.4776, 0.6449, 0.4467, 0.4805,
#         0.4554, 0.5008, 0.4899, 0.4151], device='cuda:0')
#     [E02_1] run #921 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=46 (47/48) | prompt_id=46+7+23 | mAP50=0.203 | time=3.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 5
# Scores: tensor([0.4062, 0.6610, 0.6233, 0.5499, 0.4774], device='cuda:0')
#     [E02_1] run #922 | image=20230426_Wallenwil/DJI_20230426111205_0193 | anchor=47 (48/48) | prompt_id=47+44+18 | mAP50=0.043 | time=3.0s
# [E02_1] (93/179) 20230426_Wallenwil/DJI_20230426111205_0193 done | 48 GT box(es) | image_mAP50_mean=0.124 | time=214.4s | avg/image=57.3s | ETA=82.1 min (1.37 h)
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 26
# Scores: tensor([0.6715, 0.4700, 0.7951, 0.4059, 0.5489, 0.7004, 0.4884, 0.4181, 0.5380,
#         0.5978, 0.4794, 0.5108, 0.9242, 0.5977, 0.5028, 0.7255, 0.5181, 0.5280,
#         0.6936, 0.4097, 0.4360, 0.7456, 0.6805, 0.4060, 0.5276, 0.5849],
#        device='cuda:0')
#     [E02_1] run #923 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=0 (1/66) | prompt_id=0+14+51 | mAP50=0.166 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 29
# Scores: tensor([0.5276, 0.6253, 0.4455, 0.5118, 0.4075, 0.4646, 0.6780, 0.8666, 0.5126,
#         0.4349, 0.6086, 0.6980, 0.5442, 0.6688, 0.4977, 0.5520, 0.5036, 0.6281,
#         0.4466, 0.4845, 0.4208, 0.5977, 0.4154, 0.4629, 0.6092, 0.5446, 0.7575,
#         0.4453, 0.5779], device='cuda:0')
#     [E02_1] run #924 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=1 (2/66) | prompt_id=1+49+50 | mAP50=0.202 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 28
# Scores: tensor([0.4161, 0.4751, 0.6188, 0.6815, 0.5019, 0.5153, 0.7160, 0.8536, 0.4369,
#         0.4874, 0.4013, 0.4942, 0.6790, 0.4906, 0.7771, 0.5665, 0.4343, 0.5264,
#         0.4983, 0.7319, 0.4707, 0.5094, 0.7456, 0.4033, 0.5182, 0.4840, 0.6476,
#         0.5490], device='cuda:0')
#     [E02_1] run #925 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor
| time=5.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 32
# Scores: tensor([0.7307, 0.5584, 0.6394, 0.4023, 0.4825, 0.8356, 0.7526, 0.5078, 0.4869,
#         0.6171, 0.5364, 0.7205, 0.5352, 0.8537, 0.5695, 0.4064, 0.6356, 0.4054,
#         0.6778, 0.5061, 0.4966, 0.5910, 0.4168, 0.5927, 0.5020, 0.6097, 0.7963,
#         0.4328, 0.7121, 0.5997, 0.4652, 0.6367], device='cuda:0')
#     [E02_1] run #932 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=9 (10/66) | prompt_id=9+40+2 | mAP50=0.175 | time=5.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 27
# Scores: tensor([0.4239, 0.4807, 0.4558, 0.4119, 0.4084, 0.4582, 0.4497, 0.4198, 0.4007,
#         0.5095, 0.4104, 0.4955, 0.4825, 0.4343, 0.4009, 0.4680, 0.4136, 0.5013,
#         0.4144, 0.4203, 0.4492, 0.5003, 0.5026, 0.4332, 0.4070, 0.4214, 0.4409],
#        device='cuda:0')
#     [E02_1] run #933 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=10 (11/66) | prompt_id=10+44+60 | mAP50=0.001 | time=4.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 18
# Scores: tensor([0.5025, 0.4127, 0.4490, 0.4397, 0.4127, 0.5593, 0.6008, 0.4141, 0.8644,
#         0.5338, 0.4813, 0.4213, 0.4270, 0.5736, 0.6875, 0.6030, 0.4610, 0.5739],
#        device='cuda:0')
#     [E02_1] run #934 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=11 (12/66) | prompt_id=11+1+5 | mAP50=0.153 | time=3.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 36
# Scores: tensor([0.6289, 0.6318, 0.4978, 0.5165, 0.6368, 0.6895, 0.4375, 0.6264, 0.6923,
#         0.5503, 0.5889, 0.4226, 0.6107, 0.4239, 0.4916, 0.4744, 0.5423, 0.5034,
#         0.7000, 0.5559, 0.4691, 0.5508, 0.5079, 0.5430, 0.4935, 0.5447, 0.7306,
#         0.4237, 0.7420, 0.5026, 0.5335, 0.6815, 0.5640, 0.5418, 0.6736, 0.6127],
#        device='cuda:0')
#     [E02_1] run #935 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=12 (13/66) | prompt_id=12+48+9 | mAP50=0.199 | time=5.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 26
# Scores: tensor([0.4642, 0.6029, 0.4557, 0.5372, 0.5423, 0.4743, 0.5337, 0.5655, 0.4018,
#         0.5139, 0.5194, 0.5360, 0.6027, 0.4439, 0.5134, 0.4619, 0.4382, 0.6100,
#         0.6300, 0.5688, 0.4827, 0.4247, 0.4429, 0.5625, 0.4411, 0.4654],
#        device='cuda:0')
#     [E02_1] run #936 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=13 (14/66) | prompt_id=13+33+16 | mAP50=0.160 | time=4.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 33
# Scores: tensor([0.5151, 0.5372, 0.5761, 0.5554, 0.6144, 0.4259, 0.8382, 0.5113, 0.5761,
#         0.5163, 0.5768, 0.7274, 0.5193, 0.6674, 0.4031, 0.4610, 0.4065, 0.6237,
#         0.4526, 0.7662, 0.4602, 0.6407, 0.4987, 0.6918, 0.7309, 0.4766, 0.4056,
#         0.5132, 0.6250, 0.5928, 0.5389, 0.6148, 0.5147], device='cuda:0')
#     [E02_1] run #937 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=14 (15/66) | prompt_id=14+65+30 | mAP50=0.177 | time=5.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 30
# Scores: tensor([0.5079, 0.5568, 0.6158, 0.5302, 0.6257, 0.5117, 0.6556, 0.4806, 0.5168,
#         0.5679, 0.4189, 0.5666, 0.5849, 0.4179, 0.6499, 0.5966, 0.4276, 0.4601,
#         0.5125, 0.5178, 0.4007, 0.4033, 0.5321, 0.5109, 0.5034, 0.6753, 0.7275,
#         0.4408, 0.6858, 0.6139], device='cuda:0')
#     [E02_1] run #938 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=15 (16/66) | prompt_id=15+37+52 | mAP50=0.167 | time=5.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 25
# Scores: tensor([0.4683, 0.5245, 0.6851, 0.6625, 0.6043, 0.5968, 0.8234, 0.6495, 0.4705,
#         0.5413, 0.4928, 0.6655, 0.4105, 0.6417, 0.4705, 0.5988, 0.4962, 0.4312,
#         0.5427, 0.7579, 0.4170, 0.5412, 0.4513, 0.4610, 0.5147],
#        device='cuda:0')
#     [E02_1] run #939 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=16 (17/66) | prompt_id=16+22+58 | mAP50=0.159 | time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 23
# Scores: tensor([0.5139, 0.5396, 0.7599, 0.5669, 0.4051, 0.4652, 0.6909, 0.6370, 0.4096,
#         0.6731, 0.4276, 0.5134, 0.5380, 0.5205, 0.8579, 0.4141, 0.4431, 0.8114,
#         0.5841, 0.4036, 0.5248, 0.6537, 0.4601], device='cuda:0')
#     [E02_1] run #940 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=17 (18/66) | prompt_id=17+64+25 | mAP50=0.108 | time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 30
# Scores: tensor([0.8570, 0.5004, 0.6178, 0.6425, 0.7342, 0.5572, 0.6193, 0.5464, 0.6903,
#         0.6375, 0.7766, 0.6114, 0.4297, 0.5921, 0.5307, 0.4958, 0.7025, 0.5368,
#         0.5649, 0.5888, 0.4146, 0.4379, 0.4891, 0.4956, 0.7992, 0.4038, 0.4121,
#         0.7559, 0.6749, 0.6519], device='cuda:0')
#     [E02_1] run #941 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=18 (19/66) | prompt_id=18+3+37 | mAP50=0.160 | time=5.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 37
# Scores: tensor([0.5693, 0.7380, 0.7289, 0.6800, 0.5975, 0.5207, 0.4059, 0.5308, 0.5454,
#         0.6133, 0.6099, 0.4916, 0.5490, 0.4250, 0.6109, 0.7226, 0.4848, 0.6095,
#         0.4094, 0.6629, 0.7452, 0.6172, 0.5434, 0.4039, 0.4196, 0.6895, 0.4131,
#         0.4730, 0.5422, 0.7030, 0.7840, 0.4140, 0.5361, 0.6645, 0.5361, 0.4023,
#         0.7051], device='cuda:0')
#     [E02_1] run #942 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=19 (20/66) | prompt_id=19+10+44 | mAP50=0.187 | time=5.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 38
# Scores: tensor([0.7528, 0.4079, 0.6011, 0.7095, 0.8026, 0.5496, 0.7600, 0.5648, 0.4779,
#         0.6419, 0.7037, 0.4106, 0.5698, 0.6088, 0.7624, 0.6425, 0.4138, 0.4953,
#         0.6209, 0.6739, 0.5548, 0.7213, 0.6204, 0.6106, 0.4444, 0.6804, 0.4250,
#         0.5339, 0.5135, 0.4042, 0.8039, 0.4793, 0.4330, 0.5294, 0.5392, 0.6579,
#         0.5121, 0.6672], device='cuda:0')
#     [E02_1] run #943 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=20 (21/66) | prompt_id=20+9+50 | mAP50=0.207 | time=6.1s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 38
# Scores: tensor([0.7220, 0.5374, 0.7199, 0.5405, 0.4022, 0.4101, 0.6606, 0.4501, 0.7853,
#         0.5109, 0.5870, 0.5784, 0.7440, 0.5602, 0.5047, 0.5751, 0.6905, 0.4710,
#         0.5623, 0.5583, 0.4702, 0.6416, 0.4723, 0.5103, 0.6306, 0.5392, 0.7147,
#         0.5323, 0.7633, 0.4245, 0.4880, 0.5605, 0.6546, 0.5097, 0.7280, 0.4083,
#         0.4770, 0.6591], device='cuda:0')
#     [E02_1] run #944 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=21 (22/66) | prompt_id=21+35+13 | mAP50=0.145 | time=5.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 22
# Scores: tensor([0.4474, 0.4691, 0.6730, 0.5651, 0.4980, 0.8374, 0.5887, 0.4751, 0.4789,
#         0.6898, 0.4573, 0.6808, 0.4056, 0.4676, 0.5363, 0.6293, 0.4918, 0.4170,
#         0.5766, 0.8521, 0.7836, 0.4593], device='cuda:0')
#     [E02_1] run #945 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=22 (23/66) | prompt_id=22+62+4 | mAP50=0.140 | time=4.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 29
# Scores: tensor([0.4206, 0.6597, 0.4399, 0.8567, 0.5974, 0.5325, 0.4110, 0.6579, 0.5819,
#         0.4616, 0.5443, 0.4326, 0.6704, 0.5567, 0.6240, 0.5042, 0.5671, 0.5141,
#         0.4868, 0.6300, 0.4543, 0.4468, 0.5644, 0.4276, 0.7610, 0.5079, 0.4497,
#         0.5378, 0.4548], device='cuda:0')
#     [E02_1] run #946 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=23 (24/66) | prompt_id=23+51+56 | mAP50=0.188 | time=5.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 3
# Scores: tensor([0.4295, 0.4098, 0.4282], device='cuda:0')
#     [E02_1] run #947 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=24 (25/66) | prompt_id=24+12+61 | mAP50=0.050 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 12
# Scores: tensor([0.6792, 0.4324, 0.5271, 0.5117, 0.4851, 0.4558, 0.4039, 0.4556, 0.4811,
#         0.8131, 0.4467, 0.4698], device='cuda:0')
#     [E02_1] run #948 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=25 (26/66) | prompt_id=25+62+58 | mAP50=0.061 | time=3.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 25
# Scores: tensor([0.4488, 0.6682, 0.6400, 0.8056, 0.4953, 0.4105, 0.4062, 0.5122, 0.4023,
#         0.4881, 0.4375, 0.6348, 0.4023, 0.4513, 0.5182, 0.4257, 0.5489, 0.4516,
#         0.5423, 0.4818, 0.6229, 0.7500, 0.6635, 0.5516, 0.5241],
#        device='cuda:0')
#     [E02_1] run #949 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=26 (27/66) | prompt_id=26+7+23 | mAP50=0.152 | time=4.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 14
# Scores: tensor([0.4284, 0.4242, 0.4123, 0.4217, 0.4539, 0.4188, 0.4179, 0.4171, 0.4202,
#         0.4433, 0.7211, 0.4108, 0.4254, 0.4222], device='cuda:0')
#     [E02_1] run #950 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=27 (28/66) | prompt_id=27+24+53 | mAP50=0.044 | time=4.1s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 35
# Scores: tensor([0.6765, 0.6994, 0.5562, 0.6062, 0.5338, 0.4235, 0.4369, 0.4955, 0.5676,
#         0.4849, 0.4443, 0.5016, 0.6804, 0.4439, 0.5332, 0.6243, 0.4894, 0.4323,
#         0.4031, 0.6347, 0.4194, 0.5286, 0.5117, 0.5179, 0.4423, 0.4052, 0.5803,
#         0.4552, 0.8718, 0.6996, 0.5103, 0.4510, 0.4339, 0.5659, 0.5876],
#        device='cuda:0')
#     [E02_1] run #951 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=28 (29/66) | prompt_id=28+31+15 | mAP50=0.187 | time=5.1s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 33
# Scores: tensor([0.6434, 0.4727, 0.4064, 0.4336, 0.4988, 0.6515, 0.6031, 0.5907, 0.5830,
#         0.4288, 0.4649, 0.4148, 0.4953, 0.6913, 0.7792, 0.6652, 0.4524, 0.5048,
#         0.4357, 0.6495, 0.8640, 0.4669, 0.5367, 0.4758, 0.4917, 0.4440, 0.4381,
#         0.7597, 0.4360, 0.7760, 0.5187, 0.5434, 0.4203], device='cuda:0')
#     [E02_1] run #952 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=29 (30/66) | prompt_id=29+41+64 | mAP50=0.205 | time=5.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 31
# Scores: tensor([0.5811, 0.5747, 0.6213, 0.5074, 0.4385, 0.6204, 0.5806, 0.4814, 0.7349,
#         0.5630, 0.5484, 0.6120, 0.5093, 0.5648, 0.4142, 0.5301, 0.4758, 0.6341,
#         0.6436, 0.5553, 0.5393, 0.4292, 0.4330, 0.4170, 0.5490, 0.7120, 0.4061,
#         0.6896, 0.4211, 0.6122, 0.5129], device='cuda:0')
#     [E02_1] run #953 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=30 (31/66) | prompt_id=30+60+39 | mAP50=0.179 | time=5.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 4
# Scores: tensor([0.4081, 0.4145, 0.6551, 0.4292], device='cuda:0')
#     [E02_1] run #954 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=31 (32/66) | prompt_id=31+24+60 | mAP50=0.050 | time=2.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 31
# Scores: tensor([0.7678, 0.7275, 0.6738, 0.6001, 0.6849, 0.5233, 0.6401, 0.5290, 0.4319,
#         0.6116, 0.5349, 0.5408, 0.5734, 0.7295, 0.4527, 0.6004, 0.6161, 0.4408,
#         0.6944, 0.5112, 0.5646, 0.5875, 0.4901, 0.5939, 0.6070, 0.5645, 0.7623,
#         0.4648, 0.6541, 0.5516, 0.5282], device='cuda:0')
#     [E02_1] run #955 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=32 (33/66) | prompt_id=32+8+26 | mAP50=0.195 | time=4.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 31
# Scores: tensor([0.4146, 0.5856, 0.4753, 0.5903, 0.4507, 0.6236, 0.4924, 0.5762, 0.4730,
#         0.4041, 0.5153, 0.6807, 0.4752, 0.5714, 0.6198, 0.5731, 0.5677, 0.5567,
#         0.4800, 0.5092, 0.4071, 0.5034, 0.5163, 0.5177, 0.5355, 0.5674, 0.6549,
#         0.4438, 0.5655, 0.4819, 0.4996], device='cuda:0')
#     [E02_1] run #956 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=33 (34/66) | prompt_id=33+52+57 | mAP50=0.183 | time=5.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 31
# Scores: tensor([0.7012, 0.5591, 0.4635, 0.8485, 0.4837, 0.6382, 0.6860, 0.6302, 0.6586,
#         0.6448, 0.6342, 0.5200, 0.6120, 0.7773, 0.7390, 0.4381, 0.5228, 0.6935,
#         0.5373, 0.4360, 0.7105, 0.5740, 0.5581, 0.6217, 0.5545, 0.8068, 0.5528,
#         0.7143, 0.6452, 0.4060, 0.4755], device='cuda:0')
#     [E02_1] run #957 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=34 (35/66) | prompt_id=34+4+54 | mAP50=0.187 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes:
| time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 30
# Scores: tensor([0.5079, 0.6181, 0.6592, 0.5982, 0.5190, 0.6146, 0.8077, 0.6785, 0.6030,
#         0.4292, 0.5060, 0.5327, 0.6832, 0.5938, 0.6866, 0.6265, 0.5285, 0.6698,
#         0.5359, 0.5221, 0.4974, 0.4695, 0.5022, 0.5250, 0.4327, 0.5087, 0.7697,
#         0.6187, 0.4495, 0.7952], device='cuda:0')
#     [E02_1] run #964 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=41 (42/66) | prompt_id=41+40+51 | mAP50=0.174 | time=5.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 37
# Scores: tensor([0.7265, 0.4997, 0.6977, 0.6187, 0.5769, 0.5374, 0.5949, 0.5281, 0.5093,
#         0.5115, 0.5415, 0.8537, 0.4027, 0.5834, 0.7288, 0.4719, 0.5185, 0.4181,
#         0.6686, 0.5037, 0.5280, 0.6097, 0.4065, 0.6038, 0.7116, 0.6707, 0.5221,
#         0.7732, 0.5305, 0.5717, 0.4599, 0.6816, 0.6956, 0.4791, 0.4078, 0.5198,
#         0.6554], device='cuda:0')
#     [E02_1] run #965 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=42 (43/66) | prompt_id=42+37+2 | mAP50=0.164 | time=5.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 24
# Scores: tensor([0.4567, 0.7069, 0.4993, 0.4646, 0.4210, 0.6056, 0.4784, 0.4998, 0.4447,
#         0.4674, 0.4689, 0.4553, 0.4746, 0.4717, 0.4586, 0.4902, 0.5032, 0.4477,
#         0.4579, 0.4069, 0.5563, 0.4649, 0.4030, 0.5021], device='cuda:0')
#     [E02_1] run #966 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=43 (44/66) | prompt_id=43+62+33 | mAP50=0.172 | time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 36
# Scores: tensor([0.6062, 0.6041, 0.5225, 0.6776, 0.5786, 0.5611, 0.6601, 0.4071, 0.6322,
#         0.6006, 0.5919, 0.6543, 0.4259, 0.6284, 0.4235, 0.4779, 0.5926, 0.6188,
#         0.4529, 0.4668, 0.7047, 0.5654, 0.5362, 0.5951, 0.5713, 0.4545, 0.5091,
#         0.7470, 0.4901, 0.7021, 0.7470, 0.4275, 0.5010, 0.6674, 0.5259, 0.5727],
#        device='cuda:0')
#     [E02_1] run #967 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=44 (45/66) | prompt_id=44+29+13 | mAP50=0.192 | time=5.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 31
# Scores: tensor([0.5226, 0.6226, 0.4183, 0.4900, 0.5415, 0.5625, 0.5712, 0.4803, 0.5230,
#         0.5396, 0.4607, 0.4116, 0.4346, 0.5496, 0.5717, 0.6241, 0.4816, 0.5079,
#         0.4452, 0.4419, 0.5335, 0.4669, 0.6517, 0.6681, 0.4181, 0.5105, 0.4734,
#         0.4867, 0.6314, 0.4876, 0.5576], device='cuda:0')
#     [E02_1] run #968 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=45 (46/66) | prompt_id=45+12+36 | mAP50=0.184 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 32
# Scores: tensor([0.5092, 0.5562, 0.7076, 0.5159, 0.6610, 0.6710, 0.5994, 0.5377, 0.4637,
#         0.5060, 0.5757, 0.4910, 0.4925, 0.7002, 0.5684, 0.6748, 0.6515, 0.6112,
#         0.7635, 0.4153, 0.6391, 0.5320, 0.5294, 0.4033, 0.4051, 0.5741, 0.4217,
#         0.7642, 0.4398, 0.5231, 0.4275, 0.4704], device='cuda:0')
#     [E02_1] run #969 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=46 (47/66) | prompt_id=46+12+22 | mAP50=0.197 | time=5.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 10
# Scores: tensor([0.4015, 0.6299, 0.5101, 0.4024, 0.4162, 0.4161, 0.4748, 0.8724, 0.4061,
#         0.4496], device='cuda:0')
#     [E02_1] run #970 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=47 (48/66) | prompt_id=47+62+32 | mAP50=0.102 | time=3.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 33
# Scores: tensor([0.5136, 0.5518, 0.4547, 0.6091, 0.4532, 0.4914, 0.6890, 0.4741, 0.6061,
#         0.4968, 0.4326, 0.4635, 0.5542, 0.6677, 0.5263, 0.4404, 0.4988, 0.6380,
#         0.4339, 0.7778, 0.5004, 0.6765, 0.8323, 0.4168, 0.6693, 0.7315, 0.4481,
#         0.7956, 0.4069, 0.4420, 0.4026, 0.6045, 0.5835], device='cuda:0')
#     [E02_1] run #971 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=48 (49/66) | prompt_id=48+25+14 | mAP50=0.188 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 32
# Scores: tensor([0.4731, 0.4393, 0.4533, 0.5574, 0.5014, 0.4945, 0.5755, 0.6454, 0.5269,
#         0.4204, 0.5439, 0.5945, 0.4768, 0.4486, 0.4312, 0.6246, 0.5880, 0.8352,
#         0.4461, 0.4859, 0.5283, 0.4428, 0.4711, 0.4600, 0.4711, 0.6958, 0.4404,
#         0.6955, 0.4302, 0.4255, 0.5332, 0.5087], device='cuda:0')
#     [E02_1] run #972 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=49 (50/66) | prompt_id=49+64+26 | mAP50=0.191 | time=5.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 36
# Scores: tensor([0.4679, 0.4004, 0.6650, 0.5591, 0.7190, 0.5756, 0.7216, 0.6295, 0.7426,
#         0.4630, 0.6402, 0.5609, 0.6138, 0.4054, 0.4393, 0.6507, 0.5344, 0.5831,
#         0.5591, 0.5407, 0.7250, 0.5792, 0.5876, 0.6122, 0.4379, 0.5479, 0.4286,
#         0.5599, 0.5712, 0.4287, 0.7815, 0.4504, 0.6449, 0.5600, 0.7441, 0.6691],
#        device='cuda:0')
#     [E02_1] run #973 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=50 (51/66) | prompt_id=50+5+37 | mAP50=0.175 | time=5.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 32
# Scores: tensor([0.5937, 0.5204, 0.6696, 0.4172, 0.5164, 0.4902, 0.4572, 0.4961, 0.5361,
#         0.6454, 0.4467, 0.5290, 0.4646, 0.4192, 0.5467, 0.4024, 0.6444, 0.6070,
#         0.5207, 0.8554, 0.5961, 0.4208, 0.5856, 0.4668, 0.4618, 0.4483, 0.5557,
#         0.4345, 0.5410, 0.7112, 0.4065, 0.4247], device='cuda:0')
#     [E02_1] run #974 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=51 (52/66) | prompt_id=51+64+57 | mAP50=0.172 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 18
# Scores: tensor([0.4835, 0.5425, 0.4209, 0.8316, 0.6294, 0.5685, 0.4665, 0.5962, 0.5361,
#         0.4524, 0.5524, 0.4085, 0.4361, 0.5457, 0.6714, 0.8479, 0.5144, 0.5011],
#        device='cuda:0')
#     [E02_1] run #975 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=52 (53/66) | prompt_id=52+23+40 | mAP50=0.135 | time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 25
# Scores: tensor([0.7250, 0.6199, 0.7232, 0.5287, 0.6409, 0.5371, 0.6482, 0.5687, 0.4370,
#         0.4905, 0.6842, 0.5800, 0.8736, 0.4422, 0.5165, 0.5562, 0.7417, 0.8126,
#         0.4680, 0.4514, 0.5418, 0.4115, 0.4225, 0.5664, 0.6098],
#        device='cuda:0')
#     [E02_1] run #976 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=53 (54/66) | prompt_id=53+28+8 | mAP50=0.150 | time=4.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 28
# Scores: tensor([0.6877, 0.5449, 0.5480, 0.6456, 0.5378, 0.4935, 0.6168, 0.6984, 0.5894,
#         0.4915, 0.6742, 0.5876, 0.4944, 0.5389, 0.4117, 0.4526, 0.8467, 0.4332,
#         0.6742, 0.5130, 0.5683, 0.4488, 0.4262, 0.4473, 0.6995, 0.5534, 0.7674,
#         0.6103], device='cuda:0')
#     [E02_1] run #977 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=54 (55/66) | prompt_id=54+2+13 | mAP50=0.165 | time=4.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 21
# Scores: tensor([0.6589, 0.8549, 0.4598, 0.8607, 0.4909, 0.4649, 0.6097, 0.4152, 0.4208,
#         0.6742, 0.6701, 0.4259, 0.4161, 0.6252, 0.5887, 0.5141, 0.7486, 0.6319,
#         0.7548, 0.4057, 0.4921], device='cuda:0')
#     [E02_1] run #978 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=55 (56/66) | prompt_id=55+65+23 | mAP50=0.142 | time=4.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 10
# Scores: tensor([0.5503, 0.5210, 0.4607, 0.4924, 0.4023, 0.5080, 0.4059, 0.4440, 0.7296,
#         0.4392], device='cuda:0')
#     [E02_1] run #979 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=56 (57/66) | prompt_id=56+42+62 | mAP50=0.040 | time=3.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 30
# Scores: tensor([0.4716, 0.5841, 0.6305, 0.4553, 0.5221, 0.4990, 0.5625, 0.5605, 0.5014,
#         0.5208, 0.6086, 0.4184, 0.4907, 0.5536, 0.5199, 0.5713, 0.4324, 0.4939,
#         0.6280, 0.4379, 0.5323, 0.5112, 0.4498, 0.6619, 0.6927, 0.5015, 0.4530,
#         0.6085, 0.5047, 0.5825], device='cuda:0')
#     [E02_1] run #980 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=57 (58/66) | prompt_id=57+13+45 | mAP50=0.191 | time=4.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 30
# Scores: tensor([0.6102, 0.6876, 0.6799, 0.6244, 0.6253, 0.4410, 0.5114, 0.6563, 0.5861,
#         0.5065, 0.5787, 0.5442, 0.6038, 0.6651, 0.4611, 0.5205, 0.5881, 0.4542,
#         0.7202, 0.4603, 0.5702, 0.4682, 0.6683, 0.5349, 0.4574, 0.4028, 0.6334,
#         0.7580, 0.5115, 0.5770], device='cuda:0')
#     [E02_1] run #981 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=58 (59/66) | prompt_id=58+19+33 | mAP50=0.184 | time=5.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 26
# Scores: tensor([0.7037, 0.8426, 0.7218, 0.6300, 0.5538, 0.4384, 0.4591, 0.5470, 0.6197,
#         0.4721, 0.8647, 0.5910, 0.7343, 0.5191, 0.5772, 0.4290, 0.6829, 0.4897,
#         0.5253, 0.6163, 0.8142, 0.6401, 0.5490, 0.4365, 0.5413, 0.4515],
#        device='cuda:0')
#     [E02_1] run #982 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=59 (60/66) | prompt_id=59+2+24 | mAP50=0.151 | time=5.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 30
# Scores: tensor([0.4913, 0.8138, 0.4093, 0.5063, 0.4043, 0.6010, 0.5485, 0.5774, 0.5860,
#         0.6711, 0.5256, 0.5870, 0.5464, 0.6106, 0.6404, 0.5810, 0.4195, 0.6341,
#         0.6675, 0.5258, 0.4798, 0.4300, 0.4491, 0.5224, 0.4813, 0.4471, 0.5671,
#         0.7550, 0.4025, 0.4239], device='cuda:0')
#     [E02_1] run #983 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=60 (61/66) | prompt_id=60+59+49 | mAP50=0.163 | time=4.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.4190, 0.4012, 0.4246, 0.4032, 0.4325, 0.4565], device='cuda:0')
#     [E02_1] run #984 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=61 (62/66) | prompt_id=61+7+58 | mAP50=0.000 | time=3.1s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 20
# Scores: tensor([0.4784, 0.4536, 0.6977, 0.5526, 0.4077, 0.6915, 0.9302, 0.7029, 0.6005,
#         0.6367, 0.6021, 0.5001, 0.7078, 0.6487, 0.4432, 0.6817, 0.7251, 0.4471,
#         0.5198, 0.5336], device='cuda:0')
#     [E02_1] run #985 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=62 (63/66) | prompt_id=62+3+0 | mAP50=0.088 | time=4.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 28
# Scores: tensor([0.8340, 0.6560, 0.6324, 0.5331, 0.5900, 0.5796, 0.6494, 0.5937, 0.4887,
#         0.4347, 0.6476, 0.5661, 0.5223, 0.5606, 0.6034, 0.4005, 0.6637, 0.4610,
#         0.4902, 0.4767, 0.5066, 0.5752, 0.4795, 0.7631, 0.4514, 0.5055, 0.6865,
#         0.5546], device='cuda:0')
#     [E02_1] run #986 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=63 (64/66) | prompt_id=63+59+10 | mAP50=0.171 | time=4.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 27
# Scores: tensor([0.5598, 0.4742, 0.6713, 0.5976, 0.6298, 0.6193, 0.6049, 0.8375, 0.4299,
#         0.5889, 0.5267, 0.4268, 0.6923, 0.7791, 0.4050, 0.7099, 0.4966, 0.8550,
#         0.6405, 0.4515, 0.5520, 0.4850, 0.4713, 0.7956, 0.5038, 0.5421, 0.5984],
#        device='cuda:0')
#     [E02_1] run #987 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=64 (65/66) | prompt_id=64+34+4 | mAP50=0.172 | time=4.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 21
# Scores: tensor([0.8584, 0.4410, 0.4908, 0.4545, 0.4322, 0.4349, 0.5135, 0.5200, 0.5835,
#         0.6635, 0.5115, 0.4229, 0.5548, 0.7831, 0.4212, 0.5293, 0.4627, 0.6559,
#         0.6664, 0.7848, 0.4607], device='cuda:0')
#     [E02_1] run #988 | image=20230426_Wallenwil/DJI_20230426111219_0201 | anchor=65 (66/66) | prompt_id=65+55+36 | mAP50=0.146 | time=4.7s
# [E02_1] (94/179) 20230426_Wallenwil/DJI_20230426111219_0201 done | 66 GT box(es) | image_mAP50_mean=0.155 | time=328.4s | avg/image=61.0s | ETA=86.4 min (1.44 h)
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 24
# Scores: tensor([0.9218, 0.6203, 0.7372, 0.6567, 0.7114, 0.8695, 0.5815, 0.5868, 0.8302,
#         0.4010, 0.7175, 0.6780, 0.5617, 0.5482, 0.6327, 0.9089, 0.6146, 0.8293,
#         0.8526, 0.6626, 0.8480, 0.6868, 0.4312, 0.5378], device='cuda:0')
#     [E02_1] run #989 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=0 (1/55) | prompt_id=0+43+22 | mAP50=0.142 | time=4.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 2
# Scores: tensor([0.8835, 0.4869], device='cuda:0')
#     [E02_1] run #990 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=1 (2/55) | prompt_id=1+4+53 | mAP50=0.040 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 51
# Scores: tensor([0.4270, 0.4333, 0.5876, 0.5623, 0.5999, 0.7543, 0.6242, 0.6264, 0.5482,
#         0.4179, 0.7734, 0.4126, 0.6932, 0.5402, 0.5016, 0.6099, 0.5533, 0.6358,
#         0.6027, 0.5962, 0.6707, 0.6423, 0.7642, 0.6876, 0.7763, 0.5495, 0.4537,
#         0.5520, 0.4596, 0.6280, 0.5346, 0.5727, 0.7171, 0.7284, 0.4250, 0.5995,
#         0.7189, 0.7603, 0.5049, 0.7308, 0.8722, 0.6167, 0.4853, 0.4004, 0.5884,
#         0.4929, 0.7632, 0.4141, 0.6605, 0.5071, 0.6585], device='cuda:0')
#     [E02_1] run #991 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=2 (3/55) | prompt_id=2+16+52 | mAP50=0.179 | time=5.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 22
# Scores: tensor([0.8406, 0.6450, 0.6066, 0.6599, 0.4318, 0.5664, 0.8057, 0.5791, 0.7339,
#         0.4329, 0.7722, 0.6611, 0.6427, 0.8764, 0.5362, 0.4615, 0.7407, 0.4147,
#         0.7471, 0.4681, 0.4597, 0.5271], device='cuda:0')
#     [E02_1] run #992 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=3 (4/55) | prompt_id=3+42+11 | mAP50=0.119 | time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 41
# Scores: tensor([0.8802, 0.5987, 0.4253, 0.4890, 0.4367, 0.5199, 0.5114, 0.6592, 0.4667,
#         0.6941, 0.4968, 0.5279, 0.5530, 0.4289, 0.5146, 0.4043, 0.7272, 0.8701,
#         0.4416, 0.4930, 0.4476, 0.4043, 0.4633, 0.4078, 0.5929, 0.7028, 0.4676,
#         0.6376, 0.6759, 0.4909, 0.6124, 0.6752, 0.5420, 0.4310, 0.6364, 0.4250,
#         0.6054, 0.6009, 0.4790, 0.4960, 0.5133], device='cuda:0')
#     [E02_1] run #993 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=4 (5/55) | prompt_id=4+16+11 | mAP50=0.188 | time=5.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 47
# Scores: tensor([0.4038, 0.6718, 0.5473, 0.6549, 0.5415, 0.4582, 0.4825, 0.5285, 0.4276,
#         0.5424, 0.4305, 0.4364, 0.4674, 0.5553, 0.4573, 0.6964, 0.5539, 0.7749,
#         0.4574, 0.4529, 0.4656, 0.5179, 0.6779, 0.4306, 0.6634, 0.6139, 0.5535,
#         0.6723, 0.6438, 0.5829, 0.5320, 0.5828, 0.6474, 0.4670, 0.6289, 0.5909,
#         0.4075, 0.6612, 0.4098, 0.5580, 0.4505, 0.4945, 0.5215, 0.8854, 0.6811,
#         0.4216, 0.4238], device='cuda:0')
#     [E02_1] run #994 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=5 (6/55) | prompt_id=5+11+6 | mAP50=0.222 | time=5.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 50
# Scores: tensor([0.4072, 0.6499, 0.4362, 0.6848, 0.5278, 0.4222, 0.7520, 0.6024, 0.6346,
#         0.5152, 0.7211, 0.4081, 0.7513, 0.6886, 0.5908, 0.5536, 0.6614, 0.7606,
#         0.5622, 0.5478, 0.5428, 0.7254, 0.6264, 0.7335, 0.6694, 0.5645, 0.7127,
#         0.5612, 0.5710, 0.5265, 0.5022, 0.5835, 0.5518, 0.6425, 0.6798, 0.7425,
#         0.5024, 0.5689, 0.6818, 0.7619, 0.5397, 0.7375, 0.6160, 0.5351, 0.6614,
#         0.6792, 0.5649, 0.7912, 0.4511, 0.4033], device='cuda:0')
#     [E02_1] run #995 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=6 (7/55) | prompt_id=6+46+7 | mAP50=0.252 | time=7.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 43
# Scores: tensor([0.5866, 0.5030, 0.4418, 0.7576, 0.5043, 0.6842, 0.7026, 0.4956, 0.5220,
#         0.6220, 0.4786, 0.6909, 0.5972, 0.4877, 0.6390, 0.6154, 0.6759, 0.6526,
#         0.6392, 0.4622, 0.6367, 0.7149, 0.4852, 0.5267, 0.4898, 0.5042, 0.5002,
#         0.6308, 0.7134, 0.6036, 0.8767, 0.6868, 0.7823, 0.8529, 0.4929, 0.5628,
#         0.5729, 0.5772, 0.5056, 0.4709, 0.6648, 0.4174, 0.6072],
#        device='cuda:0')
#     [E02_1] run #996 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=7 (8/55) | prompt_id=7+45+29 | mAP50=0.234 | time=5.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 30
# Scores: tensor([0.7679, 0.4936, 0.4279, 0.4679, 0.4525, 0.6009, 0.5430, 0.4947, 0.8800,
#         0.4584, 0.5271, 0.4567, 0.4054, 0.4648, 0.4605, 0.4654, 0.4972, 0.6388,
#         0.4191, 0.5167, 0.6680, 0.4818, 0.5679, 0.6633, 0.5109, 0.6574, 0.7146,
#         0.4637, 0.4853, 0.4943], device='cuda:0')
#     [E02_1] run #997 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=8 (9/55) | prompt_id=8+52+34 | mAP50=0.160 | time=4.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 18
# Scores: tensor([0.6847, 0.6375, 0.7214, 0.8842, 0.6593, 0.5971, 0.8379, 0.8180, 0.5385,
#         0.8394, 0.4488, 0.7853, 0.4783, 0.7980, 0.7454, 0.6737, 0.6080, 0.7303],
#        device='cuda:0')
#     [E02_1] run #998 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=9 (10/55) | prompt_id=9+20+51 | mAP50=0.086 | time=4.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 48
# Scores: tensor([0.5553, 0.4888, 0.5803, 0.4438, 0.4305, 0.6741, 0.5573, 0.4570, 0.5933,
#         0.5916, 0.6580, 0.5984, 0.6306, 0.4145, 0.5949, 0.4768, 0.4954, 0.5113,
#         0.6411, 0.5258, 0.5724, 0.6063, 0.6730, 0.4094, 0.4756, 0.5151, 0.4499,
#         0.4130, 0.5410, 0.4808, 0.4617, 0.6804, 0.5010, 0.5038, 0.4056, 0.5084,
#         0.5226, 0.6746, 0.6635, 0.4755, 0.6114, 0.4578, 0.7729, 0.4281, 0.6396,
#         0.5462, 0.4500, 0.4301], device='cuda:0')
#     [E02_1] run #999 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=10 (11/55) | prompt_id=10+6+50 | mAP50=0.216 | time=5.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 36
# Scores: tensor([0.4251, 0.4691, 0.8771, 0.4461, 0.7285, 0.4922, 0.4334, 0.5007, 0.6525,
#         0.4075, 0.6320, 0.4105, 0.4653, 0.4601, 0.5915, 0.5877, 0.4413, 0.6000,
#         0.7234, 0.8920, 0.5327, 0.4101, 0.6998, 0.4493, 0.4382, 0.6073, 0.5322,
#         0.6250, 0.6126, 0.8256, 0.5204, 0.6888, 0.4789, 0.4076, 0.5218, 0.5196],
#        device='cuda:0')
#     [E02_1] run #1000 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=11 (12/55) | prompt_id=11+30+16 | mAP50=0.189 | time=5.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 48
# Scores: tensor([0.4186, 0.6242, 0.4223, 0.5386, 0.6917, 0.5431, 0.8419, 0.7595, 0.5918,
#         0.6255, 0.4952, 0.7180, 0.8439, 0.4178, 0.6517, 0.5353, 0.4832, 0.6255,
#         0.6480, 0.6720, 0.6944, 0.6365, 0.7232, 0.5416, 0.4666, 0.5621, 0.5963,
#         0.5045, 0.4241, 0.5061, 0.5426, 0.7074, 0.6713, 0.6503, 0.4068, 0.5402,
#         0.6901, 0.7750, 0.5312, 0.5023, 0.6107, 0.4984, 0.5997, 0.5683, 0.4961,
#         0.7485, 0.5135, 0.6397], device='cuda:0')
#     [E02_1] run #1001 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=12 (13/55) | prompt_id=12+29+53 | mAP50=0.206 | time=6.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 11
# Scores: tensor([0.4028, 0.4023, 0.4100, 0.4680, 0.4742, 0.4305, 0.4774, 0.7962, 0.4189,
#         0.4489, 0.4165], device='cuda:0')
#     [E02_1] run #1002 | image=20230426_Wallenwil/DJI_20230426111258_0224 | anchor=13 (14/55) | prompt_id=13+53+11 | mAP50=0.087 | time=3.4s
# ...
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.7462, 0.4358, 0.4722, 0.8245, 0.8808, 0.4510], device='cuda:0')
#     [E02_1] run #1794 | image=20241203_Loehre/DJI_20241203151132_0193 | anchor=7 (8/8) | prompt_id=7+2+5 | mAP50=0.376 | time=3.0s
# [E02_1] (174/179) 20241203_Loehre/DJI_20241203151132_0193 done | 8 GT box(es) | image_mAP50_mean=0.463 | time=27.7s | avg/image=57.9s | ETA=4.8 min (0.08 h)
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 5
# Scores: tensor([0.6099, 0.8345, 0.4071, 0.4162, 0.9158], device='cuda:0')
#     [E02_1] run #1795 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=0 (1/9) | prompt_id=0+2+6 | mAP50=0.228 | time=2.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 4
# Scores: tensor([0.8821, 0.8073, 0.8576, 0.9056], device='cuda:0')
#     [E02_1] run #1796 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=1 (2/9) | prompt_id=1+5+0 | mAP50=0.309 | time=2.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.8179, 0.4892, 0.5556, 0.8671, 0.9056, 0.8529], device='cuda:0')
#     [E02_1] run #1797 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=2 (3/9) | prompt_id=2+3+7 | mAP50=0.337 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 12
# Scores: tensor([0.7983, 0.5316, 0.4471, 0.5722, 0.6228, 0.6577, 0.4369, 0.4058, 0.8213,
#         0.4994, 0.4131, 0.4147], device='cuda:0')
#     [E02_1] run #1798 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=3 (4/9) | prompt_id=3+8+1 | mAP50=0.228 | time=3.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 9
# Scores: tensor([0.4164, 0.4257, 0.4646, 0.8179, 0.8085, 0.5432, 0.8106, 0.9120, 0.4881],
#        device='cuda:0')
#     [E02_1] run #1799 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=4 (5/9) | prompt_id=4+0+3 | mAP50=0.409 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.4431, 0.4634, 0.4935, 0.4404, 0.9019, 0.4375], device='cuda:0')
#     [E02_1] run #1800 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=5 (6/9) | prompt_id=5+6+8 | mAP50=0.119 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.4431, 0.4634, 0.4935, 0.4404, 0.9019, 0.4375], device='cuda:0')
#     [E02_1] run #1801 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=6 (7/9) | prompt_id=6+5+8 | mAP50=0.119 | time=2.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 5
# Scores: tensor([0.8167, 0.4590, 0.9127, 0.8261, 0.9273], device='cuda:0')
#     [E02_1] run #1802 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=7 (8/9) | prompt_id=7+6+0 | mAP50=0.228 | time=2.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 7
# Scores: tensor([0.9141, 0.4039, 0.8651, 0.4880, 0.4714, 0.5456, 0.7147],
#        device='cuda:0')
#     [E02_1] run #1803 | image=20241203_Loehre/DJI_20241203151209_0214 | anchor=8 (9/9) | prompt_id=8+7+5 | mAP50=0.382 | time=3.1s
# [E02_1] (175/179) 20241203_Loehre/DJI_20241203151209_0214 done | 9 GT box(es) | image_mAP50_mean=0.262 | time=31.1s | avg/image=57.7s | ETA=3.8 min (0.06 h)
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 12
# Scores: tensor([0.8957, 0.5385, 0.4909, 0.6822, 0.5519, 0.4769, 0.5438, 0.6411, 0.8473,
#         0.4439, 0.6506, 0.5357], device='cuda:0')
#     [E02_1] run #1804 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=0 (1/18) | prompt_id=0+7+2 | mAP50=0.281 | time=3.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 5
# Scores: tensor([0.7503, 0.8091, 0.4030, 0.7827, 0.4003], device='cuda:0')
#     [E02_1] run #1805 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=1 (2/18) | prompt_id=1+15+17 | mAP50=0.168 | time=3.1s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 20
# Scores: tensor([0.4481, 0.5612, 0.4331, 0.5202, 0.5681, 0.4147, 0.6350, 0.6225, 0.6695,
#         0.8248, 0.4580, 0.6407, 0.8151, 0.4826, 0.6431, 0.5257, 0.4491, 0.5103,
#         0.7540, 0.6843], device='cuda:0')
#     [E02_1] run #1806 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=2 (3/18) | prompt_id=2+8+16 | mAP50=0.186 | time=4.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 8
# Scores: tensor([0.4825, 0.4014, 0.7160, 0.6367, 0.8525, 0.4088, 0.4049, 0.4426],
#        device='cuda:0')
#     [E02_1] run #1807 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=3 (4/18) | prompt_id=3+14+12 | mAP50=0.168 | time=3.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 11
# Scores: tensor([0.5586, 0.6759, 0.4605, 0.8729, 0.4870, 0.4997, 0.4046, 0.7918, 0.4575,
#         0.4279, 0.9057], device='cuda:0')
#     [E02_1] run #1808 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=4 (5/18) | prompt_id=4+8+12 | mAP50=0.221 | time=3.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 15
# Scores: tensor([0.6302, 0.4341, 0.4124, 0.4779, 0.5405, 0.6074, 0.8255, 0.6274, 0.8069,
#         0.5563, 0.4446, 0.8640, 0.4790, 0.4346, 0.6392], device='cuda:0')
#     [E02_1] run #1809 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=5 (6/18) | prompt_id=5+0+8 | mAP50=0.216 | time=4.1s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 21
# Scores: tensor([0.4450, 0.8105, 0.5593, 0.5272, 0.6206, 0.6242, 0.4495, 0.6409, 0.7207,
#         0.5793, 0.6796, 0.4463, 0.5502, 0.6425, 0.4918, 0.4989, 0.5019, 0.7468,
#         0.6422, 0.4230, 0.6672], device='cuda:0')
#     [E02_1] run #1810 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=6 (7/18) | prompt_id=6+2+8 | mAP50=0.162 | time=4.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 9
# Scores: tensor([0.8962, 0.7302, 0.8391, 0.4035, 0.5142, 0.4368, 0.9171, 0.4887, 0.5115],
#        device='cuda:0')
#     [E02_1] run #1811 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=7 (8/18) | prompt_id=7+13+3 | mAP50=0.277 | time=3.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 14
# Scores: tensor([0.4049, 0.5094, 0.9042, 0.5618, 0.5636, 0.8427, 0.6502, 0.8136, 0.5884,
#         0.6098, 0.4657, 0.4641, 0.7432, 0.6721], device='cuda:0')
#     [E02_1] run #1812 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=8 (9/18) | prompt_id=8+0+11 | mAP50=0.221 | time=3.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 11
# Scores: tensor([0.8982, 0.4593, 0.5432, 0.8355, 0.8150, 0.5090, 0.4129, 0.5207, 0.4230,
#         0.7051, 0.6352], device='cuda:0')
#     [E02_1] run #1813 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=9 (10/18) | prompt_id=9+4+16 | mAP50=0.202 | time=3.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 15
# Scores: tensor([0.4034, 0.4770, 0.4145, 0.5450, 0.5420, 0.5644, 0.4625, 0.7381, 0.4409,
#         0.5553, 0.5001, 0.4552, 0.6504, 0.5491, 0.5928], device='cuda:0')
#     [E02_1] run #1814 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=10 (11/18) | prompt_id=10+8+14 | mAP50=0.101 | time=3.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 8
# Scores: tensor([0.8994, 0.9083, 0.6586, 0.4258, 0.4039, 0.4957, 0.4442, 0.4987],
#        device='cuda:0')
#     [E02_1] run #1815 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=11 (12/18) | prompt_id=11+14+4 | mAP50=0.247 | time=3.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 14
# Scores: tensor([0.4198, 0.4226, 0.4519, 0.9055, 0.5913, 0.5276, 0.4871, 0.8764, 0.4033,
#         0.4291, 0.4942, 0.6328, 0.4693, 0.4742], device='cuda:0')
#     [E02_1] run #1816 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=12 (13/18) | prompt_id=12+2+4 | mAP50=0.247 | time=3.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 9
# Scores: tensor([0.5260, 0.8792, 0.4049, 0.6801, 0.4104, 0.4116, 0.9137, 0.5361, 0.4806],
#        device='cuda:0')
#     [E02_1] run #1817 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=13 (14/18) | prompt_id=13+3+4 | mAP50=0.149 | time=3.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 12
# Scores: tensor([0.6058, 0.4015, 0.6919, 0.6035, 0.4339, 0.8195, 0.6406, 0.4363, 0.9109,
#         0.4334, 0.4399, 0.5095], device='cuda:0')
#     [E02_1] run #1818 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=14 (15/18) | prompt_id=14+13+9 | mAP50=0.360 | time=3.5s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 16
# Scores: tensor([0.4471, 0.4004, 0.4308, 0.4491, 0.4676, 0.4397, 0.5372, 0.7321, 0.4334,
#         0.6207, 0.5274, 0.4789, 0.6385, 0.4185, 0.8045, 0.6332],
#        device='cuda:0')
#     [E02_1] run #1819 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=15 (16/18) | prompt_id=15+16+14 | mAP50=0.196 | time=3.7s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 16
# Scores: tensor([0.4471, 0.4004, 0.4308, 0.4491, 0.4676, 0.4397, 0.5372, 0.7321, 0.4334,
#         0.6207, 0.5274, 0.4789, 0.6385, 0.4185, 0.8045, 0.6332],
#        device='cuda:0')
#     [E02_1] run #1820 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=16 (17/18) | prompt_id=16+14+15 | mAP50=0.196 | time=4.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.6738, 0.7964, 0.5701, 0.4090, 0.4046, 0.8770], device='cuda:0')
#     [E02_1] run #1821 | image=20241203_Loehre/DJI_20241203151245_0234 | anchor=17 (18/18) | prompt_id=17+5+3 | mAP50=0.228 | time=3.2s
# [E02_1] (176/179) 20241203_Loehre/DJI_20241203151245_0234 done | 18 GT box(es) | image_mAP50_mean=0.213 | time=69.4s | avg/image=57.8s | ETA=2.9 min (0.05 h)
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.4212, 0.8975, 0.4419, 0.4033, 0.6989, 0.9356], device='cuda:0')
#     [E02_1] run #1822 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=0 (1/10) | prompt_id=0+8+9 | mAP50=0.488 | time=2.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 8
# Scores: tensor([0.8727, 0.4049, 0.5892, 0.9036, 0.4610, 0.6280, 0.4286, 0.8630],
#        device='cuda:0')
#     [E02_1] run #1823 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=1 (2/10) | prompt_id=1+2+4 | mAP50=0.579 | time=3.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 9
# Scores: tensor([0.4323, 0.8742, 0.7992, 0.4703, 0.4663, 0.7116, 0.4045, 0.4444, 0.4446],
#        device='cuda:0')
#     [E02_1] run #1824 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=2 (3/10) | prompt_id=2+4+5 | mAP50=0.406 | time=3.3s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 7
# Scores: tensor([0.8814, 0.5142, 0.7518, 0.9364, 0.4101, 0.4880, 0.8733],
#        device='cuda:0')
#     [E02_1] run #1825 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=3 (4/10) | prompt_id=3+0+2 | mAP50=0.505 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 8
# Scores: tensor([0.4770, 0.8990, 0.5833, 0.9209, 0.9162, 0.6942, 0.4828, 0.4270],
#        device='cuda:0')
#     [E02_1] run #1826 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=4 (5/10) | prompt_id=4+9+1 | mAP50=0.505 | time=3.1s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 5
# Scores: tensor([0.8492, 0.9172, 0.5117, 0.7235, 0.4395], device='cuda:0')
#     [E02_1] run #1827 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=5 (6/10) | prompt_id=5+4+9 | mAP50=0.505 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 14
# Scores: tensor([0.8813, 0.4551, 0.6566, 0.4950, 0.6409, 0.4458, 0.6084, 0.6007, 0.5116,
#         0.4927, 0.6243, 0.7239, 0.4236, 0.6284], device='cuda:0')
#     [E02_1] run #1828 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=6 (7/10) | prompt_id=6+8+4 | mAP50=0.282 | time=3.8s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 7
# Scores: tensor([0.4329, 0.8447, 0.5934, 0.4376, 0.4228, 0.7041, 0.4105],
#        device='cuda:0')
#     [E02_1] run #1829 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=7 (8/10) | prompt_id=7+4+5 | mAP50=0.307 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 10
# Scores: tensor([0.4927, 0.4346, 0.8733, 0.7502, 0.4506, 0.7071, 0.5024, 0.8557, 0.4946,
#         0.4257], device='cuda:0')
#     [E02_1] run #1830 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=8 (9/10) | prompt_id=8+2+3 | mAP50=0.406 | time=3.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 8
# Scores: tensor([0.4770, 0.8990, 0.5833, 0.9209, 0.9162, 0.6942, 0.4828, 0.4270],
#        device='cuda:0')
#     [E02_1] run #1831 | image=20241203_Loehre/DJI_20241203151314_0250 | anchor=9 (10/10) | prompt_id=9+1+4 | mAP50=0.505 | time=3.1s
# [E02_1] (177/179) 20241203_Loehre/DJI_20241203151314_0250 done | 10 GT box(es) | image_mAP50_mean=0.449 | time=36.3s | avg/image=57.6s | ETA=1.9 min (0.03 h)
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 8
# Scores: tensor([0.6231, 0.8238, 0.8881, 0.8070, 0.4179, 0.8687, 0.9149, 0.7787],
#        device='cuda:0')
#     [E02_1] run #1832 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=0 (1/9) | prompt_id=0+4+6 | mAP50=0.518 | time=3.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 5
# Scores: tensor([0.8264, 0.9281, 0.9519, 0.8103, 0.4601], device='cuda:0')
#     [E02_1] run #1833 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=1 (2/9) | prompt_id=1+5+6 | mAP50=0.446 | time=2.9s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 11
# Scores: tensor([0.7602, 0.5950, 0.6364, 0.4140, 0.7277, 0.6492, 0.4113, 0.4138, 0.6958,
#         0.7033, 0.4453], device='cuda:0')
#     [E02_1] run #1834 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=2 (3/9) | prompt_id=2+6+8 | mAP50=0.648 | time=3.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 10
# Scores: tensor([0.6943, 0.6172, 0.4171, 0.4402, 0.4345, 0.6252, 0.7864, 0.7814, 0.6552,
#         0.5084], device='cuda:0')
#     [E02_1] run #1835 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=3 (4/9) | prompt_id=3+7+2 | mAP50=0.663 | time=3.6s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 11
# Scores: tensor([0.7085, 0.6229, 0.5117, 0.8600, 0.4249, 0.4015, 0.4036, 0.5860, 0.6389,
#         0.7446, 0.7083], device='cuda:0')
#     [E02_1] run #1836 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=4 (5/9) | prompt_id=4+2+7 | mAP50=0.663 | time=3.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 9
# Scores: tensor([0.7207, 0.7461, 0.5604, 0.5011, 0.5267, 0.7567, 0.8165, 0.4245, 0.9447],
#        device='cuda:0')
#     [E02_1] run #1837 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=5 (6/9) | prompt_id=5+2+6 | mAP50=0.554 | time=3.2s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 5
# Scores: tensor([0.4724, 0.8253, 0.9544, 0.9304, 0.7417], device='cuda:0')
#     [E02_1] run #1838 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=6 (7/9) | prompt_id=6+5+0 | mAP50=0.446 | time=3.0s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 7
# Scores: tensor([0.7768, 0.7792, 0.8159, 0.7448, 0.9062, 0.4618, 0.4037],
#        device='cuda:0')
#     [E02_1] run #1839 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=7 (8/9) | prompt_id=7+6+1 | mAP50=0.554 | time=3.4s
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 6
# Scores: tensor([0.7263, 0.7146, 0.7766, 0.8160, 0.9014, 0.4623], device='cuda:0')
#     [E02_1] run #1840 | image=20241203_Loehre/DJI_20241203151419_0286 | anchor=8 (9/9) | prompt_id=8+1+6 | mAP50=0.554 | time=3.1s
# [E02_1] (178/179) 20241203_Loehre/DJI_20241203151419_0286 done | 9 GT box(es) | image_mAP50_mean=0.561 | time=33.4s | avg/image=57.4s | ETA=1.0 min (0.02 h)
# Returned keys: dict_keys(['scores', 'boxes', 'masks'])
# Boxes: 1
# Scores: tensor([0.8678], device='cuda:0')
#     [E02_1] run #1841 | image=20241203_Loehre/DJI_20241203151524_0321 | anchor=0 (1/1) | prompt_id=0 | mAP50=1.000 | time=2.7s
# [E02_1] (179/179) 20241203_Loehre/DJI_20241203151524_0321 done | 1 GT box(es) | image_mAP50_mean=1.000 | time=7.0s | avg/image=57.0s | ETA=0.0 min (0.00 h)
#
# Finished E02_1: 1841 new rows written to /content/drive/MyDrive/master_thesis/results/results2_E02_1.csv
# Total time: 131.6 min (2.19 h)

# %%
file_exists = os.path.exists(OUTPUT_CSV)
print(file_exists)

# %%
# Per-experiment statistical summary
EXPERIMENT_CSV = OUTPUT_CSV
df = pd.read_csv(EXPERIMENT_CSV)
exp_name = df["experiment_name"].iloc[0]


exp_name = df["experiment_name"].iloc[0]
print(f"Experiment: {exp_name}")
print(f"Total rows (image x prompt runs): {len(df)}")
print(f"Number of distinct images: {df['image_ID'].nunique()}")
# Out:
# Experiment: E02_1
# Total rows (image x prompt runs): 1841
# Number of distinct images: 136

# %%
#  Raw per-run stats (every row = one image + one prompt set, independent observation)
# Here, every row in our CSV is treated as one independent experiment.
# output 1 value per metric (produces one overall mean and one overall std for each metric)
raw_summary = df.agg(
    n_runs=("mAP50", "count"),
    mAP50_mean=("mAP50", "mean"),
    mAP50_std=("mAP50", "std"),
    precision_mean=("precision", "mean"),
    precision_std=("precision", "std"),
    recall_mean=("recall", "mean"),
    recall_std=("recall", "std"),
    IoU1_mean=("IoU1", "mean"),
    IoU1_std=("IoU1", "std"),
    IoU2_mean=("IoU2", "mean"),
    IoU2_std=("IoU2", "std"),
)
raw_summary_path = os.path.join(OUTPUT_DIR, f"raw_summary_{exp_name}.csv")
raw_summary.to_csv(raw_summary_path)
print(f"Saved raw_summary_{exp_name}.csv to {OUTPUT_DIR}")

print(f"=== {exp_name} -- raw per-run summary (all rows independent) ===")
print(raw_summary)
# Out:
# Saved raw_summary_E02_1.csv to /content/drive/MyDrive/master_thesis/results/
# === E02_1 -- raw per-run summary (all rows independent) ===
#                       mAP50  precision    recall      IoU1      IoU2
# n_runs          1841.000000        NaN       NaN       NaN       NaN
# mAP50_mean         0.263236        NaN       NaN       NaN       NaN
# mAP50_std          0.248756        NaN       NaN       NaN       NaN
# precision_mean          NaN   0.541869       NaN       NaN       NaN
# precision_std           NaN   0.232389       NaN       NaN       NaN
# recall_mean             NaN        NaN  0.298451       NaN       NaN
# recall_std              NaN        NaN  0.247917       NaN       NaN
# IoU1_mean               NaN        NaN       NaN  0.765975       NaN
# IoU1_std                NaN        NaN       NaN  0.100995       NaN
# IoU2_mean               NaN        NaN       NaN       NaN  0.237796
# IoU2_std                NaN        NaN       NaN       NaN  0.216393

# %%
# Image-level stats (collapse multiple prompt runs per image to one value first,
# so images with more GT boxes / more prompt sets don't dominate the average)
image_level = ( # produces one mean value per image for each metric
    df.groupby("image_ID")
    .agg(
        mAP50_image_mean=("mAP50", "mean"),
        precision_image_mean=("precision", "mean"),
        recall_image_mean=("recall", "mean"),
        IoU1_image_mean=("IoU1", "mean"),
        IoU2_image_mean=("IoU2", "mean"),
        n_prompts=("mAP50", "count"),
    )
    .reset_index()
