# %%
import os
from google.colab import userdata

os.environ["HF_TOKEN"] = userdata.get("HF_TOKEN")

# %%
# !pip install -q torch torchvision

# %%
import torch
import torchvision

print("PyTorch version:", torch.__version__)
print("Torchvision version:", torchvision.__version__)
print("CUDA is available:", torch.cuda.is_available())
# Out:
# PyTorch version: 2.11.0+cu128
# Torchvision version: 0.26.0+cu128
# CUDA is available: True

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# facebook/sam3 is gated on the Hub -> you must accept the license at
# https://huggingface.co/facebook/sam3 with the account whose token you use below.
# !pip install -q -U transformers accelerate huggingface_hub supervision

from huggingface_hub import login
login()  # paste your HF token (needs access to facebook/sam3)

print("Transformers SAM3 dependencies installed.")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 116.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 784.9/784.9 kB 60.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.3/373.3 kB 35.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.5/35.5 MB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 124.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.3/144.3 kB 15.9 MB/s eta 0:00:00
# Transformers SAM3 dependencies installed.

# %%
import os, glob, csv, time
import numpy as np
import pandas as pd
import gc
import torch
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import supervision as sv
import matplotlib.patches as patches
from transformers import Sam3Model, Sam3Processor

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

sam3_model = Sam3Model.from_pretrained("facebook/sam3", device_map="auto")
sam3_model.eval()

sam3_processor = Sam3Processor.from_pretrained("facebook/sam3")

print("HF transformers SAM3 model + processor loaded.")
print("Model device:", next(sam3_model.parameters()).device)
# Out:
# config.json:   0%|          | 0.00/25.8k [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 3.44GB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/1468 [00:00<?, ?it/s]
# processor_config.json:   0%|          | 0.00/1.71k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/799 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/3.64M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/588 [00:00<?, ?B/s]
# HF transformers SAM3 model + processor loaded.
# Model device: cuda:0

# %%
IMAGES_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/images"
LABELS_ROOT = "/content/drive/MyDrive/master_thesis/dataset/AGS_Multi_Rumex/annotations_yolo"
RUMEX_CLASS_ID = 0

# %%
#   USE_PRESENCE_GATE      -- best-effort score reweighting using
#                              SAM3's presence head (see caveat below)
#   ADD_GLOBAL_CONTEXT_PASS -- optional extra pass on a downsampled
#                              whole image, merged with tile results
# Both default to values I'd actually recommend: presence gating ON
# (it's free if it doesn't fire, harmless if it does), global pass
# OFF (see caveat in run_sam3_pipeline -- it's more likely to hurt
# small-object recall than help, given your image size).

EXPERIMENT_NAME = "E01_2"   # e.g. "E02_2" (Exp1), "<exp2_name>", "<exp3_name>"
N_EXEMPLARS     = 1         # 3 for Exp1/Exp2, 1 for Exp3
USE_TILING      = True      # True for Exp1/Exp3, False for Exp2

# SAM3 / tiling params
TILE_SIZE = 2000   # comfortably > max plant width (706px), leaves ~65% of the tile as context
OVERLAP   = 800     # > max plant width (706px), so any plant is fully captured whole in some tile
THRESHOLD = 0.3
IOU_THRESHOLD = 0.5
NMS_IOU_THRESHOLD = 0.5

#USE_PRESENCE_GATE = True          # multiply detection scores by SAM3's presence score, per tile
ADD_GLOBAL_CONTEXT_PASS = True   # extra downsampled whole-image pass -- OFF by default, see caveat
GLOBAL_DOWNSCALE = 2              # how much to shrink the image for the global pass, if enabled

# Batched inference settings
BATCH_SIZE = 1    # how many tiles get sent to the GPU in one model call -- lower if you hit OOM, raise if GPU memory sits idle
USE_FP16   = True  # run inference in half precision -- roughly halves memory use, usually near-zero accuracy cost

KEEP_MASKS = False   # True only if you'll actually use masks later (visualization, etc.)

RNG = np.random.default_rng(42)  # fixed seed -> reproducible exemplar sampling

# %%
# Output CSV (append-safe: survives Colab disconnects)
OUTPUT_CSV = f"/content/drive/MyDrive/master_thesis/results/results2_{EXPERIMENT_NAME}.csv"
CSV_COLUMNS = ["experiment_name", "image_ID", "anchor_idx", "Prompt_ID", "Prompt_Type", "mAP50",
               "precision", "recall", "IoU1", "IoU2"]

PROMPT_TYPE = "multiple" if N_EXEMPLARS > 1 else "single"

# %%
def load_yolo_boxes(label_path, img_width, img_height, class_id=0):
    boxes = []
    with open(label_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if not parts:
                continue
            cls = int(parts[0])
            if cls != class_id:
                continue
            xc, yc, bw, bh = map(float, parts[1:5])
            xc, yc, bw, bh = xc * img_width, yc * img_height, bw * img_width, bh * img_height
            boxes.append([xc - bw / 2, yc - bh / 2, xc + bw / 2, yc + bh / 2])
    return np.array(boxes, dtype=np.float32)

# %%
def format_prompt_id(exemplar_indices: list) -> str:
    """
    Single box (Exp3)   -> "5"
    Multiple boxes (Exp1/Exp2) -> "5+12+3"  (anchor first, then the sampled others,
    order preserved so you can always tell which one was the anchor: it's the
    first number in the string)
    """
    return "+".join(str(i) for i in exemplar_indices)

# %%
def find_label_path(image_filename_no_ext, folder_name):
    mirrored = os.path.join(LABELS_ROOT, folder_name, image_filename_no_ext + ".txt")  # <- change here if needed
    flat = os.path.join(LABELS_ROOT, image_filename_no_ext + ".txt")                    # <- and here
    if os.path.exists(mirrored):
        return mirrored
    if os.path.exists(flat):
        return flat
    return None

# %%
#Discover every image across all folders in AGS_MULTI_RUMEX
image_records = []  # (folder, image_path, label_path, image_id)
VALID_EXT = (".jpg", ".jpeg", ".png")

for folder in sorted(os.listdir(IMAGES_ROOT)):
    folder_path = os.path.join(IMAGES_ROOT, folder)
    if not os.path.isdir(folder_path):
        continue
    for fname in sorted(os.listdir(folder_path)):
        if not fname.lower().endswith(VALID_EXT):
            continue
        name_no_ext = os.path.splitext(fname)[0]
        label_path = find_label_path(name_no_ext, folder)
        image_id = f"{folder}/{name_no_ext}"
        image_records.append((folder, os.path.join(folder_path, fname), label_path, image_id))
        missing_labels = [r for r in image_records if r[2] is None]

print(f"Discovered {len(image_records)} images across {len(set(r[0] for r in image_records))} folders.")
if missing_labels:
    print(f"WARNING: {len(missing_labels)} images have no matching label file (will be skipped). "
          f"First few: {[r[3] for r in missing_labels[:5]]}")
# Out:
# Discovered 179 images across 15 folders.

# %%
def select_exemplar_indices(n_gt: int, anchor_idx: int, n_exemplars: int, image_id: str) -> list:
    """
    Builds the exemplar index set for one run:
      - always includes the anchor box (the one this row is "about")
      - fills the rest (n_exemplars - 1 slots) with OTHER GT boxes from the
        same image, sampled without replacement
      - if the image doesn't have enough other GT boxes, just uses whatever
        is available (no duplication, no crash)
    """
    ## each GT bbox gets a chance to act as the "anchor"
    ## prompt, while the remaining exemplars are randomly sampled from the same image.
    seed = abs(hash((image_id, anchor_idx))) % (2**32)
    rng = np.random.default_rng(seed)
    others = [i for i in range(n_gt) if i != anchor_idx]
    n_others_needed = min(n_exemplars - 1, len(others))   # min(1 - 1, ...) = min(0, ...) = 0
    if n_others_needed > 0: #in case of several input bboxes
        chosen_others = list(rng.choice(others, size=n_others_needed, replace=False))
    else: #in case of 1 GT as a bbox (1 anchor per run)=>no random sampling
        chosen_others = []                                # <-- always hits this branch
    return [anchor_idx] + chosen_others                    # -> [anchor_idx]

# %%
def get_local_background_patch(tile_img: Image.Image, patch_w: int, patch_h: int) -> Image.Image:
    """
    Instead of a flat white block, sample REAL texture from the tile itself to use as
    the strip's background. Why this matters:
      - Color balance, brightness, and grain automatically match this tile's own
        lighting conditions (which can vary tile-to-tile across a large drone photo).
      - There's no artificial white-vs-photo boundary for the vision transformer's
        self-attention to latch onto as a spurious "edge feature".
      - The exemplar's ROI-pooled feature (computed AFTER the image encoder has already
        mixed in neighboring context via attention) ends up looking like "a plant in
        grass" instead of "a plant in a void" -- much closer to a real target instance.

    We grab the top-left corner of the tile from target img (an area that won't be duplicated, since
    the strip sits ABOVE the tile in the final canvas, not overlapping it).
    """
    sample = tile_img.crop((0, 0, min(patch_w, tile_img.width), min(patch_h, tile_img.height)))
    if sample.size != (patch_w, patch_h):
        sample = sample.resize((patch_w, patch_h))
    return sample


def make_feather_mask(size, feather_width):
    w, h = size
    mask = np.full((h, w), 255.0, dtype=np.float32)

    effective_feather = min(feather_width, h // 2, w // 2)
    if effective_feather >= 1:
        for i in range(effective_feather):
            alpha = 255.0 * (i + 1) / effective_feather
            mask[i, :] = np.minimum(mask[i, :], alpha)
            mask[h - 1 - i, :] = np.minimum(mask[h - 1 - i, :], alpha)
            mask[:, i] = np.minimum(mask[:, i], alpha)
            mask[:, w - 1 - i] = np.minimum(mask[:, w - 1 - i], alpha)

    return Image.fromarray(mask.astype(np.uint8), mode="L")  # <-- return a PIL Image, not ndarray

# %%
def compose_tile_with_exemplars(tile_img: Image.Image, crop_images: list,
                                 margin: int = 6, feather_width: int = 8):
    """
    Builds the small composed image actually sent to SAM3, for ONE tile, with
    MULTIPLE exemplar crops placed side-by-side in a strip above the tile.

    Returns:
        composed  -- the image to feed to SAM3
        crop_boxes -- list of [x1,y1,x2,y2], one per exemplar, in composed-image coords
        offset    -- (dx, dy) to convert composed target-region coords back
                     to this TILE's own coordinate system
    """
    n = len(crop_images)
    strip_h = max(c.height for c in crop_images) + 2 * margin
    strip_content_w = sum(c.width for c in crop_images) + margin * (n + 1)
    canvas_w = max(tile_img.width, strip_content_w)
    canvas_h = strip_h + tile_img.height

    strip_bg = get_local_background_patch(tile_img, canvas_w, strip_h)

    composed = Image.new("RGB", (canvas_w, canvas_h))
    composed.paste(strip_bg, (0, 0))
    offset = (0, strip_h)
    composed.paste(tile_img, offset)

    crop_boxes = []
    cursor_x = margin
    for crop_image in crop_images:
        feather_mask = make_feather_mask(crop_image.size, feather_width=feather_width)
        paste_xy = (cursor_x, margin)
        composed.paste(crop_image, paste_xy, feather_mask)

        crop_boxes.append([
            paste_xy[0], paste_xy[1],
            paste_xy[0] + crop_image.width, paste_xy[1] + crop_image.height,
        ])
        cursor_x += crop_image.width + margin

    return composed, crop_boxes, offset

# %%
def tile_bboxes(img_w: int, img_h: int, tile_size: int, overlap: int):
    """
    Generates (x1,y1,x2,y2) windows covering the whole image, with overlap so plants
    sitting right on a tile boundary aren't missed or half-cut in every window.
    """
    step = tile_size - overlap
    tiles = []
    for y in range(0, img_h, step):
        for x in range(0, img_w, step):
            x2 = min(x + tile_size, img_w)
            y2 = min(y + tile_size, img_h)
            x1 = max(0, x2 - tile_size)
            y1 = max(0, y2 - tile_size)
            tiles.append((x1, y1, x2, y2))
    return list(dict.fromkeys(tiles))

# %%
# MODIFIED CELL: keep_only_target_region_detections
# Only change: masks are explicitly cast to a boolean array before
# being stored. If they were already coming back as float32
# (common if the model outputs raw sigmoid probabilities before
# any threshold is applied), this alone can cut mask memory by
# ~4-8x. If they're already bool, this is a no-op.

def keep_only_target_region_detections(boxes, scores, masks, offset, y_tolerance=5):
    """
    Drop any detection sitting inside the padding strip (that's a pasted exemplar
    being re-detected, not a real find), keep only detections that fall within the
    tile's real-content region, and remap their coordinates back to that tile's own
    coordinate system (undo the paste offset).
    """
    dx, dy = offset
    kept_boxes, kept_scores, kept_masks = [], [], []

    for box, score, mask in zip(boxes, scores, masks):
        x1, y1, x2, y2 = box.tolist() if torch.is_tensor(box) else box
        if y1 >= dy - y_tolerance:
            remapped_box = [x1 - dx, max(y1 - dy, 0), x2 - dx, y2 - dy]
            kept_boxes.append(remapped_box)
            kept_scores.append(score)
            mask_np = mask.cpu().numpy() if torch.is_tensor(mask) else mask
            mask_np = mask_np[dy:, dx:] if dx or dy else mask_np
            kept_masks.append(mask_np.astype(np.bool_))  # was implicitly float before
    return kept_boxes, kept_scores, kept_masks

# %%
def filter_implausible_boxes(boxes, scores, masks, tile_w, tile_h,
                              min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5):
    """
    Drops detections unlikely to be real single Rumex plants:
      - box area implausibly large relative to the tile (likely background clutter,
        not a single plant)
      - predicted mask fills too little of its own box (weak/noisy detection rather
        than a confident, well-localized instance)
      - degenerate boxes clipped to (near) zero size at the tile edges
    `edge_margin` is used to tolerate boxes that legitimately touch a tile border
    (real plants often do, since tiles overlap and neighboring tiles will pick up
    the rest of the same plant) rather than penalizing them outright.
    """
    kept_boxes, kept_scores, kept_masks = [], [], []
    tile_area = tile_w * tile_h

    for box, score, mask in zip(boxes, scores, masks):
        x1, y1, x2, y2 = box
        box_w, box_h = x2 - x1, y2 - y1
        if box_w <= edge_margin or box_h <= edge_margin:
            continue

        box_area = box_w * box_h
        if box_area / tile_area > max_area_fraction:
            continue

        mask_np = mask.cpu().numpy() if torch.is_tensor(mask) else mask
        x1c, y1c = int(max(0, x1)), int(max(0, y1))
        x2c, y2c = int(min(mask_np.shape[1], x2)), int(min(mask_np.shape[0], y2))
        if x2c <= x1c or y2c <= y1c:
            continue

        region = mask_np[y1c:y2c, x1c:x2c]
        fill_ratio = (region > 0.5).mean() if region.size > 0 else 0.0
        if fill_ratio < min_fill_ratio:
            continue

        kept_boxes.append(box)
        kept_scores.append(score)
        kept_masks.append(None)

    return kept_boxes, kept_scores, kept_masks

# %%
# ============================================================
# MODIFIED CELL: run_sam3_on_tiles_batched
# Added: presence-token gating, applied per-item inside each batch.
#
# Plain English: after the model looks at a tile, it can also output
# a "presence" score -- its own estimate of whether the thing you're
# looking for (a Rumex plant matching the exemplar crops) is present
# ANYWHERE in that tile at all, separate from where exactly it might
# be. We multiply every detection's confidence in that tile by this
# presence score. A tile of pure empty grass that the model is only
# 20% confident contains anything real will have its detections
# knocked down (0.6 confidence x 0.2 presence = 0.12, likely dropped
# below threshold). A tile the model is 95% sure has a real plant
# keeps its detections almost untouched.
#
# CAVEAT (same as before): presence_logits comes back with shape
# (batch_size, 1) -- one score per tile in the batch. It's documented
# around TEXT-conditioned prompts; in box-only exemplar mode (no
# text=, which is what this pipeline uses) some transformers versions
# may leave it as None. The code checks for that and just skips
# gating if so -- behavior falls back to exactly what you had before,
# nothing crashes either way. Print a few presence_prob values the
# first time you run this to confirm it's actually firing for you.
# ============================================================
def run_sam3_on_tiles_batched(composed_tiles, crop_boxes, offset, threshold=0.3,
                                batch_size=4, use_fp16=True, use_presence_gate=True):
    all_results = [None] * len(composed_tiles)

    def process_batch(indices):
        batch = [composed_tiles[i] for i in indices]
        b = len(batch)
        try:
            inputs = sam3_processor(
                images=batch,
                input_boxes=[[[float(c) for c in box] for box in crop_boxes]] * b,
                input_boxes_labels=[[1] * len(crop_boxes)] * b,
                return_tensors="pt",
            ).to(sam3_model.device)

            with torch.inference_mode():
                if use_fp16:
                    with torch.autocast(device_type="cuda", dtype=torch.float16):
                        outputs = sam3_model(**inputs)
                else:
                    outputs = sam3_model(**inputs)

            # # --- presence scores for this batch, one per tile (best-effort) ---
            # presence_probs = None
            # if use_presence_gate and getattr(outputs, "presence_logits", None) is not None:
            #     # shape (b, 1) -> squeeze to a flat list of b floats, one per tile
            #     presence_probs = torch.sigmoid(outputs.presence_logits).squeeze(-1).tolist()
            #     if isinstance(presence_probs, float):  # b == 1 case, squeeze can over-flatten
            #         presence_probs = [presence_probs]

            batch_results = sam3_processor.post_process_instance_segmentation(
                outputs, threshold=threshold, mask_threshold=0.4,
                target_sizes=inputs.get("original_sizes").tolist(),
            )

            # # --- apply presence gating per tile, before remapping coordinates ---
            # if presence_probs is not None:
            #     for res, p in zip(batch_results, presence_probs):
            #         if len(res["scores"]) == 0:
            #             continue
            #         rescaled = [s * p for s in res["scores"]]
            #         keep_idx = [i for i, s in enumerate(rescaled) if s >= threshold]
            #         res["boxes"] = [res["boxes"][i] for i in keep_idx]
            #         res["scores"] = [rescaled[i] for i in keep_idx]
            #         res["masks"] = [res["masks"][i] for i in keep_idx]

            for idx, res in zip(indices, batch_results):
                all_results[idx] = keep_only_target_region_detections(
                    res["boxes"], res["scores"], res["masks"], offset
                )

            del inputs, outputs, batch_results
            torch.cuda.empty_cache()

        except torch.cuda.OutOfMemoryError:
            torch.cuda.empty_cache()
            if b == 1:
                print(f"    WARNING: OOM on a single tile, skipping it (threshold/tile too large for T4).")
                all_results[indices[0]] = ([], [], [])
                return
            mid = b // 2
            print(f"    OOM at batch_size={b}, splitting into {mid} + {b - mid} and retrying...")
            process_batch(indices[:mid])
            process_batch(indices[mid:])

    for start in range(0, len(composed_tiles), batch_size):
        chunk = list(range(start, min(start + batch_size, len(composed_tiles))))
        process_batch(chunk)

    return all_results

# %%
def nms_merge(boxes, scores, masks, iou_thresh: float = NMS_IOU_THRESHOLD):
    """
    Because tiles overlap, the same real plant can get detected in two neighboring
    tiles. Standard IoU-based Non-Max Suppression collapses duplicates down to the
    single highest-confidence box -- carries the matching mask through too.
    """
    if not boxes:
        return [], [], []

    boxes_t = torch.tensor(boxes, dtype=torch.float32)
    scores_t = torch.tensor([s.item() if torch.is_tensor(s) else s for s in scores])
    order = scores_t.argsort(descending=True)
    keep = []

    while order.numel() > 0:
        i = order[0].item()
        keep.append(i)
        if order.numel() == 1:
            break
        rest = order[1:]
        xx1 = torch.maximum(boxes_t[i, 0], boxes_t[rest, 0])
        yy1 = torch.maximum(boxes_t[i, 1], boxes_t[rest, 1])
        xx2 = torch.minimum(boxes_t[i, 2], boxes_t[rest, 2])
        yy2 = torch.minimum(boxes_t[i, 3], boxes_t[rest, 3])
        inter = (xx2 - xx1).clamp(0) * (yy2 - yy1).clamp(0)
        area_i = (boxes_t[i, 2] - boxes_t[i, 0]) * (boxes_t[i, 3] - boxes_t[i, 1])
        area_r = (boxes_t[rest, 2] - boxes_t[rest, 0]) * (boxes_t[rest, 3] - boxes_t[rest, 1])
        iou = inter / (area_i + area_r - inter + 1e-6)
        order = rest[iou <= iou_thresh]

    kept_boxes = [boxes[i] for i in keep]
    kept_scores = [scores[i] for i in keep]
    kept_masks = [masks[i] for i in keep]
    return kept_boxes, kept_scores, kept_masks

# %%
# ============================================================
# MODIFIED CELL: run_sam3_pipeline
# Added: an optional extra pass on a downsampled copy of the WHOLE
# image (no tiling), whose detections get scaled back up and merged
# in with the tiled detections via NMS.
#
# REPEATING THE CAVEAT FROM BEFORE, because it matters here: SAM3's
# own image processor resizes whatever you feed it to ~1024px on the
# longest side before the model ever sees it -- that happens whether
# you hand it a 1000px tile or the full 8192px image. So shrinking
# your image by GLOBAL_DOWNSCALE=2 (giving a 4096x2730 image) doesn't
# preserve detail -- SAM3 crunches it down to ~1024px anyway, i.e.
# ANOTHER ~4x shrink on top of the one you already did. A Rumex plant
# that's ~50px wide in the original image would end up only a few
# pixels wide by the time the model actually processes it in this
# pass -- likely too small to detect. This is why ADD_GLOBAL_CONTEXT_PASS
# defaults to False. Test it on a small subset (10-15 images, compare
# mAP50 with it on vs off) before trusting it on a full experiment run.
# ============================================================
def run_sam3_pipeline(image, exemplar_crops, use_tiling, tile_size=1000, overlap=150,
                       threshold=0.3, cached_tiles=None, batch_size=BATCH_SIZE,
                       nms_iou_thresh=NMS_IOU_THRESHOLD, use_fp16=USE_FP16,
                       add_global_pass=ADD_GLOBAL_CONTEXT_PASS, global_downscale=GLOBAL_DOWNSCALE,
                       keep_masks=KEEP_MASKS):
    all_boxes, all_scores, all_masks = [], [], []

    if use_tiling:
        tiles = cached_tiles if cached_tiles is not None else [
            (x1, y1, x2, y2, image.crop((x1, y1, x2, y2)))
            for (x1, y1, x2, y2) in tile_bboxes(image.width, image.height, tile_size, overlap)
        ]

        for start in range(0, len(tiles), batch_size):
            chunk = tiles[start:start + batch_size]
            composed_tiles = []
            crop_boxes, offset = None, None
            for (x1, y1, x2, y2, tile) in chunk:
                ct, cb, off = compose_tile_with_exemplars(tile, exemplar_crops, margin=6, feather_width=8)
                composed_tiles.append(ct)
                crop_boxes, offset = cb, off

            batch_results = run_sam3_on_tiles_batched(
                composed_tiles, crop_boxes, offset,
                threshold=threshold, batch_size=batch_size, use_fp16=use_fp16,
            )

            for (x1, y1, x2, y2, _), (boxes, scores, masks) in zip(chunk, batch_results):
                tile_w, tile_h = x2 - x1, y2 - y1
                boxes, scores, masks = filter_implausible_boxes(
                    boxes, scores, masks, tile_w, tile_h,
                    min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5,
                )
                for b, s, m in zip(boxes, scores, masks):
                    all_boxes.append([b[0] + x1, b[1] + y1, b[2] + x1, b[3] + y1])
                    all_scores.append(s.item() if torch.is_tensor(s) else s)
                    all_masks.append((m, x1, y1) if keep_masks else None)

            for ct in composed_tiles:
                ct.close()
            del composed_tiles

        torch.cuda.empty_cache()

    else:
        composed, crop_boxes, offset = compose_tile_with_exemplars(image, exemplar_crops, margin=6, feather_width=8)
        results = run_sam3_on_tiles_batched(
            [composed], crop_boxes, offset, threshold=threshold, batch_size=1,
            use_fp16=use_fp16,
        )
        boxes, scores, masks = results[0]
        boxes, scores, masks = filter_implausible_boxes(
            boxes, scores, masks, image.width, image.height,
            min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5,
        )
        for b, s, m in zip(boxes, scores, masks):
            all_boxes.append([b[0], b[1], b[2], b[3]])
            all_scores.append(s.item() if torch.is_tensor(s) else s)
            all_masks.append((m, 0, 0))

        composed.close()


    # ---- Optional global downsampled context pass (off by default) ----
    if add_global_pass:
        small_img = image.resize((image.width // global_downscale, image.height // global_downscale))
        # single-image, non-tiled call -- reuses the whole-image branch logic above
        g_composed, g_crop_boxes, g_offset = compose_tile_with_exemplars(
            small_img, exemplar_crops, margin=6, feather_width=8
        )
        g_results = run_sam3_on_tiles_batched(
            [g_composed], g_crop_boxes, g_offset, threshold=threshold, batch_size=1,
            use_fp16=use_fp16
        )
        g_boxes, g_scores, g_masks = g_results[0]
        g_boxes, g_scores, g_masks = filter_implausible_boxes(
            g_boxes, g_scores, g_masks, small_img.width, small_img.height,
            min_fill_ratio=0.15, max_area_fraction=0.6, edge_margin=5,
        )
        # scale detections from the small image back up to full-image coordinates
        scale = image.width / small_img.width
        for b, s, m in zip(g_boxes, g_scores, g_masks):
            all_boxes.append([b[0]*scale, b[1]*scale, b[2]*scale, b[3]*scale])
            all_scores.append(s.item() if torch.is_tensor(s) else s)
            all_masks.append((m, 0, 0))  # note: mask is still at small_img resolution, not rescaled

        g_composed.close()
        small_img.close()
        gc.collect()
        torch.cuda.empty_cache()

    # NMS runs once at the end across everything -- tiled detections AND
    # (if enabled) the global-pass detections -- to remove duplicates.
    final_boxes, final_scores, final_masks = nms_merge(all_boxes, all_scores, all_masks, iou_thresh=nms_iou_thresh)
    return final_boxes, final_scores, final_masks

# %%
# Metrics helper -- refactored from Exp1's evaluation cell
# Returns mAP50, precision, recall, IoU1 (matched-only), IoU2 (over all GT)
import supervision as sv
from supervision.metrics import MeanAveragePrecision

def compute_iou_matrix(boxes1, boxes2):
    if len(boxes1) == 0 or len(boxes2) == 0:
        return np.zeros((len(boxes1), len(boxes2)))
    x1 = np.maximum(boxes1[:, None, 0], boxes2[None, :, 0])
    y1 = np.maximum(boxes1[:, None, 1], boxes2[None, :, 1])
    x2 = np.minimum(boxes1[:, None, 2], boxes2[None, :, 2])
    y2 = np.minimum(boxes1[:, None, 3], boxes2[None, :, 3])
    inter_w = np.clip(x2 - x1, 0, None)
    inter_h = np.clip(y2 - y1, 0, None)
    inter_area = inter_w * inter_h
    area1 = (boxes1[:, 2] - boxes1[:, 0]) * (boxes1[:, 3] - boxes1[:, 1])
    area2 = (boxes2[:, 2] - boxes2[:, 0]) * (boxes2[:, 3] - boxes2[:, 1])
    union_area = area1[:, None] + area2[None, :] - inter_area
    return np.where(union_area > 0, inter_area / union_area, 0.0)


def compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold: float = 0.5) -> dict:
    """
    final_boxes/final_scores: predictions for ONE run (one image, one exemplar set)
    gt_boxes: ALL GT boxes for that image (numpy array, xyxy)
    Mirrors exactly the metric logic from Exp1's evaluation cell.
    """
    pred_boxes_np = np.array(final_boxes, dtype=np.float32) if final_boxes else np.zeros((0, 4), dtype=np.float32)
    pred_scores_np = np.array(final_scores, dtype=np.float32) if final_scores else np.zeros((0,), dtype=np.float32)

    # --- mAP50 via supervision ---
    pred_detections = sv.Detections(
        xyxy=pred_boxes_np,
        confidence=pred_scores_np,
        class_id=np.zeros(len(pred_scores_np), dtype=int),
    )
    gt_detections = sv.Detections(
        xyxy=gt_boxes,
        class_id=np.zeros(len(gt_boxes), dtype=int),
    )
    try:
        map_metric = MeanAveragePrecision()
        result = map_metric.update([pred_detections], [gt_detections]).compute()
        map50 = float(result.map50)
    except Exception:
        # supervision can raise/return NaN on degenerate cases (0 preds & 0 GT etc.)
        map50 = 0.0 if len(gt_boxes) > 0 else float("nan")

    #  precision / recall / IoU via greedy matching
    num_preds, num_gt = len(pred_boxes_np), len(gt_boxes)
    iou_matrix = compute_iou_matrix(pred_boxes_np, gt_boxes)

    matched_gt = set()
    true_positives = 0
    matched_ious = []
    pred_order = np.argsort(-pred_scores_np) if num_preds > 0 else []

    for pred_idx in pred_order:
        if num_gt == 0:
            break
        best_gt_idx = np.argmax(iou_matrix[pred_idx])
        best_iou = iou_matrix[pred_idx, best_gt_idx]
        if best_iou >= iou_threshold and best_gt_idx not in matched_gt:
            matched_gt.add(best_gt_idx)
            true_positives += 1
            matched_ious.append(best_iou)

    precision = true_positives / num_preds if num_preds > 0 else 0.0
    recall = true_positives / num_gt if num_gt > 0 else 0.0
    iou1_matched_only = float(np.mean(matched_ious)) if matched_ious else 0.0
    iou2_over_all_gt = float(np.sum(matched_ious) / num_gt) if num_gt > 0 else 0.0

    return {
        "map50": map50,
        "precision": precision,
        "recall": recall,
        "iou_matched": iou1_matched_only,
        "iou_all_gt": iou2_over_all_gt,
    }

# %%
# ============================================================
# CELL: Main automated loop -- Exp x Image x Anchor Bbox -> CSV
# Now with: resume support, per-image tile caching, batched inference,
# per-image logging (time per image + running ETA)
#
# Plain English of the caching part (CHANGE 2 below): a given image
# gets processed once per GT box (once per "anchor"). Previously,
# every single anchor run re-cropped the SAME tiles from the SAME
# image from scratch -- wasted, repeated work. Now the tile crops are
# built ONCE per image (right after loading it, before the anchor
# loop starts) and reused for every anchor of that image via
# cached_tiles, then thrown away (`del cached_tiles`) once the image
# is done and we move to the next one.
# ============================================================
import psutil

done_keys = set()
file_exists = os.path.exists(OUTPUT_CSV)
if file_exists:
    existing = pd.read_csv(OUTPUT_CSV)
    existing = existing[existing["experiment_name"] == EXPERIMENT_NAME]
    done_keys = set(zip(existing["image_ID"], existing["anchor_idx"].astype(int)))
    print(f"Resuming: {len(done_keys)} rows already done for {EXPERIMENT_NAME}.")
    del existing
    gc.collect()

csv_file = open(OUTPUT_CSV, "a", newline="")
csv_writer = csv.DictWriter(csv_file, fieldnames=CSV_COLUMNS)
if not file_exists:
    csv_writer.writeheader()

start_time = time.time()
n_runs = 0
image_times = []

valid_images = [rec for rec in image_records if rec[2] is not None]
n_total_images = len(valid_images)

MEM_STOP_THRESHOLD_PCT = 70  # tune based on what the [MEM] logs show

for img_idx, (folder, image_path, label_path, image_id) in enumerate(valid_images, start=1):
    mem_pct = psutil.virtual_memory().percent
    if mem_pct > MEM_STOP_THRESHOLD_PCT:
        print(f"RAM at {mem_pct:.0f}% (threshold {MEM_STOP_THRESHOLD_PCT}%) -- "
              f"stopping cleanly before {image_id} to avoid a hard crash. "
              f"Restart the runtime and rerun this cell to resume from where you left off.")
        break

    image_t0 = time.time()

    image = Image.open(image_path).convert("RGB")
    img_w, img_h = image.size
    gt_boxes = load_yolo_boxes(label_path, img_w, img_h, class_id=RUMEX_CLASS_ID)
    n_gt = len(gt_boxes)

    if n_gt == 0:
        print(f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id}: 0 GT boxes, skipped.")
        continue

    # CHANGE 2: cache raw tile crops ONCE per image -- reused for every anchor below
    cached_tiles = None
    if USE_TILING:
        cached_tiles = [
            (x1, y1, x2, y2, image.crop((x1, y1, x2, y2)))
            for (x1, y1, x2, y2) in tile_bboxes(img_w, img_h, TILE_SIZE, OVERLAP)
        ]

    image_map50s = []

    for anchor_idx in range(n_gt):
        gc.collect()
        torch.cuda.empty_cache()

        mem_pct = psutil.virtual_memory().percent
        rss_gb = psutil.Process().memory_info().rss / 1e9
        if n_runs % 3 == 0:  # log at the same cadence as cleanup, keep it cheap
            print(f"        [MEM] anchor={anchor_idx} RSS={rss_gb:.2f} GB | system RAM used={mem_pct:.0f}%")
        if mem_pct > MEM_STOP_THRESHOLD_PCT:
            print(f"RAM at {mem_pct:.0f}% mid-image at {image_id} anchor={anchor_idx} -- "
                  f"stopping cleanly. Restart runtime and rerun to resume "
                  f"(this image's completed anchors are already saved; incomplete ones will retry).")
            csv_file.close()
            raise SystemExit("Stopped cleanly due to RAM threshold — restart runtime and rerun.")
        if (image_id, anchor_idx) in done_keys:
            continue  # skip BEFORE touching RNG at all

        run_t0 = time.time()

        try:

            exemplar_indices = select_exemplar_indices(n_gt, anchor_idx, N_EXEMPLARS, image_id)
            prompt_id = format_prompt_id(exemplar_indices)
            exemplar_crops = [image.crop([int(round(v)) for v in gt_boxes[i]]) for i in exemplar_indices]

            final_boxes, final_scores, final_masks = run_sam3_pipeline(
                image, exemplar_crops, use_tiling=USE_TILING,
                tile_size=TILE_SIZE, overlap=OVERLAP, threshold=THRESHOLD,
                cached_tiles=cached_tiles, batch_size=BATCH_SIZE,
                nms_iou_thresh=NMS_IOU_THRESHOLD,
            )

            metrics = compute_detection_metrics(final_boxes, final_scores, gt_boxes, iou_threshold=IOU_THRESHOLD)
            image_map50s.append(metrics["map50"])

            row = {
                "experiment_name": EXPERIMENT_NAME,
                "image_ID": image_id,
                "anchor_idx": anchor_idx,
                "Prompt_ID": prompt_id,
                "Prompt_Type": PROMPT_TYPE,
                "mAP50": metrics["map50"],
                "precision": metrics["precision"],
                "recall": metrics["recall"],
                "IoU1": metrics["iou_matched"],
                "IoU2": metrics["iou_all_gt"],
            }
            csv_writer.writerow(row)
            csv_file.flush()
            os.fsync(csv_file.fileno())
            n_runs += 1

            del final_boxes, final_scores, final_masks, exemplar_crops

        except Exception as e:
                print(f"    ERROR on {image_id} anchor={anchor_idx}: {type(e).__name__}: {e} -- skipping, not written to CSV.")
                gc.collect()
                torch.cuda.empty_cache()
                continue

       # gc.collect() force a CUDA sync each call, costly when batching
        gc.collect()
        torch.cuda.empty_cache()

        run_elapsed = time.time() - run_t0
        print(
            f"    [{EXPERIMENT_NAME}] run #{n_runs} | image={image_id} | "
            f"anchor={anchor_idx} ({anchor_idx+1}/{n_gt}) | prompt_id={prompt_id} | "
            f"mAP50={metrics['map50']:.3f} | time={run_elapsed:.1f}s"
        )

    # free this image's cached tiles before moving on
    del cached_tiles
    image.close()
    gc.collect()
    torch.cuda.empty_cache()

    image_elapsed = time.time() - image_t0
    image_times.append(image_elapsed)
    avg_time_per_image = np.mean(image_times)
    images_left = n_total_images - img_idx
    eta_seconds = images_left * avg_time_per_image

    map50_str = f"{np.mean(image_map50s):.3f}" if image_map50s else "N/A (all anchors already done, skipped)"

    print(
        f"[{EXPERIMENT_NAME}] ({img_idx}/{n_total_images}) {image_id} done | "
        f"{n_gt} GT box(es) | image_mAP50_mean={map50_str} | "
        f"time={image_elapsed:.1f}s | avg/image={avg_time_per_image:.1f}s | "
        f"ETA={eta_seconds/60:.1f} min ({eta_seconds/3600:.2f} h)"
    )

    rss_gb = psutil.Process().memory_info().rss / 1e9
    avail_gb = psutil.virtual_memory().available / 1e9
    print(f"    [MEM] process RSS={rss_gb:.2f} GB | system available={avail_gb:.2f} GB")

csv_file.close()
total_elapsed = time.time() - start_time
print(f"\nFinished {EXPERIMENT_NAME}: {n_runs} new rows written to {OUTPUT_CSV}")
print(f"Total time: {total_elapsed/60:.1f} min ({total_elapsed/3600:.2f} h)")
# Out:
# Resuming: 9 rows already done for E01_2.
#         [MEM] anchor=0 RSS=3.63 GB | system RAM used=45%
# [E01_2] (1/179) 20220513_Halden/DJI_20220513075116_0213 done | 1 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.7s | avg/image=1.7s | ETA=5.0 min (0.08 h)
#     [MEM] process RSS=3.20 GB | system available=7.93 GB
#         [MEM] anchor=0 RSS=3.63 GB | system RAM used=45%
#         [MEM] anchor=1 RSS=3.63 GB | system RAM used=45%
# [E01_2] (2/179) 20220513_Halden/DJI_20220513075207_0234 done | 2 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=1.9s | avg/image=1.8s | ETA=5.2 min (0.09 h)
#     [MEM] process RSS=3.20 GB | system available=7.90 GB
#         [MEM] anchor=0 RSS=3.63 GB | system RAM used=45%
#         [MEM] anchor=1 RSS=3.63 GB | system RAM used=45%
#         [MEM] anchor=2 RSS=3.63 GB | system RAM used=45%
#         [MEM] anchor=3 RSS=3.63 GB | system RAM used=45%
#         [MEM] anchor=4 RSS=3.63 GB | system RAM used=45%
#         [MEM] anchor=5 RSS=3.63 GB | system RAM used=45%
# [E01_2] (3/179) 20220513_Halden/DJI_20220513075336_0270 done | 6 GT box(es) | image_mAP50_mean=N/A (all anchors already done, skipped) | time=2.5s | avg/image=2.0s | ETA=5.9 min (0.10 h)
#     [MEM] process RSS=3.20 GB | system available=7.91 GB
#         [MEM] anchor=0 RSS=3.63 GB | system RAM used=45%
# /tmp/ipykernel_2622/3591573759.py:35: DeprecationWarning: 'mode' parameter is deprecated and will be removed in Pillow 13 (2026-10-15)
#   return Image.fromarray(mask.astype(np.uint8), mode="L")  # <-- return a PIL Image, not ndarray
#     [E01_2] run #1 | image=20220513_Halden/DJI_20220513075432_0295 | anchor=0 (1/3) | prompt_id=0 | mAP50=0.418 | time=20.0s
#     [E01_2] run #2 | image=20220513_Halden/DJI_20220513075432_0295 | anchor=1 (2/3) | prompt_id=1 | mAP50=0.681 | time=20.6s
#     [E01_2] run #3 | image=20220513_Halden/DJI_20220513075432_0295 | anchor=2 (3/3) | prompt_id=2 | mAP50=0.764 | time=19.9s
# [E01_2] (4/179) 20220513_Halden/DJI_20220513075432_0295 done | 3 GT box(es) | image_mAP50_mean=0.621 | time=62.2s | avg/image=17.0s | ETA=49.7 min (0.83 h)
#     [MEM] process RSS=3.20 GB | system available=7.94 GB
#         [MEM] anchor=0 RSS=3.61 GB | system RAM used=45%
#     [E01_2] run #4 | image=20220513_Halden/DJI_20220513075444_0300 | anchor=0 (1/3) | prompt_id=0 | mAP50=0.663 | time=20.7s
#     [E01_2] run #5 | image=20220513_Halden/DJI_20220513075444_0300 | anchor=1 (2/3) | prompt_id=1 | mAP50=0.332 | time=20.6s
#     [E01_2] run #6 | image=20220513_Halden/DJI_20220513075444_0300 | anchor=2 (3/3) | prompt_id=2 | mAP50=0.442 | time=20.5s
# [E01_2] (5/179) 20220513_Halden/DJI_20220513075444_0300 done | 3 GT box(es) | image_mAP50_mean=0.479 | time=63.5s | avg/image=26.3s | ETA=76.4 min (1.27 h)
#     [MEM] process RSS=3.20 GB | system available=7.94 GB
#         [MEM] anchor=0 RSS=3.61 GB | system RAM used=44%
#     [E01_2] run #7 | image=20220513_Halden/DJI_20220513075506_0309 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.500 | time=19.9s
# [E01_2] (6/179) 20220513_Halden/DJI_20220513075506_0309 done | 1 GT box(es) | image_mAP50_mean=0.500 | time=21.0s | avg/image=25.5s | ETA=73.4 min (1.22 h)
#     [MEM] process RSS=3.20 GB | system available=7.94 GB
#     [E01_2] run #8 | image=20220513_Halden/DJI_20220513075707_0358 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.500 | time=20.8s
# [E01_2] (7/179) 20220513_Halden/DJI_20220513075707_0358 done | 1 GT box(es) | image_mAP50_mean=0.500 | time=22.1s | avg/image=25.0s | ETA=71.6 min (1.19 h)
#     [MEM] process RSS=3.20 GB | system available=7.93 GB
#     [E01_2] run #9 | image=20220513_Halden/DJI_20220513075753_0379 | anchor=0 (1/4) | prompt_id=0 | mAP50=0.456 | time=21.1s
#         [MEM] anchor=1 RSS=3.65 GB | system RAM used=45%
#     [E01_2] run #10 | image=20220513_Halden/DJI_20220513075753_0379 | anchor=1 (2/4) | prompt_id=1 | mAP50=0.252 | time=20.8s
#     [E01_2] run #11 | image=20220513_Halden/DJI_20220513075753_0379 | anchor=2 (3/4) | prompt_id=2 | mAP50=0.282 | time=21.5s
#     [E01_2] run #12 | image=20220513_Halden/DJI_20220513075753_0379 | anchor=3 (4/4) | prompt_id=3 | mAP50=0.328 | time=20.5s
# [E01_2] (8/179) 20220513_Halden/DJI_20220513075753_0379 done | 4 GT box(es) | image_mAP50_mean=0.330 | time=85.9s | avg/image=32.6s | ETA=92.9 min (1.55 h)
#     [MEM] process RSS=3.20 GB | system available=7.95 GB
#         [MEM] anchor=0 RSS=3.61 GB | system RAM used=44%
#     [E01_2] run #13 | image=20220513_Halden/DJI_20220513075822_0391 | anchor=0 (1/5) | prompt_id=0 | mAP50=0.489 | time=21.8s
#     [E01_2] run #14 | image=20220513_Halden/DJI_20220513075822_0391 | anchor=1 (2/5) | prompt_id=1 | mAP50=0.231 | time=22.8s
#     [E01_2] run #15 | image=20220513_Halden/DJI_20220513075822_0391 | anchor=2 (3/5) | prompt_id=2 | mAP50=0.802 | time=21.4s
#         [MEM] anchor=3 RSS=3.61 GB | system RAM used=44%
#     [E01_2] run #16 | image=20220513_Halden/DJI_20220513075822_0391 | anchor=3 (4/5) | prompt_id=3 | mAP50=0.274 | time=22.8s
#     [E01_2] run #17 | image=20220513_Halden/DJI_20220513075822_0391 | anchor=4 (5/5) | prompt_id=4 | mAP50=0.604 | time=20.3s
# [E01_2] (9/179) 20220513_Halden/DJI_20220513075822_0391 done | 5 GT box(es) | image_mAP50_mean=0.480 | time=111.4s | avg/image=41.3s | ETA=117.1 min (1.95 h)
#     [MEM] process RSS=3.20 GB | system available=7.94 GB
#     [E01_2] run #18 | image=20220513_Halden/DJI_20220513075916_0413 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.333 | time=20.4s
# [E01_2] (10/179) 20220513_Halden/DJI_20220513075916_0413 done | 1 GT box(es) | image_mAP50_mean=0.333 | time=23.0s | avg/image=39.5s | ETA=111.3 min (1.85 h)
#     [MEM] process RSS=3.20 GB | system available=7.93 GB
#         [MEM] anchor=0 RSS=3.61 GB | system RAM used=44%
#     [E01_2] run #19 | image=20220701_Halden/DJI_20220701165417_0004 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.036 | time=27.2s
#     [E01_2] run #20 | image=20220701_Halden/DJI_20220701165417_0004 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.061 | time=23.8s
# [E01_2] (11/179) 20220701_Halden/DJI_20220701165417_0004 done | 2 GT box(es) | image_mAP50_mean=0.049 | time=54.2s | avg/image=40.8s | ETA=114.4 min (1.91 h)
#     [MEM] process RSS=3.20 GB | system available=7.95 GB
# [E01_2] (12/179) 20220701_Halden/DJI_20220701170828_0136: 0 GT boxes, skipped.
#     [E01_2] run #21 | image=20220701_Halden/DJI_20220701170852_0151 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.222 | time=20.0s
#         [MEM] anchor=1 RSS=3.62 GB | system RAM used=45%
#     [E01_2] run #22 | image=20220701_Halden/DJI_20220701170852_0151 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.000 | time=20.5s
# [E01_2] (13/179) 20220701_Halden/DJI_20220701170852_0151 done | 2 GT box(es) | image_mAP50_mean=0.111 | time=43.6s | avg/image=41.1s | ETA=113.7 min (1.89 h)
#     [MEM] process RSS=3.20 GB | system available=7.92 GB
#     [E01_2] run #23 | image=20220701_Halden/DJI_20220701170908_0161 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.000 | time=19.7s
# [E01_2] (14/179) 20220701_Halden/DJI_20220701170908_0161 done | 1 GT box(es) | image_mAP50_mean=0.000 | time=23.0s | avg/image=39.7s | ETA=109.1 min (1.82 h)
#     [MEM] process RSS=3.20 GB | system available=7.94 GB
# [E01_2] (15/179) 20220701_Halden/DJI_20220701170934_0178: 0 GT boxes, skipped.
# [E01_2] (16/179) 20220701_Halden/DJI_20220701170943_0185: 0 GT boxes, skipped.
# [E01_2] (17/179) 20220701_Halden/DJI_20220701170957_0193: 0 GT boxes, skipped.
# [E01_2] (18/179) 20220701_Halden/DJI_20220701171012_0203: 0 GT boxes, skipped.
# [E01_2] (19/179) 20220701_Halden/DJI_20220701171049_0225: 0 GT boxes, skipped.
#     [E01_2] run #24 | image=20220701_Halden/DJI_20220701171150_0238 | anchor=0 (1/3) | prompt_id=0 | mAP50=0.361 | time=23.5s
#         [MEM] anchor=1 RSS=3.62 GB | system RAM used=45%
#     [E01_2] run #25 | image=20220701_Halden/DJI_20220701171150_0238 | anchor=1 (2/3) | prompt_id=1 | mAP50=0.699 | time=21.7s
#     [E01_2] run #26 | image=20220701_Halden/DJI_20220701171150_0238 | anchor=2 (3/3) | prompt_id=2 | mAP50=0.536 | time=19.9s
# [E01_2] (20/179) 20220701_Halden/DJI_20220701171150_0238 done | 3 GT box(es) | image_mAP50_mean=0.532 | time=68.3s | avg/image=41.7s | ETA=110.6 min (1.84 h)
#     [MEM] process RSS=3.20 GB | system available=7.93 GB
#     [E01_2] run #27 | image=20220701_Waldegg/DJI_20220701173416_0008 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.505 | time=25.1s
#         [MEM] anchor=1 RSS=3.61 GB | system RAM used=45%
#     [E01_2] run #28 | image=20220701_Waldegg/DJI_20220701173416_0008 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.505 | time=23.2s
# [E01_2] (21/179) 20220701_Waldegg/DJI_20220701173416_0008 done | 2 GT box(es) | image_mAP50_mean=0.505 | time=51.5s | avg/image=42.4s | ETA=111.6 min (1.86 h)
#     [MEM] process RSS=3.20 GB | system available=7.93 GB
# [E01_2] (22/179) 20220701_Waldegg/DJI_20220701173429_0016: 0 GT boxes, skipped.
# [E01_2] (23/179) 20220701_Waldegg/DJI_20220701173552_0032: 0 GT boxes, skipped.
#     [E01_2] run #29 | image=20220701_Waldegg/DJI_20220701173614_0046 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.000 | time=22.3s
# [E01_2] (24/179) 20220701_Waldegg/DJI_20220701173614_0046 done | 1 GT box(es) | image_mAP50_mean=0.000 | time=25.2s | avg/image=41.3s | ETA=106.7 min (1.78 h)
#     [MEM] process RSS=3.84 GB | system available=7.32 GB
#     [E01_2] run #30 | image=20220701_Waldegg/DJI_20220701173639_0062 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.333 | time=22.8s
# [E01_2] (25/179) 20220701_Waldegg/DJI_20220701173639_0062 done | 1 GT box(es) | image_mAP50_mean=0.333 | time=25.9s | avg/image=40.4s | ETA=103.7 min (1.73 h)
#     [MEM] process RSS=3.20 GB | system available=7.94 GB
# [E01_2] (26/179) 20220701_Waldegg/DJI_20220701173702_0076: 0 GT boxes, skipped.
#         [MEM] anchor=0 RSS=3.62 GB | system RAM used=44%
#     [E01_2] run #31 | image=20220701_Waldegg/DJI_20220701173741_0100 | anchor=0 (1/3) | prompt_id=0 | mAP50=0.456 | time=25.9s
#     [E01_2] run #32 | image=20220701_Waldegg/DJI_20220701173741_0100 | anchor=1 (2/3) | prompt_id=1 | mAP50=0.418 | time=26.9s
#     [E01_2] run #33 | image=20220701_Waldegg/DJI_20220701173741_0100 | anchor=2 (3/3) | prompt_id=2 | mAP50=0.663 | time=22.2s
# [E01_2] (27/179) 20220701_Waldegg/DJI_20220701173741_0100 done | 3 GT box(es) | image_mAP50_mean=0.513 | time=78.2s | avg/image=42.5s | ETA=107.7 min (1.79 h)
#     [MEM] process RSS=3.19 GB | system available=7.93 GB
#         [MEM] anchor=0 RSS=3.59 GB | system RAM used=44%
#     [E01_2] run #34 | image=20220701_Waldegg/DJI_20220701173746_0103 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.529 | time=35.1s
#     [E01_2] run #35 | image=20220701_Waldegg/DJI_20220701173746_0103 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.505 | time=24.2s
# [E01_2] (28/179) 20220701_Waldegg/DJI_20220701173746_0103 done | 2 GT box(es) | image_mAP50_mean=0.517 | time=62.6s | avg/image=43.6s | ETA=109.6 min (1.83 h)
#     [MEM] process RSS=3.12 GB | system available=7.93 GB
#     [E01_2] run #36 | image=20220701_Waldegg/DJI_20220701174049_0215 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.000 | time=29.6s
# [E01_2] (29/179) 20220701_Waldegg/DJI_20220701174049_0215 done | 1 GT box(es) | image_mAP50_mean=0.000 | time=32.9s | avg/image=43.0s | ETA=107.6 min (1.79 h)
#     [MEM] process RSS=3.12 GB | system available=7.94 GB
# [E01_2] (30/179) 20220701_Waldegg/DJI_20220701174249_0292: 0 GT boxes, skipped.
# [E01_2] (31/179) 20220708_Herrenpuent/DJI_20220708152335_0016: 0 GT boxes, skipped.
# [E01_2] (32/179) 20220708_Herrenpuent/DJI_20220708152405_0036: 0 GT boxes, skipped.
# [E01_2] (33/179) 20220708_Herrenpuent/DJI_20220708152423_0047: 0 GT boxes, skipped.
# [E01_2] (34/179) 20220708_Herrenpuent/DJI_20220708152437_0056: 0 GT boxes, skipped.
#         [MEM] anchor=0 RSS=3.53 GB | system RAM used=45%
#     [E01_2] run #37 | image=20220708_Herrenpuent/DJI_20220708152505_0073 | anchor=0 (1/5) | prompt_id=0 | mAP50=0.407 | time=20.6s
#     [E01_2] run #38 | image=20220708_Herrenpuent/DJI_20220708152505_0073 | anchor=1 (2/5) | prompt_id=1 | mAP50=0.161 | time=21.6s
#     [E01_2] run #39 | image=20220708_Herrenpuent/DJI_20220708152505_0073 | anchor=2 (3/5) | prompt_id=2 | mAP50=0.049 | time=22.6s
#         [MEM] anchor=3 RSS=3.67 GB | system RAM used=46%
#     [E01_2] run #40 | image=20220708_Herrenpuent/DJI_20220708152505_0073 | anchor=3 (4/5) | prompt_id=3 | mAP50=0.071 | time=23.0s
#     [E01_2] run #41 | image=20220708_Herrenpuent/DJI_20220708152505_0073 | anchor=4 (5/5) | prompt_id=4 | mAP50=0.144 | time=21.5s
# [E01_2] (35/179) 20220708_Herrenpuent/DJI_20220708152505_0073 done | 5 GT box(es) | image_mAP50_mean=0.166 | time=113.9s | avg/image=46.4s | ETA=111.4 min (1.86 h)
#     [MEM] process RSS=3.12 GB | system available=7.92 GB
# [E01_2] (36/179) 20220708_Herrenpuent/DJI_20220708152528_0087: 0 GT boxes, skipped.
#     [E01_2] run #42 | image=20220708_Herrenpuent/DJI_20220708152551_0102 | anchor=0 (1/1) | prompt_id=0 | mAP50=1.000 | time=20.5s
# [E01_2] (37/179) 20220708_Herrenpuent/DJI_20220708152551_0102 done | 1 GT box(es) | image_mAP50_mean=1.000 | time=24.5s | avg/image=45.4s | ETA=107.5 min (1.79 h)
#     [MEM] process RSS=3.12 GB | system available=7.89 GB
# [E01_2] (38/179) 20220708_Herrenpuent/DJI_20220708152616_0112: 0 GT boxes, skipped.
#         [MEM] anchor=0 RSS=3.53 GB | system RAM used=44%
#     [E01_2] run #43 | image=20220708_Herrenpuent/DJI_20220708152637_0125 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.333 | time=22.3s
# [E01_2] (39/179) 20220708_Herrenpuent/DJI_20220708152637_0125 done | 1 GT box(es) | image_mAP50_mean=0.333 | time=25.4s | avg/image=44.5s | ETA=103.9 min (1.73 h)
#     [MEM] process RSS=3.12 GB | system available=7.95 GB
#     [E01_2] run #44 | image=20220708_Herrenpuent/DJI_20220708152738_0164 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.000 | time=31.9s
#     [E01_2] run #45 | image=20220708_Herrenpuent/DJI_20220708152738_0164 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.000 | time=27.9s
# [E01_2] (40/179) 20220708_Herrenpuent/DJI_20220708152738_0164 done | 2 GT box(es) | image_mAP50_mean=0.000 | time=63.3s | avg/image=45.3s | ETA=105.0 min (1.75 h)
#     [MEM] process RSS=3.09 GB | system available=7.94 GB
#         [MEM] anchor=0 RSS=3.50 GB | system RAM used=44%
#     [E01_2] run #46 | image=20220902_Herrenpuent/DJI_20220902101510_0137 | anchor=0 (1/1) | prompt_id=0 | mAP50=1.000 | time=20.7s
# [E01_2] (41/179) 20220902_Herrenpuent/DJI_20220902101510_0137 done | 1 GT box(es) | image_mAP50_mean=1.000 | time=22.8s | avg/image=44.4s | ETA=102.2 min (1.70 h)
#     [MEM] process RSS=3.09 GB | system available=7.93 GB
# [E01_2] (42/179) 20220902_Herrenpuent/DJI_20220902102152_0354: 0 GT boxes, skipped.
#     [E01_2] run #47 | image=20220902_Herrenpuent/DJI_20220902102227_0374 | anchor=0 (1/3) | prompt_id=0 | mAP50=0.646 | time=22.5s
#     [E01_2] run #48 | image=20220902_Herrenpuent/DJI_20220902102227_0374 | anchor=1 (2/3) | prompt_id=1 | mAP50=0.668 | time=21.0s
#         [MEM] anchor=2 RSS=3.50 GB | system RAM used=44%
#     [E01_2] run #49 | image=20220902_Herrenpuent/DJI_20220902102227_0374 | anchor=2 (3/3) | prompt_id=2 | mAP50=0.442 | time=21.3s
# [E01_2] (43/179) 20220902_Herrenpuent/DJI_20220902102227_0374 done | 3 GT box(es) | image_mAP50_mean=0.586 | time=67.8s | avg/image=45.3s | ETA=102.7 min (1.71 h)
#     [MEM] process RSS=3.09 GB | system available=7.93 GB
#     [E01_2] run #50 | image=20220902_Herrenpuent/DJI_20220902102331_0408 | anchor=0 (1/1) | prompt_id=0 | mAP50=0.333 | time=20.0s
# [E01_2] (44/179) 20220902_Herrenpuent/DJI_20220902102331_0408 done | 1 GT box(es) | image_mAP50_mean=0.333 | time=22.9s | avg/image=44.5s | ETA=100.1 min (1.67 h)
#     [MEM] process RSS=3.09 GB | system available=7.93 GB
#     [E01_2] run #51 | image=20220902_Herrenpuent/DJI_20220902102358_0423 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.126 | time=23.7s
#         [MEM] anchor=1 RSS=3.51 GB | system RAM used=45%
#     [E01_2] run #52 | image=20220902_Herrenpuent/DJI_20220902102358_0423 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.835 | time=20.8s
# [E01_2] (45/179) 20220902_Herrenpuent/DJI_20220902102358_0423 done | 2 GT box(es) | image_mAP50_mean=0.481 | time=47.2s | avg/image=44.6s | ETA=99.6 min (1.66 h)
#     [MEM] process RSS=3.09 GB | system available=7.93 GB
#     [E01_2] run #53 | image=20220902_Herrenpuent/DJI_20220902102502_0458 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.505 | time=20.3s
#     [E01_2] run #54 | image=20220902_Herrenpuent/DJI_20220902102502_0458 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.505 | time=20.9s
# [E01_2] (46/179) 20220902_Herrenpuent/DJI_20220902102502_0458 done | 2 GT box(es) | image_mAP50_mean=0.505 | time=44.4s | avg/image=44.6s | ETA=98.8 min (1.65 h)
#     [MEM] process RSS=3.09 GB | system available=7.94 GB
#         [MEM] anchor=0 RSS=3.50 GB | system RAM used=44%
#     [E01_2] run #55 | image=20220902_Herrenpuent/DJI_20220902102606_0492 | anchor=0 (1/3) | prompt_id=0 | mAP50=0.554 | time=22.7s
#     [E01_2] run #56 | image=20220902_Herrenpuent/DJI_20220902102606_0492 | anchor=1 (2/3) | prompt_id=1 | mAP50=0.442 | time=22.7s
#     [E01_2] run #57 | image=20220902_Herrenpuent/DJI_20220902102606_0492 | anchor=2 (3/3) | prompt_id=2 | mAP50=0.500 | time=21.7s
# [E01_2] (47/179) 20220902_Herrenpuent/DJI_20220902102606_0492 done | 3 GT box(es) | image_mAP50_mean=0.499 | time=69.9s | avg/image=45.4s | ETA=99.9 min (1.67 h)
#     [MEM] process RSS=3.09 GB | system available=7.97 GB
#         [MEM] anchor=0 RSS=3.50 GB | system RAM used=44%
#     [E01_2] run #58 | image=20220902_Herrenpuent/DJI_20220902102721_0533 | anchor=0 (1/3) | prompt_id=0 | mAP50=0.467 | time=23.2s
#     [E01_2] run #59 | image=20220902_Herrenpuent/DJI_20220902102721_0533 | anchor=1 (2/3) | prompt_id=1 | mAP50=0.332 | time=21.1s
#     [E01_2] run #60 | image=20220902_Herrenpuent/DJI_20220902102721_0533 | anchor=2 (3/3) | prompt_id=2 | mAP50=0.299 | time=20.7s
# [E01_2] (48/179) 20220902_Herrenpuent/DJI_20220902102721_0533 done | 3 GT box(es) | image_mAP50_mean=0.366 | time=68.0s | avg/image=46.2s | ETA=100.8 min (1.68 h)
#     [MEM] process RSS=3.09 GB | system available=7.94 GB
#         [MEM] anchor=0 RSS=3.50 GB | system RAM used=44%
#     [E01_2] run #61 | image=20220902_Herrenpuent/DJI_20220902103027_0633 | anchor=0 (1/1) | prompt_id=0 | mAP50=1.000 | time=20.0s
# [E01_2] (49/179) 20220902_Herrenpuent/DJI_20220902103027_0633 done | 1 GT box(es) | image_mAP50_mean=1.000 | time=23.2s | avg/image=45.4s | ETA=98.4 min (1.64 h)
#     [MEM] process RSS=3.54 GB | system available=7.48 GB
#     [E01_2] run #62 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=0 (1/21) | prompt_id=0 | mAP50=0.373 | time=22.5s
#     [E01_2] run #63 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=1 (2/21) | prompt_id=1 | mAP50=0.017 | time=30.1s
#         [MEM] anchor=2 RSS=3.49 GB | system RAM used=45%
#     [E01_2] run #64 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=2 (3/21) | prompt_id=2 | mAP50=0.200 | time=26.7s
#     [E01_2] run #65 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=3 (4/21) | prompt_id=3 | mAP50=0.322 | time=20.9s
#     [E01_2] run #66 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=4 (5/21) | prompt_id=4 | mAP50=0.307 | time=28.1s
#         [MEM] anchor=5 RSS=3.52 GB | system RAM used=45%
#     [E01_2] run #67 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=5 (6/21) | prompt_id=5 | mAP50=0.443 | time=23.7s
#     [E01_2] run #68 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=6 (7/21) | prompt_id=6 | mAP50=0.299 | time=23.6s
#     [E01_2] run #69 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=7 (8/21) | prompt_id=7 | mAP50=0.013 | time=33.8s
#         [MEM] anchor=8 RSS=3.60 GB | system RAM used=45%
#     [E01_2] run #70 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=8 (9/21) | prompt_id=8 | mAP50=0.163 | time=28.1s
#     [E01_2] run #71 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=9 (10/21) | prompt_id=9 | mAP50=0.255 | time=25.6s
#     [E01_2] run #72 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=10 (11/21) | prompt_id=10 | mAP50=0.013 | time=31.9s
#         [MEM] anchor=11 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #73 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=11 (12/21) | prompt_id=11 | mAP50=0.338 | time=22.5s
#     [E01_2] run #74 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=12 (13/21) | prompt_id=12 | mAP50=0.391 | time=20.9s
#     [E01_2] run #75 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=13 (14/21) | prompt_id=13 | mAP50=0.464 | time=21.9s
#         [MEM] anchor=14 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #76 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=14 (15/21) | prompt_id=14 | mAP50=0.448 | time=20.4s
#     [E01_2] run #77 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=15 (16/21) | prompt_id=15 | mAP50=0.388 | time=20.8s
#     [E01_2] run #78 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=16 (17/21) | prompt_id=16 | mAP50=0.488 | time=20.9s
#         [MEM] anchor=17 RSS=3.62 GB | system RAM used=46%
#     [E01_2] run #79 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=17 (18/21) | prompt_id=17 | mAP50=0.428 | time=23.7s
#     [E01_2] run #80 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=18 (19/21) | prompt_id=18 | mAP50=0.444 | time=21.0s
#     [E01_2] run #81 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=19 (20/21) | prompt_id=19 | mAP50=0.017 | time=29.1s
#         [MEM] anchor=20 RSS=4.34 GB | system RAM used=51%
#     [E01_2] run #82 | image=20220902_Herrenpuent/DJI_20220902103325_0729 | anchor=20 (21/21) | prompt_id=20 | mAP50=0.010 | time=29.9s
# [E01_2] (50/179) 20220902_Herrenpuent/DJI_20220902103325_0729 done | 21 GT box(es) | image_mAP50_mean=0.277 | time=533.4s | avg/image=60.2s | ETA=129.5 min (2.16 h)
#     [MEM] process RSS=3.64 GB | system available=7.38 GB
#     [E01_2] run #83 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=0 (1/9) | prompt_id=0 | mAP50=0.337 | time=20.5s
#     [E01_2] run #84 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=1 (2/9) | prompt_id=1 | mAP50=0.119 | time=23.9s
#         [MEM] anchor=2 RSS=3.63 GB | system RAM used=46%
#     [E01_2] run #85 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=2 (3/9) | prompt_id=2 | mAP50=0.347 | time=21.1s
#     [E01_2] run #86 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=3 (4/9) | prompt_id=3 | mAP50=0.373 | time=21.8s
#     [E01_2] run #87 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=4 (5/9) | prompt_id=4 | mAP50=0.437 | time=22.0s
#         [MEM] anchor=5 RSS=3.67 GB | system RAM used=46%
#     [E01_2] run #88 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=5 (6/9) | prompt_id=5 | mAP50=0.401 | time=22.7s
#     [E01_2] run #89 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=6 (7/9) | prompt_id=6 | mAP50=0.346 | time=21.3s
#     [E01_2] run #90 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=7 (8/9) | prompt_id=7 | mAP50=0.388 | time=21.8s
#         [MEM] anchor=8 RSS=3.63 GB | system RAM used=46%
#     [E01_2] run #91 | image=20221010_HaldenNord/DJI_20221010151043_0001 | anchor=8 (9/9) | prompt_id=8 | mAP50=0.373 | time=22.4s
# [E01_2] (51/179) 20221010_HaldenNord/DJI_20221010151043_0001 done | 9 GT box(es) | image_mAP50_mean=0.347 | time=202.5s | avg/image=64.4s | ETA=137.4 min (2.29 h)
#     [MEM] process RSS=3.60 GB | system available=7.39 GB
#     [E01_2] run #92 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=0 (1/13) | prompt_id=0 | mAP50=0.211 | time=20.7s
#     [E01_2] run #93 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=1 (2/13) | prompt_id=1 | mAP50=0.134 | time=22.4s
#         [MEM] anchor=2 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #94 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=2 (3/13) | prompt_id=2 | mAP50=0.111 | time=20.8s
#     [E01_2] run #95 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=3 (4/13) | prompt_id=3 | mAP50=0.220 | time=22.5s
#     [E01_2] run #96 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=4 (5/13) | prompt_id=4 | mAP50=0.135 | time=20.4s
#         [MEM] anchor=5 RSS=3.67 GB | system RAM used=46%
#     [E01_2] run #97 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=5 (6/13) | prompt_id=5 | mAP50=0.127 | time=22.8s
#     [E01_2] run #98 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=6 (7/13) | prompt_id=6 | mAP50=0.173 | time=21.3s
#     [E01_2] run #99 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=7 (8/13) | prompt_id=7 | mAP50=0.198 | time=21.0s
#         [MEM] anchor=8 RSS=3.63 GB | system RAM used=46%
#     [E01_2] run #100 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=8 (9/13) | prompt_id=8 | mAP50=0.110 | time=22.8s
#     [E01_2] run #101 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=9 (10/13) | prompt_id=9 | mAP50=0.127 | time=22.6s
#     [E01_2] run #102 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=10 (11/13) | prompt_id=10 | mAP50=0.198 | time=21.8s
#         [MEM] anchor=11 RSS=3.65 GB | system RAM used=46%
#     [E01_2] run #103 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=11 (12/13) | prompt_id=11 | mAP50=0.111 | time=22.6s
#     [E01_2] run #104 | image=20221010_HaldenNord/DJI_20221010151055_0012 | anchor=12 (13/13) | prompt_id=12 | mAP50=0.113 | time=23.6s
# [E01_2] (52/179) 20221010_HaldenNord/DJI_20221010151055_0012 done | 13 GT box(es) | image_mAP50_mean=0.151 | time=291.5s | avg/image=70.9s | ETA=150.1 min (2.50 h)
#     [MEM] process RSS=3.60 GB | system available=7.40 GB
#     [E01_2] run #105 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=0 (1/18) | prompt_id=0 | mAP50=0.166 | time=22.5s
#         [MEM] anchor=1 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #106 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=1 (2/18) | prompt_id=1 | mAP50=0.316 | time=21.3s
#     [E01_2] run #107 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=2 (3/18) | prompt_id=2 | mAP50=0.153 | time=22.4s
#     [E01_2] run #108 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=3 (4/18) | prompt_id=3 | mAP50=0.277 | time=20.6s
#         [MEM] anchor=4 RSS=3.62 GB | system RAM used=46%
#     [E01_2] run #109 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=4 (5/18) | prompt_id=4 | mAP50=0.149 | time=22.1s
#     [E01_2] run #110 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=5 (6/18) | prompt_id=5 | mAP50=0.122 | time=22.3s
#     [E01_2] run #111 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=6 (7/18) | prompt_id=6 | mAP50=0.116 | time=22.5s
#         [MEM] anchor=7 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #112 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=7 (8/18) | prompt_id=7 | mAP50=0.307 | time=20.8s
#     [E01_2] run #113 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=8 (9/18) | prompt_id=8 | mAP50=0.142 | time=20.3s
#     [E01_2] run #114 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=9 (10/18) | prompt_id=9 | mAP50=0.261 | time=21.7s
#         [MEM] anchor=10 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #115 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=10 (11/18) | prompt_id=10 | mAP50=0.191 | time=21.4s
#     [E01_2] run #116 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=11 (12/18) | prompt_id=11 | mAP50=0.165 | time=21.0s
#     [E01_2] run #117 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=12 (13/18) | prompt_id=12 | mAP50=0.194 | time=21.2s
#         [MEM] anchor=13 RSS=3.60 GB | system RAM used=45%
#     [E01_2] run #118 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=13 (14/18) | prompt_id=13 | mAP50=0.068 | time=23.2s
#     [E01_2] run #119 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=14 (15/18) | prompt_id=14 | mAP50=0.099 | time=23.4s
#     [E01_2] run #120 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=15 (16/18) | prompt_id=15 | mAP50=0.104 | time=22.8s
#         [MEM] anchor=16 RSS=3.62 GB | system RAM used=46%
#     [E01_2] run #121 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=16 (17/18) | prompt_id=16 | mAP50=0.123 | time=22.8s
#     [E01_2] run #122 | image=20221010_HaldenNord/DJI_20221010151239_0115 | anchor=17 (18/18) | prompt_id=17 | mAP50=0.198 | time=22.7s
# [E01_2] (53/179) 20221010_HaldenNord/DJI_20221010151239_0115 done | 18 GT box(es) | image_mAP50_mean=0.175 | time=402.0s | avg/image=80.1s | ETA=168.2 min (2.80 h)
#     [MEM] process RSS=3.69 GB | system available=7.32 GB
#     [E01_2] run #123 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=0 (1/14) | prompt_id=0 | mAP50=0.507 | time=20.1s
#         [MEM] anchor=1 RSS=3.69 GB | system RAM used=46%
#     [E01_2] run #124 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=1 (2/14) | prompt_id=1 | mAP50=0.325 | time=22.2s
#     [E01_2] run #125 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=2 (3/14) | prompt_id=2 | mAP50=0.468 | time=20.6s
#     [E01_2] run #126 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=3 (4/14) | prompt_id=3 | mAP50=0.470 | time=21.3s
#         [MEM] anchor=4 RSS=3.65 GB | system RAM used=46%
#     [E01_2] run #127 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=4 (5/14) | prompt_id=4 | mAP50=0.448 | time=20.9s
#     [E01_2] run #128 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=5 (6/14) | prompt_id=5 | mAP50=0.495 | time=20.3s
#     [E01_2] run #129 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=6 (7/14) | prompt_id=6 | mAP50=0.493 | time=21.9s
#         [MEM] anchor=7 RSS=3.65 GB | system RAM used=46%
#     [E01_2] run #130 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=7 (8/14) | prompt_id=7 | mAP50=0.317 | time=24.7s
#     [E01_2] run #131 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=8 (9/14) | prompt_id=8 | mAP50=0.467 | time=21.7s
#     [E01_2] run #132 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=9 (10/14) | prompt_id=9 | mAP50=0.057 | time=23.8s
#         [MEM] anchor=10 RSS=3.63 GB | system RAM used=46%
#     [E01_2] run #133 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=10 (11/14) | prompt_id=10 | mAP50=0.459 | time=22.0s
#     [E01_2] run #134 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=11 (12/14) | prompt_id=11 | mAP50=0.469 | time=23.3s
#     [E01_2] run #135 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=12 (13/14) | prompt_id=12 | mAP50=0.460 | time=21.7s
#         [MEM] anchor=13 RSS=3.65 GB | system RAM used=46%
#     [E01_2] run #136 | image=20221010_HaldenNord/DJI_20221010151341_0176 | anchor=13 (14/14) | prompt_id=13 | mAP50=0.140 | time=23.4s
# [E01_2] (54/179) 20221010_HaldenNord/DJI_20221010151341_0176 done | 14 GT box(es) | image_mAP50_mean=0.398 | time=314.5s | avg/image=86.4s | ETA=180.1 min (3.00 h)
#     [MEM] process RSS=4.43 GB | system available=6.57 GB
#     [E01_2] run #137 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=0 (1/23) | prompt_id=0 | mAP50=0.453 | time=22.9s
#     [E01_2] run #138 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=1 (2/23) | prompt_id=1 | mAP50=0.437 | time=25.0s
#         [MEM] anchor=2 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #139 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=2 (3/23) | prompt_id=2 | mAP50=0.041 | time=25.6s
#     [E01_2] run #140 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=3 (4/23) | prompt_id=3 | mAP50=0.178 | time=25.0s
#     [E01_2] run #141 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=4 (5/23) | prompt_id=4 | mAP50=0.577 | time=22.7s
#         [MEM] anchor=5 RSS=3.64 GB | system RAM used=46%
#     [E01_2] run #142 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=5 (6/23) | prompt_id=5 | mAP50=0.546 | time=23.5s
#     [E01_2] run #143 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=6 (7/23) | prompt_id=6 | mAP50=0.511 | time=24.1s
#     [E01_2] run #144 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=7 (8/23) | prompt_id=7 | mAP50=0.011 | time=25.8s
#         [MEM] anchor=8 RSS=3.74 GB | system RAM used=46%
#     [E01_2] run #145 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=8 (9/23) | prompt_id=8 | mAP50=0.509 | time=22.2s
#     [E01_2] run #146 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=9 (10/23) | prompt_id=9 | mAP50=0.645 | time=20.7s
#     [E01_2] run #147 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=10 (11/23) | prompt_id=10 | mAP50=0.553 | time=21.6s
#         [MEM] anchor=11 RSS=3.66 GB | system RAM used=46%
#     [E01_2] run #148 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=11 (12/23) | prompt_id=11 | mAP50=0.602 | time=21.1s
#     [E01_2] run #149 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=12 (13/23) | prompt_id=12 | mAP50=0.608 | time=20.9s
#     [E01_2] run #150 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=13 (14/23) | prompt_id=13 | mAP50=0.456 | time=21.2s
#         [MEM] anchor=14 RSS=3.66 GB | system RAM used=46%
#     [E01_2] run #151 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=14 (15/23) | prompt_id=14 | mAP50=0.484 | time=22.7s
#     [E01_2] run #152 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=15 (16/23) | prompt_id=15 | mAP50=0.493 | time=21.6s
#     [E01_2] run #153 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=16 (17/23) | prompt_id=16 | mAP50=0.281 | time=22.9s
#         [MEM] anchor=17 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #154 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=17 (18/23) | prompt_id=17 | mAP50=0.311 | time=25.7s
#     [E01_2] run #155 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=18 (19/23) | prompt_id=18 | mAP50=0.414 | time=23.6s
#     [E01_2] run #156 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=19 (20/23) | prompt_id=19 | mAP50=0.072 | time=26.8s
#         [MEM] anchor=20 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #157 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=20 (21/23) | prompt_id=20 | mAP50=0.389 | time=25.0s
#     [E01_2] run #158 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=21 (22/23) | prompt_id=21 | mAP50=0.426 | time=25.5s
#     [E01_2] run #159 | image=20221010_HaldenNord/DJI_20221010151406_0200 | anchor=22 (23/23) | prompt_id=22 | mAP50=0.012 | time=28.3s
# [E01_2] (55/179) 20221010_HaldenNord/DJI_20221010151406_0200 done | 23 GT box(es) | image_mAP50_mean=0.392 | time=552.6s | avg/image=98.7s | ETA=204.0 min (3.40 h)
#     [MEM] process RSS=3.60 GB | system available=7.43 GB
#         [MEM] anchor=0 RSS=3.60 GB | system RAM used=45%
#     [E01_2] run #160 | image=20221010_HaldenNord/DJI_20221010151502_0255 | anchor=0 (1/5) | prompt_id=0 | mAP50=0.220 | time=20.9s
#     [E01_2] run #161 | image=20221010_HaldenNord/DJI_20221010151502_0255 | anchor=1 (2/5) | prompt_id=1 | mAP50=0.247 | time=21.2s
#     [E01_2] run #162 | image=20221010_HaldenNord/DJI_20221010151502_0255 | anchor=2 (3/5) | prompt_id=2 | mAP50=0.302 | time=20.0s
#         [MEM] anchor=3 RSS=3.62 GB | system RAM used=46%
#     [E01_2] run #163 | image=20221010_HaldenNord/DJI_20221010151502_0255 | anchor=3 (4/5) | prompt_id=3 | mAP50=0.212 | time=21.3s
#     [E01_2] run #164 | image=20221010_HaldenNord/DJI_20221010151502_0255 | anchor=4 (5/5) | prompt_id=4 | mAP50=0.423 | time=20.7s
# [E01_2] (56/179) 20221010_HaldenNord/DJI_20221010151502_0255 done | 5 GT box(es) | image_mAP50_mean=0.281 | time=108.5s | avg/image=98.9s | ETA=202.8 min (3.38 h)
#     [MEM] process RSS=3.63 GB | system available=7.39 GB
#     [E01_2] run #165 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=0 (1/11) | prompt_id=0 | mAP50=0.044 | time=21.4s
#         [MEM] anchor=1 RSS=3.64 GB | system RAM used=46%
#     [E01_2] run #166 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=1 (2/11) | prompt_id=1 | mAP50=0.158 | time=20.4s
#     [E01_2] run #167 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=2 (3/11) | prompt_id=2 | mAP50=0.188 | time=20.1s
#     [E01_2] run #168 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=3 (4/11) | prompt_id=3 | mAP50=0.183 | time=20.3s
#         [MEM] anchor=4 RSS=3.64 GB | system RAM used=46%
#     [E01_2] run #169 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=4 (5/11) | prompt_id=4 | mAP50=0.117 | time=20.0s
#     [E01_2] run #170 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=5 (6/11) | prompt_id=5 | mAP50=0.042 | time=21.4s
#     [E01_2] run #171 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=6 (7/11) | prompt_id=6 | mAP50=0.133 | time=20.0s
#         [MEM] anchor=7 RSS=3.67 GB | system RAM used=46%
#     [E01_2] run #172 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=7 (8/11) | prompt_id=7 | mAP50=0.035 | time=21.4s
#     [E01_2] run #173 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=8 (9/11) | prompt_id=8 | mAP50=0.023 | time=28.0s
#     [E01_2] run #174 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=9 (10/11) | prompt_id=9 | mAP50=0.206 | time=20.4s
#         [MEM] anchor=10 RSS=3.62 GB | system RAM used=45%
#     [E01_2] run #175 | image=20221010_HaldenNord/DJI_20221010151556_0309 | anchor=10 (11/11) | prompt_id=10 | mAP50=0.128 | time=20.5s
# [E01_2] (57/179) 20221010_HaldenNord/DJI_20221010151556_0309 done | 11 GT box(es) | image_mAP50_mean=0.114 | time=239.1s | avg/image=102.4s | ETA=208.3 min (3.47 h)
#     [MEM] process RSS=3.62 GB | system available=7.40 GB
#     [E01_2] run #176 | image=20221010_HaldenNord/DJI_20221010151812_0443 | anchor=0 (1/2) | prompt_id=0 | mAP50=0.046 | time=29.4s
#     [E01_2] run #177 | image=20221010_HaldenNord/DJI_20221010151812_0443 | anchor=1 (2/2) | prompt_id=1 | mAP50=0.505 | time=20.0s
# [E01_2] (58/179) 20221010_HaldenNord/DJI_20221010151812_0443 done | 2 GT box(es) | image_mAP50_mean=0.275 | time=52.6s | avg/image=101.2s | ETA=204.2 min (3.40 h)
#     [MEM] process RSS=3.63 GB | system available=7.39 GB
#         [MEM] anchor=0 RSS=3.63 GB | system RAM used=46%
#     [E01_2] run #178 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=0 (1/25) | prompt_id=0 | mAP50=0.363 | time=22.7s
#     [E01_2] run #179 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=1 (2/25) | prompt_id=1 | mAP50=0.100 | time=27.1s
#     [E01_2] run #180 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=2 (3/25) | prompt_id=2 | mAP50=0.099 | time=27.0s
#         [MEM] anchor=3 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #181 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=3 (4/25) | prompt_id=3 | mAP50=0.090 | time=27.3s
#     [E01_2] run #182 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=4 (5/25) | prompt_id=4 | mAP50=0.023 | time=21.6s
#     [E01_2] run #183 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=5 (6/25) | prompt_id=5 | mAP50=0.094 | time=26.8s
#         [MEM] anchor=6 RSS=3.64 GB | system RAM used=46%
#     [E01_2] run #184 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=6 (7/25) | prompt_id=6 | mAP50=0.187 | time=22.5s
#     [E01_2] run #185 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=7 (8/25) | prompt_id=7 | mAP50=0.221 | time=22.6s
#     [E01_2] run #186 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=8 (9/25) | prompt_id=8 | mAP50=0.229 | time=21.4s
#         [MEM] anchor=9 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #187 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=9 (10/25) | prompt_id=9 | mAP50=0.353 | time=25.2s
#     [E01_2] run #188 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=10 (11/25) | prompt_id=10 | mAP50=0.082 | time=27.5s
#     [E01_2] run #189 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=11 (12/25) | prompt_id=11 | mAP50=0.222 | time=22.0s
#         [MEM] anchor=12 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #190 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=12 (13/25) | prompt_id=12 | mAP50=0.357 | time=21.9s
#     [E01_2] run #191 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=13 (14/25) | prompt_id=13 | mAP50=0.090 | time=26.7s
#     [E01_2] run #192 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=14 (15/25) | prompt_id=14 | mAP50=0.366 | time=25.0s
#         [MEM] anchor=15 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #193 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=15 (16/25) | prompt_id=15 | mAP50=0.158 | time=25.1s
#     [E01_2] run #194 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=16 (17/25) | prompt_id=16 | mAP50=0.080 | time=25.5s
#     [E01_2] run #195 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=17 (18/25) | prompt_id=17 | mAP50=0.297 | time=21.6s
#         [MEM] anchor=18 RSS=3.60 GB | system RAM used=46%
#     [E01_2] run #196 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=18 (19/25) | prompt_id=18 | mAP50=0.057 | time=26.2s
#     [E01_2] run #197 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=19 (20/25) | prompt_id=19 | mAP50=0.191 | time=23.6s
#     [E01_2] run #198 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=20 (21/25) | prompt_id=20 | mAP50=0.183 | time=22.9s
#         [MEM] anchor=21 RSS=3.66 GB | system RAM used=46%
#     [E01_2] run #199 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=21 (22/25) | prompt_id=21 | mAP50=0.305 | time=22.7s
#     [E01_2] run #200 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=22 (23/25) | prompt_id=22 | mAP50=0.105 | time=27.7s
#     [E01_2] run #201 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=23 (24/25) | prompt_id=23 | mAP50=0.188 | time=23.0s
#         [MEM] anchor=24 RSS=3.65 GB | system RAM used=46%
#     [E01_2] run #202 | image=20221010_HaldenNord/DJI_20221010151951_0542 | anchor=24 (25/25) | prompt_id=24 | mAP50=0.088 | time=28.4s
# [E01_2] (59/179) 20221010_HaldenNord/DJI_20221010151951_0542 done | 25 GT box(es) | image_mAP50_mean=0.181 | time=622.6s | avg/image=113.6s | ETA=227.3 min (3.79 h)
#     [MEM] process RSS=3.70 GB | system available=7.29 GB
#     [E01_2] run #203 | image=20221010_HaldenNord/DJI_20221010152133_0643 | anchor=0 (1/7) | prompt_id=0 | mAP50=0.252 | time=21.0s
#     [E01_2] run #204 | image=20221010_HaldenNord/DJI_20221010152133_0643 | anchor=1 (2/7) | prompt_id=1 | mAP50=0.370 | time=19.5s
#         [MEM] anchor=2 RSS=3.70 GB | system RAM used=46%
#     [E01_2] run #205 | image=20221010_HaldenNord/DJI_20221010152133_0643 | anchor=2 (3/7) | prompt_id=2 | mAP50=0.237 | time=21.4s
#     [E01_2] run #206 | image=20221010_HaldenNord/DJI_20221010152133_0643 | anchor=3 (4/7) | prompt_id=3 | mAP50=0.272 | time=21.3s
#     [E01_2] run #207 | image=20221010_HaldenNord/DJI_20221010152133_0643 | anchor=4 (5/7) | prompt_id=4 | mAP50=0.290 | time=21.1s
#         [MEM] anchor=5 RSS=3.70 GB | system RAM used=46%
#     [E01_2] run #208 | image=20221010_HaldenNord/DJI_20221010152133_0643 | anchor=5 (6/7) | prompt_id=5 | mAP50=0.390 | time=19.9s
#     [E01_2] run #209 | image=20221010_HaldenNord/DJI_20221010152133_0643 | anchor=6 (7/7) | prompt_id=6 | mAP50=0.275 | time=22.3s
# [E01_2] (60/179) 20221010_HaldenNord/DJI_20221010152133_0643 done | 7 GT box(es) | image_mAP50_mean=0.298 | time=150.4s | avg/image=114.5s | ETA=227.1 min (3.78 h)
#     [MEM] process RSS=3.77 GB | system available=7.26 GB
#     [E01_2] run #210 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=0 (1/16) | prompt_id=0 | mAP50=0.099 | time=20.0s
#         [MEM] anchor=1 RSS=3.77 GB | system RAM used=47%
#     [E01_2] run #211 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=1 (2/16) | prompt_id=1 | mAP50=0.099 | time=20.9s
#     [E01_2] run #212 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=2 (3/16) | prompt_id=2 | mAP50=0.175 | time=20.4s
#     [E01_2] run #213 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=3 (4/16) | prompt_id=3 | mAP50=0.086 | time=20.4s
#         [MEM] anchor=4 RSS=3.77 GB | system RAM used=47%
#     [E01_2] run #214 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=4 (5/16) | prompt_id=4 | mAP50=0.152 | time=20.4s
#     [E01_2] run #215 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=5 (6/16) | prompt_id=5 | mAP50=0.026 | time=22.4s
#     [E01_2] run #216 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=6 (7/16) | prompt_id=6 | mAP50=0.036 | time=23.4s
#         [MEM] anchor=7 RSS=3.70 GB | system RAM used=46%
#     [E01_2] run #217 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=7 (8/16) | prompt_id=7 | mAP50=0.173 | time=19.9s
#     [E01_2] run #218 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=8 (9/16) | prompt_id=8 | mAP50=0.141 | time=23.2s
#     [E01_2] run #219 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=9 (10/16) | prompt_id=9 | mAP50=0.167 | time=20.2s
#         [MEM] anchor=10 RSS=3.76 GB | system RAM used=47%
#     [E01_2] run #220 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=10 (11/16) | prompt_id=10 | mAP50=0.123 | time=22.4s
#     [E01_2] run #221 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=11 (12/16) | prompt_id=11 | mAP50=0.125 | time=24.7s
#     [E01_2] run #222 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=12 (13/16) | prompt_id=12 | mAP50=0.127 | time=20.7s
#         [MEM] anchor=13 RSS=3.76 GB | system RAM used=47%
#     [E01_2] run #223 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=13 (14/16) | prompt_id=13 | mAP50=0.071 | time=21.6s
#     [E01_2] run #224 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=14 (15/16) | prompt_id=14 | mAP50=0.122 | time=21.7s
#     [E01_2] run #225 | image=20221010_HaldenNord/DJI_20221010152627_0933 | anchor=15 (16/16) | prompt_id=15 | mAP50=0.087 | time=21.6s
# [E01_2] (61/179) 20221010_HaldenNord/DJI_20221010152627_0933 done | 16 GT box(es) | image_mAP50_mean=0.113 | time=350.1s | avg/image=119.9s | ETA=235.7 min (3.93 h)
#     [MEM] process RSS=3.76 GB | system available=7.24 GB
#         [MEM] anchor=0 RSS=3.76 GB | system RAM used=47%
#     [E01_2] run #226 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=0 (1/48) | prompt_id=0 | mAP50=0.212 | time=21.9s
#     [E01_2] run #227 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=1 (2/48) | prompt_id=1 | mAP50=0.236 | time=22.8s
#     [E01_2] run #228 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=2 (3/48) | prompt_id=2 | mAP50=0.172 | time=27.0s
#         [MEM] anchor=3 RSS=3.70 GB | system RAM used=46%
#     [E01_2] run #229 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=3 (4/48) | prompt_id=3 | mAP50=0.076 | time=26.7s
#     [E01_2] run #230 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=4 (5/48) | prompt_id=4 | mAP50=0.213 | time=25.4s
#     [E01_2] run #231 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=5 (6/48) | prompt_id=5 | mAP50=0.294 | time=25.2s
#         [MEM] anchor=6 RSS=3.77 GB | system RAM used=47%
#     [E01_2] run #232 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=6 (7/48) | prompt_id=6 | mAP50=0.237 | time=24.2s
#     [E01_2] run #233 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=7 (8/48) | prompt_id=7 | mAP50=0.255 | time=23.2s
#     [E01_2] run #234 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=8 (9/48) | prompt_id=8 | mAP50=0.074 | time=28.3s
#         [MEM] anchor=9 RSS=3.70 GB | system RAM used=46%
#     [E01_2] run #235 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=9 (10/48) | prompt_id=9 | mAP50=0.087 | time=29.5s
#     [E01_2] run #236 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=10 (11/48) | prompt_id=10 | mAP50=0.088 | time=24.5s
#     [E01_2] run #237 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=11 (12/48) | prompt_id=11 | mAP50=0.088 | time=27.1s
#         [MEM] anchor=12 RSS=3.70 GB | system RAM used=46%
#     [E01_2] run #238 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=12 (13/48) | prompt_id=12 | mAP50=0.073 | time=26.9s
#     [E01_2] run #239 | image=20221010_HaldenNord/DJI_20221010152733_0996 | anchor=13 (14/48) | prompt_id=13 | mAP50=0.104 | time=26.9s
# ...
#     [E01_2] run #638 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=42 (43/105) | prompt_id=42 | mAP50=0.059 | time=38.6s
#     [E01_2] run #639 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=43 (44/105) | prompt_id=43 | mAP50=0.075 | time=32.1s
#         [MEM] anchor=44 RSS=4.01 GB | system RAM used=35%
#     [E01_2] run #640 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=44 (45/105) | prompt_id=44 | mAP50=0.094 | time=43.9s
#     [E01_2] run #641 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=45 (46/105) | prompt_id=45 | mAP50=0.182 | time=32.5s
#     [E01_2] run #642 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=46 (47/105) | prompt_id=46 | mAP50=0.162 | time=33.5s
#         [MEM] anchor=47 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #643 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=47 (48/105) | prompt_id=47 | mAP50=0.104 | time=26.8s
#     [E01_2] run #644 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=48 (49/105) | prompt_id=48 | mAP50=0.138 | time=27.5s
#     [E01_2] run #645 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=49 (50/105) | prompt_id=49 | mAP50=0.184 | time=33.1s
#         [MEM] anchor=50 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #646 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=50 (51/105) | prompt_id=50 | mAP50=0.076 | time=34.7s
#     [E01_2] run #647 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=51 (52/105) | prompt_id=51 | mAP50=0.196 | time=28.3s
#     [E01_2] run #648 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=52 (53/105) | prompt_id=52 | mAP50=0.085 | time=24.3s
#         [MEM] anchor=53 RSS=3.82 GB | system RAM used=34%
#     [E01_2] run #649 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=53 (54/105) | prompt_id=53 | mAP50=0.076 | time=26.5s
#     [E01_2] run #650 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=54 (55/105) | prompt_id=54 | mAP50=0.153 | time=25.2s
#     [E01_2] run #651 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=55 (56/105) | prompt_id=55 | mAP50=0.095 | time=23.6s
#         [MEM] anchor=56 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #652 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=56 (57/105) | prompt_id=56 | mAP50=0.113 | time=41.8s
#     [E01_2] run #653 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=57 (58/105) | prompt_id=57 | mAP50=0.072 | time=41.6s
#     [E01_2] run #654 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=58 (59/105) | prompt_id=58 | mAP50=0.109 | time=23.1s
#         [MEM] anchor=59 RSS=3.83 GB | system RAM used=34%
#     [E01_2] run #655 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=59 (60/105) | prompt_id=59 | mAP50=0.149 | time=26.1s
#     [E01_2] run #656 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=60 (61/105) | prompt_id=60 | mAP50=0.118 | time=34.7s
#     [E01_2] run #657 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=61 (62/105) | prompt_id=61 | mAP50=0.094 | time=34.8s
#         [MEM] anchor=62 RSS=4.42 GB | system RAM used=38%
#     [E01_2] run #658 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=62 (63/105) | prompt_id=62 | mAP50=0.122 | time=25.0s
#     [E01_2] run #659 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=63 (64/105) | prompt_id=63 | mAP50=0.173 | time=31.5s
#     [E01_2] run #660 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=64 (65/105) | prompt_id=64 | mAP50=0.213 | time=35.6s
#         [MEM] anchor=65 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #661 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=65 (66/105) | prompt_id=65 | mAP50=0.124 | time=42.1s
#     [E01_2] run #662 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=66 (67/105) | prompt_id=66 | mAP50=0.178 | time=41.5s
#     [E01_2] run #663 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=67 (68/105) | prompt_id=67 | mAP50=0.155 | time=28.2s
#         [MEM] anchor=68 RSS=4.02 GB | system RAM used=35%
#     [E01_2] run #664 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=68 (69/105) | prompt_id=68 | mAP50=0.117 | time=29.0s
#     [E01_2] run #665 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=69 (70/105) | prompt_id=69 | mAP50=0.167 | time=30.3s
#     [E01_2] run #666 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=70 (71/105) | prompt_id=70 | mAP50=0.084 | time=41.1s
#         [MEM] anchor=71 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #667 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=71 (72/105) | prompt_id=71 | mAP50=0.120 | time=23.3s
#     [E01_2] run #668 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=72 (73/105) | prompt_id=72 | mAP50=0.107 | time=24.0s
#     [E01_2] run #669 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=73 (74/105) | prompt_id=73 | mAP50=0.098 | time=24.8s
#         [MEM] anchor=74 RSS=3.83 GB | system RAM used=34%
#     [E01_2] run #670 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=74 (75/105) | prompt_id=74 | mAP50=0.122 | time=26.1s
#     [E01_2] run #671 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=75 (76/105) | prompt_id=75 | mAP50=0.067 | time=35.9s
#     [E01_2] run #672 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=76 (77/105) | prompt_id=76 | mAP50=0.052 | time=36.5s
#         [MEM] anchor=77 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #673 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=77 (78/105) | prompt_id=77 | mAP50=0.151 | time=38.7s
#     [E01_2] run #674 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=78 (79/105) | prompt_id=78 | mAP50=0.060 | time=35.3s
#     [E01_2] run #675 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=79 (80/105) | prompt_id=79 | mAP50=0.163 | time=32.8s
#         [MEM] anchor=80 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #676 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=80 (81/105) | prompt_id=80 | mAP50=0.053 | time=36.6s
#     [E01_2] run #677 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=81 (82/105) | prompt_id=81 | mAP50=0.062 | time=36.8s
#     [E01_2] run #678 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=82 (83/105) | prompt_id=82 | mAP50=0.049 | time=34.7s
#         [MEM] anchor=83 RSS=4.91 GB | system RAM used=42%
#     [E01_2] run #679 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=83 (84/105) | prompt_id=83 | mAP50=0.055 | time=35.9s
#     [E01_2] run #680 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=84 (85/105) | prompt_id=84 | mAP50=0.130 | time=27.9s
#     [E01_2] run #681 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=85 (86/105) | prompt_id=85 | mAP50=0.151 | time=28.2s
#         [MEM] anchor=86 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #682 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=86 (87/105) | prompt_id=86 | mAP50=0.068 | time=44.0s
#     [E01_2] run #683 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=87 (88/105) | prompt_id=87 | mAP50=0.162 | time=28.8s
#     [E01_2] run #684 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=88 (89/105) | prompt_id=88 | mAP50=0.051 | time=43.4s
#         [MEM] anchor=89 RSS=4.26 GB | system RAM used=37%
#     [E01_2] run #685 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=89 (90/105) | prompt_id=89 | mAP50=0.144 | time=35.7s
#     [E01_2] run #686 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=90 (91/105) | prompt_id=90 | mAP50=0.068 | time=35.7s
#     [E01_2] run #687 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=91 (92/105) | prompt_id=91 | mAP50=0.124 | time=29.0s
#         [MEM] anchor=92 RSS=4.78 GB | system RAM used=41%
#     [E01_2] run #688 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=92 (93/105) | prompt_id=92 | mAP50=0.062 | time=38.6s
#     [E01_2] run #689 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=93 (94/105) | prompt_id=93 | mAP50=0.061 | time=36.9s
#     [E01_2] run #690 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=94 (95/105) | prompt_id=94 | mAP50=0.066 | time=36.0s
#         [MEM] anchor=95 RSS=6.35 GB | system RAM used=52%
#     [E01_2] run #691 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=95 (96/105) | prompt_id=95 | mAP50=0.172 | time=26.5s
#     [E01_2] run #692 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=96 (97/105) | prompt_id=96 | mAP50=0.127 | time=24.7s
#     [E01_2] run #693 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=97 (98/105) | prompt_id=97 | mAP50=0.132 | time=39.1s
#         [MEM] anchor=98 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #694 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=98 (99/105) | prompt_id=98 | mAP50=0.069 | time=35.3s
#     [E01_2] run #695 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=99 (100/105) | prompt_id=99 | mAP50=0.149 | time=31.2s
#     [E01_2] run #696 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=100 (101/105) | prompt_id=100 | mAP50=0.084 | time=34.5s
#         [MEM] anchor=101 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #697 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=101 (102/105) | prompt_id=101 | mAP50=0.130 | time=27.2s
#     [E01_2] run #698 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=102 (103/105) | prompt_id=102 | mAP50=0.118 | time=24.6s
#     [E01_2] run #699 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=103 (104/105) | prompt_id=103 | mAP50=0.125 | time=26.2s
#         [MEM] anchor=104 RSS=3.84 GB | system RAM used=34%
#     [E01_2] run #700 | image=20230426_Wallenwil/DJI_20230426110820_0061 | anchor=104 (105/105) | prompt_id=104 | mAP50=0.104 | time=24.7s
# [E01_2] (89/179) 20230426_Wallenwil/DJI_20230426110820_0061 done | 105 GT box(es) | image_mAP50_mean=0.106 | time=3417.4s | avg/image=269.1s | ETA=403.7 min (6.73 h)
#     [MEM] process RSS=3.79 GB | system available=9.03 GB
#     [E01_2] run #701 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=0 (1/51) | prompt_id=0 | mAP50=0.278 | time=24.2s
#     [E01_2] run #702 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=1 (2/51) | prompt_id=1 | mAP50=0.269 | time=22.0s
#         [MEM] anchor=2 RSS=3.80 GB | system RAM used=34%
#     [E01_2] run #703 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=2 (3/51) | prompt_id=2 | mAP50=0.074 | time=29.8s
#     [E01_2] run #704 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=3 (4/51) | prompt_id=3 | mAP50=0.171 | time=22.1s
#     [E01_2] run #705 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=4 (5/51) | prompt_id=4 | mAP50=0.048 | time=32.1s
#         [MEM] anchor=5 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #706 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=5 (6/51) | prompt_id=5 | mAP50=0.223 | time=21.9s
#     [E01_2] run #707 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=6 (7/51) | prompt_id=6 | mAP50=0.372 | time=24.7s
#     [E01_2] run #708 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=7 (8/51) | prompt_id=7 | mAP50=0.314 | time=22.3s
#         [MEM] anchor=8 RSS=3.85 GB | system RAM used=34%
#     [E01_2] run #709 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=8 (9/51) | prompt_id=8 | mAP50=0.375 | time=22.9s
#     [E01_2] run #710 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=9 (10/51) | prompt_id=9 | mAP50=0.190 | time=23.7s
#     [E01_2] run #711 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=10 (11/51) | prompt_id=10 | mAP50=0.271 | time=21.8s
#         [MEM] anchor=11 RSS=3.82 GB | system RAM used=34%
#     [E01_2] run #712 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=11 (12/51) | prompt_id=11 | mAP50=0.243 | time=21.7s
#     [E01_2] run #713 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=12 (13/51) | prompt_id=12 | mAP50=0.269 | time=24.3s
#     [E01_2] run #714 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=13 (14/51) | prompt_id=13 | mAP50=0.069 | time=29.2s
#         [MEM] anchor=14 RSS=4.25 GB | system RAM used=37%
#     [E01_2] run #715 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=14 (15/51) | prompt_id=14 | mAP50=0.234 | time=21.6s
#     [E01_2] run #716 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=15 (16/51) | prompt_id=15 | mAP50=0.283 | time=25.5s
#     [E01_2] run #717 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=16 (17/51) | prompt_id=16 | mAP50=0.082 | time=29.4s
#         [MEM] anchor=17 RSS=3.92 GB | system RAM used=35%
#     [E01_2] run #718 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=17 (18/51) | prompt_id=17 | mAP50=0.185 | time=21.6s
#     [E01_2] run #719 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=18 (19/51) | prompt_id=18 | mAP50=0.218 | time=23.8s
#     [E01_2] run #720 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=19 (20/51) | prompt_id=19 | mAP50=0.258 | time=22.0s
#         [MEM] anchor=20 RSS=3.84 GB | system RAM used=34%
#     [E01_2] run #721 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=20 (21/51) | prompt_id=20 | mAP50=0.074 | time=27.9s
#     [E01_2] run #722 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=21 (22/51) | prompt_id=21 | mAP50=0.207 | time=26.0s
#     [E01_2] run #723 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=22 (23/51) | prompt_id=22 | mAP50=0.184 | time=21.8s
#         [MEM] anchor=23 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #724 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=23 (24/51) | prompt_id=23 | mAP50=0.278 | time=21.4s
#     [E01_2] run #725 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=24 (25/51) | prompt_id=24 | mAP50=0.134 | time=21.0s
#     [E01_2] run #726 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=25 (26/51) | prompt_id=25 | mAP50=0.279 | time=21.5s
#         [MEM] anchor=26 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #727 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=26 (27/51) | prompt_id=26 | mAP50=0.247 | time=22.0s
#     [E01_2] run #728 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=27 (28/51) | prompt_id=27 | mAP50=0.066 | time=26.9s
#     [E01_2] run #729 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=28 (29/51) | prompt_id=28 | mAP50=0.079 | time=32.2s
#         [MEM] anchor=29 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #730 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=29 (30/51) | prompt_id=29 | mAP50=0.073 | time=29.3s
#     [E01_2] run #731 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=30 (31/51) | prompt_id=30 | mAP50=0.070 | time=29.9s
#     [E01_2] run #732 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=31 (32/51) | prompt_id=31 | mAP50=0.068 | time=30.6s
#         [MEM] anchor=32 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #733 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=32 (33/51) | prompt_id=32 | mAP50=0.070 | time=28.6s
#     [E01_2] run #734 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=33 (34/51) | prompt_id=33 | mAP50=0.081 | time=29.2s
#     [E01_2] run #735 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=34 (35/51) | prompt_id=34 | mAP50=0.070 | time=27.7s
#         [MEM] anchor=35 RSS=3.79 GB | system RAM used=34%
#     [E01_2] run #736 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=35 (36/51) | prompt_id=35 | mAP50=0.062 | time=34.9s
#     [E01_2] run #737 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=36 (37/51) | prompt_id=36 | mAP50=0.078 | time=29.1s
#     [E01_2] run #738 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=37 (38/51) | prompt_id=37 | mAP50=0.082 | time=30.1s
#         [MEM] anchor=38 RSS=4.29 GB | system RAM used=38%
#     [E01_2] run #739 | image=20230426_Wallenwil/DJI_20230426110838_0071 | anchor=38 (39/51) | prompt_id=38 | mAP50=0.216 | time=22.4s

# %%
#  Aggregate statistics for ONE experiment (run separately per experiment)
import pandas as pd
import numpy as np
import os

#  Change this single line for each experiment
EXPERIMENT_CSV = "/content/drive/MyDrive/master_thesis/results/results2_E02_2.csv"
OUTPUT_DIR = "/content/drive/MyDrive/master_thesis/results/"
os.makedirs(OUTPUT_DIR, exist_ok=True)  # just in case it doesn't exist yet

assert os.path.exists(EXPERIMENT_CSV), f"File not found: {EXPERIMENT_CSV}"
df = pd.read_csv(EXPERIMENT_CSV)

exp_name = df["experiment_name"].iloc[0]
print(f"Experiment: {exp_name}")
print(f"Total rows (image x prompt runs): {len(df)}")
print(f"Number of distinct images: {df['image_ID'].nunique()}")

# %%
#  Raw per-run stats (every row = one image + one prompt set, independent observation)
# Here, every row in our CSV is treated as one independent experiment.
#output 1 value per metric (produces one overall mean and one overall std for each metric)
raw_summary = df.agg(
    n_runs=("mAP50", "count"),
    mAP50_mean=("mAP50", "mean"),
    mAP50_std=("mAP50", "std"),
    precision_mean=("precision", "mean"),
    precision_std=("precision", "std"),
    recall_mean=("recall", "mean"),
    recall_std=("recall", "std"),
    IoU1_mean=("IoU1", "mean"),
    IoU1_std=("IoU1", "std"),
    IoU2_mean=("IoU2", "mean"),
    IoU2_std=("IoU2", "std"),
)

raw_summary.to_csv(os.path.join(OUTPUT_DIR, f"raw_summary_{exp_name}.csv"), index=False)
print(f"Saved raw_summary_{exp_name}.csv to {OUTPUT_DIR}")

print(f"=== {exp_name} -- raw per-run summary (all rows independent) ===")
print(raw_summary)

# %%
# Image-level stats (collapse multiple prompt runs per image to one value first,
# so images with more GT boxes / more prompt sets don't dominate the average)
image_level = ( # produces one mean value per image for each metric
    df.groupby("image_ID")
    .agg(
        mAP50_image_mean=("mAP50", "mean"),
        precision_image_mean=("precision", "mean"),
        recall_image_mean=("recall", "mean"),
        IoU1_image_mean=("IoU1", "mean"),
        IoU2_image_mean=("IoU2", "mean"),
        n_prompts=("mAP50", "count"),
    )
    .reset_index()
)
image_level.to_csv(os.path.join(OUTPUT_DIR, f"image_level_{exp_name}.csv"), index=False)
print(f"Saved image_level{exp_name}.csv to {OUTPUT_DIR}")

print(f"=== {exp_name} -- image-level results ({len(image_level)} images) ===")
with pd.option_context("display.max_rows", None, "display.max_columns", None):
    print(image_level.to_string(index=False))

# %%
image_level_summary = pd.DataFrame({
    "experiment_name": [exp_name],
    "n_images": [image_level["image_ID"].nunique()],
    "mAP50_mean": [image_level["mAP50_image_mean"].mean()],
    "mAP50_std": [image_level["mAP50_image_mean"].std()],
    "precision_mean": [image_level["precision_image_mean"].mean()],
    "precision_std": [image_level["precision_image_mean"].std()],
    "recall_mean": [image_level["recall_image_mean"].mean()],
    "recall_std": [image_level["recall_image_mean"].std()],
    "IoU1_mean": [image_level["IoU1_image_mean"].mean()],
    "IoU2_mean": [image_level["IoU2_image_mean"].mean()],
})

image_level_summary.to_csv(os.path.join(OUTPUT_DIR, f"summary_{exp_name}.csv"), index=False)
print(f"\nSaved image_level_{exp_name}.csv and summary_{exp_name}.csv to {OUTPUT_DIR}")

print(f"\n=== {exp_name} -- image-level summary ===")
print(image_level_summary.to_string(index=False))
